# %%
# ============================
# 0. 구글 드라이브 마운트
# ============================
from google.colab import drive
drive.mount('/content/drive')

# (선택) 드라이브 구조 확인
# !ls -lah /content/drive
# !ls -lah "/content/drive/MyDrive"
# Out:
# Mounted at /content/drive
# total 16K
# dr-x------ 4 root root 4.0K Nov 25 07:33 .Encrypted
# drwx------ 2 root root 4.0K Nov 25 07:33 MyDrive
# dr-x------ 2 root root 4.0K Nov 25 07:33 .shortcut-targets-by-id
# drwx------ 5 root root 4.0K Nov 25 07:33 .Trash-0
# ls: /content/drive/MyDrive/멀티캠퍼스_LLMs_Llama_index: No such file or directory
# total 265K
# -rw------- 1 root root  176 Nov 21 02:43 '11 21 헤세드 인적사항 사본.gsheet'
# -rw------- 1 root root  176 Mar 29  2025 '5 11 업데이트 버스킹 Song List 추천.gsheet'
# drwx------ 2 root root 4.0K May  7  2025 'Colab Notebooks'
# drwx------ 2 root root 4.0K Nov 13 06:40  data_MP3
# drwx------ 2 root root 4.0K Nov 13 06:40  data_MP4
# drwx------ 2 root root 4.0K Nov 13 07:30  output
# lrw------- 1 root root    0 Nov 19 02:15  멀티캠퍼스_LLMs_Llama_index -> /content/drive/.shortcut-targets-by-id/1L_SL2y6c8AjDF5Plju0IaQnV4pi-pBmJ/멀티캠퍼스_LLMs_Llama_index
# -rw------- 1 root root 247K Nov 14 08:04  퍼실AI_baseline.ipynb
# -rw------- 1 root root  176 Nov 17 11:01 '헤세드 라인연결 가이드.gslides'
# -rw------- 1 root root  176 Oct 31 03:50 '헤세드 인적사항 복사본.gsheet'

# %%
# ============================
# 1. 패키지 설치
# ============================
# Whisper는 안 쓰니까 제거, 대신 requests만 추가
# !pip -q install moviepy requests
# !pip -q install transformers accelerate librosa soundfile torchaudio

# %%
# ============================
# 2. import
# ============================
import os
from pathlib import Path
import mimetypes
import json
import time
import getpass

import numpy as np
import torch
import librosa
import soundfile as sf
import requests

from transformers import (
    pipeline,
    AutoConfig,
    AutoTokenizer,
    AutoModelForSequenceClassification,
)

from collections import Counter
import csv
import math

# %%
# ============================
# 2-1. 리턴제로 STT 클라이언트 정의
# ============================
class RTZROpenAPIClient:
    """
    리턴제로 파일 STT용 최소 클라이언트
    - /v1/authenticate : JWT 발급
    - /v1/transcribe   : 파일 STT 요청
    - /v1/transcribe/{id} : 결과 폴링
    """
    def __init__(self, client_id: str, client_secret: str,
                 base_url: str = "https://openapi.vito.ai"):
        self.base_url = base_url.rstrip("/")
        self.client_id = client_id
        self.client_secret = client_secret

        if not self.client_id or not self.client_secret:
            raise ValueError("RTZR CLIENT_ID / CLIENT_SECRET가 비었습니다.")

        self._sess = requests.Session()
        self._token = None

    @property
    def token(self) -> str:
        """현재 JWT 토큰을 반환, 없거나 오래되면 /v1/authenticate로 갱신"""
        # expire_at 기준으로 30분 전이면 다시 받기 (공식 샘플과 유사 로직)
        if self._token is None or self._token.get("expire_at", 0) < time.time() - 1800:
            resp = self._sess.post(
                f"{self.base_url}/v1/authenticate",
                data={
                    "client_id": self.client_id,
                    "client_secret": self.client_secret,
                },
            )
            resp.raise_for_status()
            self._token = resp.json()

        access = self._token.get("access_token")
        if not access:
            raise RuntimeError("authenticate 응답에 access_token이 없습니다.")
        return access

    def _auth_headers(self):
        return {"Authorization": f"Bearer {self.token}"}

    def transcribe_file(self, file_path: str, config: dict) -> dict:
        """ /v1/transcribe 로 파일 STT 요청 """
        url = f"{self.base_url}/v1/transcribe"
        with open(file_path, "rb") as f:
            files = {"file": (os.path.basename(file_path), f)}
            data = {"config": json.dumps(config)}
            resp = self._sess.post(url, headers=self._auth_headers(),
                                   files=files, data=data)
            resp.raise_for_status()
            return resp.json()  # {"id": "..."} 형태

    def get_transcription(self, transcribe_id: str) -> dict:
        url = f"{self.base_url}/v1/transcribe/{transcribe_id}"
        resp = self._sess.get(url, headers=self._auth_headers())
        resp.raise_for_status()
        return resp.json()

    def wait_for_result(self, transcribe_id: str,
                        poll_interval_sec: int = 5,
                        timeout_sec: int = 3600) -> dict:
        """폴링하면서 completed/failed 될 때까지 기다렸다가 결과 리턴"""
        deadline = time.time() + timeout_sec
        while True:
            if time.time() > deadline:
                raise TimeoutError("STT 결과 대기 중 timeout")

            result = self.get_transcription(transcribe_id)
            status = result.get("status")
            if status in ("completed", "failed"):
                return result

            time.sleep(poll_interval_sec)

# %%
# ============================
# 3. 입력 미디어 설정 (비디오 or 오디오)
# ============================
media_path = "/content/drive/MyDrive/data_MP3/PMCT.mp3"
desired_audio_path = "/content/drive/MyDrive/data_MP3/extracted_audio.mp3"  # 비디오일 때만 사용

def is_audio(path: str) -> bool:
    mt, _ = mimetypes.guess_type(path)
    return (mt or "").startswith("audio")

if is_audio(media_path):
    # 이미 오디오 파일이면 추출 생략
    audio_path = media_path
    print(f"[SKIP extract] Detected audio file. Use as-is: {audio_path}")
else:
    # 비디오면 moviepy로 오디오 추출
    from moviepy.editor import VideoFileClip
    Path(Path(desired_audio_path).parent).mkdir(parents=True, exist_ok=True)
    clip = VideoFileClip(media_path)
    if clip.audio is None:
        raise RuntimeError("이 비디오에는 오디오 트랙이 없습니다.")
    clip.audio.write_audiofile(desired_audio_path)  # 확장자에 따라 자동 인코딩
    clip.close()
    audio_path = desired_audio_path
    print(f"[EXTRACT] Audio saved to: {audio_path}")
# Out:
# [SKIP extract] Detected audio file. Use as-is: /content/drive/MyDrive/data_MP3/PMCT.mp3

# %%
# ============================
# 4. 리턴제로 기반 텍스트 인식
# ============================
clean_audio_path = "/content/drive/MyDrive/data_MP3/PMCT_cleaned.wav"

# 4-1) 오디오 전처리: 16kHz 모노 + 앞/뒤 무음 제거 + 노멀라이즈
y, sr = librosa.load(audio_path, sr=16000, mono=True)
raw_duration = len(y) / sr
print(f"[DEBUG] 원본 오디오 duration = {raw_duration:.2f} s")

# 앞/뒤 무음만 제거 (중간은 건드리지 않음)
y, _ = librosa.effects.trim(y, top_db=30)

peak = np.max(np.abs(y))
if peak > 0:
    y = y / peak

Path(clean_audio_path).parent.mkdir(parents=True, exist_ok=True)
sf.write(clean_audio_path, y, 16000)
audio_for_asr = clean_audio_path

clean_duration = librosa.get_duration(path=audio_for_asr)
print(f"[DEBUG] 정제된 오디오 duration = {clean_duration:.2f} s")

# 4-2) RTZR API 키 입력 (환경변수 우선, 없으면 직접 입력)
if "RTZR_CLIENT_ID" in os.environ and "RTZR_CLIENT_SECRET" in os.environ:
    RTZR_CLIENT_ID = os.environ["RTZR_CLIENT_ID"]
    RTZR_CLIENT_SECRET = os.environ["RTZR_CLIENT_SECRET"]
    print("[INFO] 환경변수에서 RTZR CLIENT_ID/SECRET을 읽었습니다.")
else:
    RTZR_CLIENT_ID = input("RTZR CLIENT_ID를 입력하세요: ").strip()
    RTZR_CLIENT_SECRET = getpass.getpass(
        "RTZR CLIENT_SECRET를 입력하세요 (입력 시 화면에 표시되지 않습니다): "
    ).strip()

client = RTZROpenAPIClient(RTZR_CLIENT_ID, RTZR_CLIENT_SECRET)

# 4-3) STT 설정 (화자 분리 ON)
#   - Somm ers 모델 + GENERAL 도메인 기준
SPEAKER_COUNT = 0  # 0이면 화자 수 자동 추정

config = {
    "model_name": "sommers",          # 또는 "whisper"
    "domain": "GENERAL",              # 회의/콜이면 "CALL" 고려
    "use_diarization": True,          # 화자 분리
    "diarization": {"spk_count": SPEAKER_COUNT},
    "use_paragraph_splitter": True,
    "paragraph_splitter": {"max": 80},
    "use_itn": False,
    "use_disfluency_filter": False,
    "use_profanity_filter": False,
    # 필요하면 옵션 추가 가능 (keywords, use_word_timestamp 등)
}

print("[DEBUG] RTZR STT config:")
print(json.dumps(config, ensure_ascii=False, indent=2))

# 4-4) STT 요청 + 결과 대기
submit_resp = client.transcribe_file(audio_for_asr, config)
transcribe_id = submit_resp.get("id")
print(f"[INFO] STT 작업 ID: {transcribe_id}")

if not transcribe_id:
    print("[ERROR] transcribe_id가 없습니다. 응답 전체:")
    print(json.dumps(submit_resp, ensure_ascii=False, indent=2))
    raise SystemExit

print("[INFO] 결과 대기 중 (5초 간격 폴링)...")
rtzr_result = client.wait_for_result(transcribe_id, poll_interval_sec=5, timeout_sec=3600)

print(f"[DEBUG] RTZR status = {rtzr_result.get('status')}")

# 4-5) RTZR 결과 → Whisper 스타일 segments_to_use로 변환
utterances = rtzr_result.get("results", {}).get("utterances", [])
print(f"[DEBUG] 총 utterance 개수 = {len(utterances)}")

segments_to_use = []
for utt in utterances:
    start_ms = int(utt.get("start_at", 0))
    dur_ms = int(utt.get("duration", 0))
    start_s = start_ms / 1000.0
    end_s = (start_ms + dur_ms) / 1000.0
    text = utt.get("msg", "").strip()
    spk = utt.get("spk", 0)

    segments_to_use.append({
        "start": start_s,
        "end": end_s,
        "text": text,
        "speaker": spk,  # 나중에 화자별 분석용으로 사용 가능
    })

if segments_to_use:
    last_end = segments_to_use[-1]["end"]
    print(f"[DEBUG] 마지막 세그먼트 end = {last_end:.2f} s")

    print("\n[DEBUG] 처음 5개 세그먼트:")
    for seg in segments_to_use[:5]:
        print(
            f"  [{seg['start']:.2f}-{seg['end']:.2f}] "
            f"Speaker={seg['speaker']} :: {seg['text']}"
        )

    print("\n[DEBUG] 마지막 5개 세그먼트:")
    for seg in segments_to_use[-5:]:
        print(
            f"  [{seg['start']:.2f}-{seg['end']:.2f}] "
            f"Speaker={seg['speaker']} :: {seg['text']}"
        )

# 콘솔에 구간별 자막 형태로 출력
for seg in segments_to_use:
    print(f"[{seg['start']:.2f}–{seg['end']:.2f}] (spk={seg['speaker']}) {seg['text']}")

# 전체 텍스트 합치기
full_text = " ".join(seg["text"] for seg in segments_to_use)
print("Full text:\n", full_text)

# 텍스트 파일로 저장
output_txt_path = '/content/drive/MyDrive/output/sample.txt'
Path(output_txt_path).parent.mkdir(parents=True, exist_ok=True)
with open(output_txt_path, 'w', encoding="utf-8") as f:
    for seg in segments_to_use:
        f.write(f"[{seg['start']:.2f}–{seg['end']:.2f}] (spk={seg['speaker']}) {seg['text']}\n")

print(f"\nTranscription saved to {output_txt_path}")
# Out:
# /tmp/ipython-input-3798986629.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(audio_path, sr=16000, mono=True)
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# [DEBUG] 원본 오디오 duration = 6982.80 s
# [DEBUG] 정제된 오디오 duration = 6982.29 s
# RTZR CLIENT_ID를 입력하세요: wtVlucULYnE0c0ATqMlq
# RTZR CLIENT_SECRET를 입력하세요 (입력 시 화면에 표시되지 않습니다): ··········
# [DEBUG] RTZR STT config:
# {
#   "model_name": "sommers",
#   "domain": "GENERAL",
#   "use_diarization": true,
#   "diarization": {
#     "spk_count": 0
#   },
#   "use_paragraph_splitter": true,
#   "paragraph_splitter": {
#     "max": 80
#   },
#   "use_itn": false,
#   "use_disfluency_filter": false,
#   "use_profanity_filter": false
# }
# [INFO] STT 작업 ID: HTsAxAr1QA-K7CEL7zQotg
# [INFO] 결과 대기 중 (5초 간격 폴링)...
# [DEBUG] RTZR status = completed
# [DEBUG] 총 utterance 개수 = 781
# [DEBUG] 마지막 세그먼트 end = 6982.27 s
#
# [DEBUG] 처음 5개 세그먼트:
#   [0.20-9.14] Speaker=0 :: 네, 사실 제가 지난번에 에폴라랑, 에이패스비, 에이아이 공강의 목표를 쓴 게 있었는데, 사실 이제 저는 그거를 제가 직접 설정하지는 않았어요.
#   [9.74-22.05] Speaker=0 :: 왜냐하면은 사실 종일 대표님으로부터 그냥 너 이거 해라고 탁 그냥 부여를 받았기 때문에 제가 하지 않아서 여기에 피엠 이 한다라고 딱 못 쓰겠더라고요.
#   [22.59-32.42] Speaker=0 :: 그래서 앞에 프로젝트를 발휘하고 추진한자 그까 동일 대표님을 네 생각을 하면서 이렇게 쓴 거죠. 네, 그리고 사실상 피엠이 하긴 해야죠.
#   [32.42-45.00] Speaker=0 :: 그래서 목적 달성 인무를 위임받아 프로젝표를 맡게 된 비엠 교육을 받고 있는 우리 네 해래서 좀 앞으로도 제가 목표를 아무리 받아도 내가 그거를 약간 이게 말이 되는 목표인가.
#   [45.09-50.63] Speaker=0 :: 정말 이게 근거가 있는 건가라고 좀 다시 회고를 해야 되는 네 생각을 하게 됐고요.
#
# [DEBUG] 마지막 5개 세그먼트:
#   [6958.87-6959.98] Speaker=1 :: 어, 배고파 예.
#   [6962.24-6967.86] Speaker=1 :: 그래서 이렇게 마무리를 하고 음 다음 주에 봐요.
#   [6970.19-6971.17] Speaker=1 :: 수고하셨습니다.
#   [6973.52-6976.31] Speaker=3 :: 수고 아이 왜
#   [6977.09-6982.27] Speaker=1 :: 머리가 아프지 여기 공기가 안통한가, 아니.
# [0.20–9.14] (spk=0) 네, 사실 제가 지난번에 에폴라랑, 에이패스비, 에이아이 공강의 목표를 쓴 게 있었는데, 사실 이제 저는 그거를 제가 직접 설정하지는 않았어요.
# [9.74–22.05] (spk=0) 왜냐하면은 사실 종일 대표님으로부터 그냥 너 이거 해라고 탁 그냥 부여를 받았기 때문에 제가 하지 않아서 여기에 피엠 이 한다라고 딱 못 쓰겠더라고요.
# [22.59–32.42] (spk=0) 그래서 앞에 프로젝트를 발휘하고 추진한자 그까 동일 대표님을 네 생각을 하면서 이렇게 쓴 거죠. 네, 그리고 사실상 피엠이 하긴 해야죠.
# [32.42–45.00] (spk=0) 그래서 목적 달성 인무를 위임받아 프로젝표를 맡게 된 비엠 교육을 받고 있는 우리 네 해래서 좀 앞으로도 제가 목표를 아무리 받아도 내가 그거를 약간 이게 말이 되는 목표인가.
# [45.09–50.63] (spk=0) 정말 이게 근거가 있는 건가라고 좀 다시 회고를 해야 되는 네 생각을 하게 됐고요.
# [51.13–63.97] (spk=0) 네, 그리고 저는 이 질문을 다른 분들이랑 읽다 보니까지 제가 좀 잘못 이해했다고 생각했는데 저는 목표를 설정하는 것이 중요하다라고 해정을 해서. 네, 막 이 썼어요.
# [64.00–77.51] (spk=0) 네, 그래서 사실 일 번이랑 좀 겹친다고 생각도 들었고, 네, 그래서 뭐 이거는 그냥 넘어갈게요. 네, 일 번이랑 거의 비슷한 얘기라서 네, 그리고 좋은 목표는 어때야 되는가?
# [77.60–89.35] (spk=0) 이 좋은이라 게 좀 네 좀 어려웠는데. 사실 이제 뭐 형희 질장님이랑 원언언 하면서 좀 얘기했던 거를 갖고 왔는데 아까도 얘기한 것처럼. 근거 기반으로 네 목표를.
# [89.35–103.11] (spk=0) 설정을 해야 되고 약간 무작정 뭐 백배 백 배 달성 막 약간 이런 것들은 그냥 무대거잖아요. 네, 거기까지 도달하기 위해서 어떤 계획을 해야 될지, 뭐 이렇게 지침이 되는 것도 아니고.
# [103.30–111.26] (spk=0) 해래서 근거 기반으로 설정해야 그 목표를 달성하기 위한 계획도 세워질 수 있을 것 같아서. 네, 그리고 멤버들도 이해를 할 수 있겠죠.
# [111.53–125.86] (spk=0) 그랬고, 그리고 근거를 기반으로 했다고 해서 좀 이거는 저희가 간과하면 안 되는 것 같은데. 현실적이고 달성, 회범직함, 약간 이런 쉬운 목표는 좋은 목표가 아닌 것 같애요.
# [125.99–134.01] (spk=0) 네, 그래서 도전 인식이 생겨야 되고, 그다음에 그냥 뭐. 예를 들어 하루에 세 끼 먹기 아, 새 끼 좀 어려울 수 있죠.
# [287.97–296.94] (spk=0) 그래서 막 이거를 다 답변을 하고 그 기존의 원언원이라든지 뭐 추가자료 공유해 주신 걸 보니까 좀 약간 아, 반성이 되더라고요.
# [296.94–305.90] (spk=0) 그리고 어쨌든 제가 이 각 프로젝트의 목표가 있다 보니까 네, 이거를 그냥 네 와이하우 왓 약간 이 포맷으로 한번 정리를 해봤어요.
# [306.06–315.60] (spk=0) 결국에 제가 이 두 개를 다 하고 있는 거는 지금 우리 코코네, 엠의 흑자전환 목표를 가지고 하는 거인 것 같아서 이렇게 써웠습니다.
# [318.34–318.58] (spk=0) 예.
# [321.33–321.85] (spk=0) 아, 네.
# [323.91–341.40] (spk=1) 의견을 적해서 그랬듯이 한마디씩 무조건 하 그랬었잖아요. 당분간은 요 체계로 한번 어 입트임 연습 한다 생각하고 해봅시다. 제 제 그 제가 순서를 정해드릴게요.
# [342.01–348.09] (spk=1) 제 그 화면 기준으로 선민님 풀림님, 지수님, 지오리상 기옥님 이렇게 돼 있어서.
# [356.24–357.22] (spk=2) 어
# [360.32–360.71] (spk=1) 아하.
# [361.69–363.43] (spk=3) 데 어
# [365.20–368.72] (spk=5) 아니면 저 궁금한 거 있는 먼저 해도 될까요?
# [369.42–369.66] (spk=1) 네.
# [371.43–387.73] (spk=5) 네, 그 한수님이 써주신 것 중에 저도 공감을 했던 게 이제 보전의식을 불러일으키는 목표 좋다고 생각했어요. 근데 앞부분에 이제 현실적이고 달성하기 쉬운 것은 좋지 않은 목표다라고 하셨는데.
# [388.18–396.79] (spk=5) 너무 거리가 먼 목트인 경우에는 누군가한테는 아니 협업자들에게는 저게 될까 하는 의구심도 심어줄 수 있을 거 같거든요.
# [396.87–408.07] (spk=5) 그런 그렇게 갈라오면 또 오히려 약간 서로 다른 귀을 갖게 되고 막 좀 인식이 맞지 않을 때도 있을 거라고 생각하는데 그것 어떻게 생각하시는지?
# [408.16–421.44] (spk=0) 궁금합다. 네, 그래서 제가 이거를 먼저 쓴 이유가 이거를 전제로 하고 그다음이라고 생각을 해주시면 될 것 같아요. 그러니까 사실 제가 앞부분에까 앞부분도 제가 그렇게 얘기했잖아요.
# [421.52–426.94] (spk=0) 백배 달성, 이런 목표는 좋은 목표가 아니라고. 왜냐하면 근거 없이 정말 터무늬 없는.
# [427.12–428.46] (spk=6) 높은 목표는?
# [429.43–440.12] (spk=0) 그 그 목표를 설정한 리더도 이 백배 달성을 위해서 우리가 어떤 거를 할 수 있습니다. 라고 구체적인 계획을 못 세울 거예요. 왜냐면은 애당초 근거 기반으로 설정한 목표가 아니기 때문에.
# [440.52–453.46] (spk=0) 네, 그래서 저는 네, 그래서 네 지수님이 생각하시는 거에 완벽하게 네 동의를 하고요. 네, 근데 뭐 이게 사실 체감하는 거는 사람마다 다를 수는 있을 것 같긴 해요.
# [453.49–467.60] (spk=0) 뭐 아무리 근거 기반으로 해서 뭐 나는 두 배가 될 것 같애 했는데, 누군가한테는 어 나는 두 배도 안 될 것 같은데 어 약간 그 그렇기 때문에 이제 뭐 네, 뭐 그 그 뭐지?
# [1016.60–1017.28] (spk=0) 반싸이.
# [1017.96–1023.18] (spk=2) 저를 되돌아보면서 예, 반성을 하는 시간이었던 것 같습니다.
# [1030.11–1030.35] (spk=2) 네.
# [1030.85–1031.35] (spk=1) 풀리님.
# [1035.06–1051.14] (spk=3) 하 알겠습니데 의무적으로 하려고 하니까 무슨 말 해야될지 잘 모르겠는데 응, 어, 그냥 저는 지금 들으면서 뭔가 다른 의견이 있고 막 이런 거는 없구요. 다 공감이 되는 거였고.
# [1051.71–1065.48] (spk=3) 그냥 어쨌든 저도 지금 신규 프로젝트를 진행을 하면서 목표라는 게 큰 목표는 모두가 똑같이 하나. 이제 글로벌 프로젝트를 완성한다. 그 진출한다.
# [1065.51–1081.89] (spk=3) 이거는 있지만 그거를 달성하면서도 계속 세부적으로 목표가 계속 생기더라고요. 근데 이제 그것들을 내가 지금 팀원들한테 잘 공유를 했고 잘 설명을 했냐라고 하니까. 뭔가 좀 네.
# [1082.10–1094.68] (spk=3) 기수님이 얘기한 것처럼 좀 저도 뭔가 반성을 하게 되는 네, 그런 지금 좀 생각을 하고 있었어요. 음 그래서 뭐 예를 들어서 단순히 지금 저랑 저는 식이랑 일을 하고 있으니까.
# [1095.08–1105.81] (spk=3) 씨디가 저한테 뭐 이거는 이래서 이렇게 해야 됩니다라고 했을 때 그냥 그거를 그대로 전달하는 경우가 사실 좀 많았어요. 시간적 여유가 없다는 핑계로.
# [1106.34–1115.55] (spk=3) 근데 그럼에도 불구하고 그런 것조차 어 팀원들한테는 다 설명을 잘 해야겠다라는 네, 그런 생각도 좀 들고.
# [1116.30–1125.27] (spk=3) 그래서 뭐 음 네, 말이 좀 정리가 안 되는데, 그래서 아무튼 네 목표는 정말 중요하다는 거 네, 굉장히.
# [1125.27–1126.21] (spk=4) 느끼고 있고.
# [1126.52–1140.71] (spk=3) 목표가 크게 하나가 있지만, 계 뭔가 뭔가를 진행을 하면서도 계속 계속 하나씩 하나씩 추가가 될 수 있다라는 생각이 좀 들었습니다. 네, 죄송해요, 제가 지금 약간 제정신이.
# [1140.74–1143.14] (spk=1) 아니어가지고 괜찮아요, 괜찮아요지.
# [1143.20–1143.76] (spk=3) 모르겠지만.
# [1143.80–1144.84] (spk=0) 전달이 됐을까요?
# [1145.75–1162.05] (spk=1) 근데 이제 전반적인 피드백들을 보면 사실은 한슬림의 어떤 내용에 대한 것보다는 목표 자체에 대한 피드백을. 지금 좀 그 목표 자체에 대한 각자의 생각과 의견들이 지금 중심인 것 같애요.
# [1162.16–1177.62] (spk=1) 그래서 어, 그렇다면 제가 그냥 바로 저도 의견을 좀 드리자면 어, 처음에 인제 지수님이 그 딜레마 같은 이야기인 거죠. 목표가 얼만큼 근거를 토대로 하고 해야 되는가?
# [1178.10–1187.58] (spk=1) 사실 저는 그 모든 세상을 바라볼 때 그냥 정답은 없다, 그니까 늘 제가 하는 얘기인데 답은 없다라고 생각해요. 답은 없다.
# [1496.00–1506.98] (spk=1) 그니까 수도 없이 앞으로도 내 삶에서 내가 기업을 하든 뭘 하든 계속 위기는 올 것인데. 이런 위기를 극복하는 방식 자체를 경험한다는 것이 굉장히 큰 의미가 있을 거고.
# [1507.23–1519.78] (spk=1) 또 하나는 뭐냐하면 그래서 그냥 생존에서 끝나는 게 아니라 저는 이 생존 그까. 딱 칼 자르듯이 생각할 수 있는데, 저는 생존을 할려면 결국은 그냥 어, 이것만. 달성하면 생존.
# [1519.78–1527.81] (spk=1) 이때부터 생존이라고 생각하지 않거든요. 결국은 장기적으로 생존할 수 있는 모델을 만들어야만 생존해 나갈 수 있다라는 생각이에요.
# [1527.89–1534.13] (spk=1) 그래서 결국은 흑자 전환을 한다는 건 단기흡자 전환이 아니라 장기흡자 전환을 해서 우리가 지속적인 성장을 한다.
# [1534.13–1546.13] (spk=1) 지속적인 성장에 모멘텀을 만들어낸다라는 사실 기업의 근간에 가까운 일이라서 뭐 저는 그 또한 좋다라고 생각하는데, 이런 메세지들이 사실은 잘 전달이 안 되는 것 같애요.
# [1547.06–1553.11] (spk=1) 그게 어 뭐 누가 잘했다? 잘못했다를 떠나서 사실 저는 이렇게 생각하거든요.
# [1553.90–1565.16] (spk=1) 그게 대표님이 해주면 좋지, 대표님이 해주면 좋은데 대표님이 바쁠 수도 있고 대표님이 어 대표님의 커뮤니케이션 방식이 그게 아닐 수도 있고.
# [1566.01–1571.70] (spk=1) 아쉽다면 그 아쉬운 부분을 최소한 내 조직에서는 내가 채워야지. 그럼 이게 맞나?
# [1571.81–1582.19] (spk=1) 그니까 예를 들어서 의미부여가 안 돼 있고 숫자만 왔다라고 하면 의미부여가 필요하다라고 하면 어, 내가 생각하는 의미부여는 이거야. 그걸 가지고 대표님하고 한번 더 확인을 해보는 거죠.
# [1582.22–1587.36] (spk=1) 대표님, 저는 이렇게 생각해요. 이 숫자에 대한 의미는 의미부여는 이거 아닌가요? 저 이렇게 전달해도 되나요?
# [1587.51–1596.63] (spk=1) 저는 이 메세지로 전달해야 우리 같이 일하는 구성원들이 동기부여가 될 것 같아요라고 좀 생각을 하는 편이고, 그렇게 할려고 저는 좀 움직이는 편이고요.
# [1597.96–1609.05] (spk=1) 또 인제 어 서민님 얘기해서 인제 목표는 있고 방법론은 없다 해서 요것도 인제, 어떤 조직에서 어떤 방식으로 움직이느냐에 따라서도 다 다를 것 같아요.
# [1609.36–1636.58] (spk=1) 그리고 어느 단계에서 목표냐에 따라서 방법론이 구체적일수록 좋은 게 있고, 또 아닌 게 있고, 이런데 전는 오히려 어 방법을을 제시하는 것도 좋지만, 오히려 그 그 목표와 가지는 의미에 대해서 계속 강조를 하는 이유가 뭐냐면 어, 목표 자체가 어 그 목표의 방법론은 저는 계속 바뀔 수 있다고 생각이 들거든요.
# [1636.87–1648.24] (spk=1) 시도해 볼 수 있는 방향성을 제시할 수 있다고 생각을 해요. 예를 들면 자, 우리가 우리 이런 거 있잖아요. 지금 입자 전환하기 위해서 어 에이 씨 에스 디 는 일단 아.
# [1648.29–1658.75] (spk=1) 이 억이라는 숫자 최대 매출을 찍어 그렇게 되면 올해 안에 올해 흑자로 전환했다라는 시비널을 통해서. 컴퍼니 전그까 그룹사 전체 어떤 그런 메세지가 될 수 있고.
# [1658.75–1669.94] (spk=1) 우리가 일을 함에 있어서 다른 그룹사에 신뢰를 얻어서 일을 하고 전략을 하고 계획을 수립하고 인적. 운영하는 데 용이해. 근데 그 방법에서 일단 에이치 에스는 이 억을 찍어주면 좋겠어.
# [1670.16–1683.83] (spk=1) 자, 센트는 신규 모멘텀을 만들었으면 좋겠어. 자, 그다음에 뭐야? 어 에이치 엠 엘 디는 어, 이제 수익성을 개선을 했으면 좋겠어. 그리고 뭐 저라면 이런 거죠. 수익상 개선도 있고.
# [1683.99–1693.09] (spk=1) 아웃소싱을 통해서 더 많은 가치를 만들 수 있는 방법을 찾아서. 우리가 더 많은 것들을 할 수 있는 기반을 만들었으면 좋겠어요. 이렇게 되면 이 세 가지 전략대로 가는 거잖아요.
# [1693.43–1706.36] (spk=1) 세 가지 전략이 만약에 있다고 쳐봐봐요. 근데 갔는데 안 됐어. 센트가 들어갔는데 센트가 오픈을 했는데 어 생각보다 이게 어 이게 지금 반응은 반응이 안 나와. 그러면 전환 할 수 있는 거죠.
# [1706.36–1712.57] (spk=1) 자, 지금부터는 무엇을 할 거냐 하면 일단 마케팅을 중지하고 지금 들어와 있는 고객들을 분석하고.
# [1712.75–1724.55] (spk=1) 철저히 분석한 다음에 새로운 방향성을 수립하고 수립한 다음에 그 수립하고 액션을 하는데, 그 액션의 규모를 굉장히 작게 해서 가자 이렇게 갈 수도 있죠. 그럼 답을 찾을 때까지 그걸 하는 거예요.
# [1724.95–1733.06] (spk=1) 근데 답을 못 찾았어. 그럼 계속 가는 거고. 근데 어 이거 열 개 할려고 했는데 답을 너무 큰 시그널를 하나 찾은 거예요. 어, 이거 안 되겠어요? 집중해야 될 것 같애.
# [1733.06–1740.74] (spk=1) 이거 이거 이거 확신에 가까워 실험을 해봤는데 이거 확신에 가까워. 앞으로 뒤에 나와 있는 아홉 개의 계획은 지금 보류하자.
# [1741.10–1747.48] (spk=1) 그리고 이거에 대해서 가장 확대할 수 있는 방법으로 전환을 해보자라고 전환을 해볼 수가 있다고 생각을 하거든요.
# [1747.97–1755.96] (spk=1) 그리고 또 하나는 와이가 공유가 돼야 어, 이 목표가 이 목표에 맞는 집단 지정이 발생을 할 수 있을 것 같아요.
# [1756.18–1761.39] (spk=1) 어, 지금 이거 해봤더니 안 되는데 그럼 뭘로 해보지, 어, 지금 저걸 딴 쪽에서 해주고 있네.
# [1761.42–1768.77] (spk=1) 그럼 나는 뭘 해보지 라는 것들이 발생할 수 있어서 그렇지만 그렇다고 인제 방법원이 필요 없다라는 건 아니에요.
# [1768.96–1777.31] (spk=1) 제 또 조직의 상황에 따라서 예를 들어서 그 조직이 그런 것들을 고민할 여력이 없어 지금 우리는 신규 빌딩된 조직이야.
# [1777.34–1788.67] (spk=1) 그래서 막 지금은 그냥 딱 정해진 목표로 달리는 것밖에 사실 멘파워가 못해 그러면 정해져야죠. 정해지고 달려야 된다라고 좀 생각을 하고. 음, 그렇습니다.
# [1789.93–1798.36] (spk=1) 아, 그렇구요, 어, 제가 이제 그 저는 그 한슬님에 그.
# [1800.74–1813.27] (spk=1) 어, 이 정리된 거에. 그래서 보면 이제 코커네의 영업이 이제 흑자전환, 그니까 흑자 전환이 와이이긴 한데 저게 와이로 충분한가 니까. 흑자 전환을 통해서 뭘 해고 싶은 거지.
# [1813.58–1816.43] (spk=1) 흑자 전환이 우리한테는 무슨 의미가 있어 그니까 또 이런 거잖아요.
# [1816.92–1827.76] (spk=1) 예를 들면 이게 저게 텍스트로 쓰기는 어려운데, 저 흑자 전환 못하면 사실 이 이 규모의 조직을 운영하기가 어려워요라는 것들에 대해서.
# [1828.15–1837.01] (spk=1) 사실 우리한테는 당연하다라고 생각을 할 수 있지만, 그렇게 생각 안 하고 일하시는 분들도 있을 거거든요. 필요하다면 그런 메시지도 저는 전달을해야 된다라고 생각을 해요.
# [1838.10–1846.37] (spk=1) 어, 그게 인제 의미가 이제 더 들어가는 거라고 생각을 하고, 조금 다른 얘기를 하자면 조직의 역량에 대한 얘기가 거의 안 나왔어요.
# [1846.61–1857.99] (spk=1) 거의 안 나왔는데 의견 중에서는 목표에 대한 얘기만 하고 그래서 조직의 역량 역량이라고 하니까 좀 좀 포괄적인데.
# [1858.02–1867.73] (spk=1) 사실 어 지금 지금이라는 단어를 제가 왜 썼냐면 각각의 프로젝트마다 지금 필요한 역량은 다를 수 있다 라고 저는 생각을 해요.
# [1867.92–1876.85] (spk=1) 뭐냐면 자, 이 지금 얘기한 것들을 시뮬레이션 해보면 일단 기본적으로 목표가 있죠. 이제 목표가 수립이 돼야 되죠, 그죠. 목표가 수립이 됐어요.
# [1877.03–1886.62] (spk=1) 근데 그 목표가 공감대를 형성하고 전달이 되고 동기부여하기에 충분한 의미부여가 와이가 있는가 라는 생각을 해볼 수 있어요. 그럼 와이도 채워야 되는 거죠.
# [1887.14–1893.35] (spk=1) 그럼 이건 목표 영역이니까 자, 목표가 수립이 됐어. 그럼 이 목표를 시행하는 전략을 수립해야 되겠죠.
# [1893.81–1904.91] (spk=1) 전략, 그러니까 예를 들면 우리 그룹사 전체는 글로벌에서 어 에이비유 를 통해서 새로운 고객 가치를 만들어낸다. 그 구체적인 숫자가 일 억 기율을 목표로 달린다. 전략은 뭐야?
# [1905.27–1912.97] (spk=1) 어, 원이라는 그니까. 이 그룹사 전체가 하나의 조직으로 움직인다. 지금까지와는 다르게 하나의 방향성을 찔러본다라는 거예요.
# [1913.25–1925.22] (spk=1) 그래서 퍼블리싱과 어 매니지먼트의 큰 그림은 어 원에서 원과 어 퍼블리셔어인 에프인가요, 피인가요? 아, 피 피가 하는 거고.
# [1925.48–1933.92] (spk=1) 각각의 티 브이, 엠은 각각의 개발사와 같은 역할로 각각의 각각의 개발들을 한다. 이 이 체계로 진행을 하는 거예요.
# [2088.18–2105.69] (spk=5) 네, 저 도 목표의 역할은 방향을 제시하고 집중하게 하는 역할이라고 생각했고, 목표는 누가 수립할까 했을 때 좀 두 개로 나눴어요. 먼저 이제 가장 상위에서 조직의 목표는 사업부랑 식팀이다.
# [2105.69–2115.71] (spk=5) 혹은 기획팀이 수립해야 된다고 생각을 했고. 이제 사업부 같은 경우에 당연히 이제 상업적인 견해 가장 있으신 분들로 이루져 있으니까 그게 맞다고 생각하는데.
# [2115.74–2127.74] (spk=5) 거기에서 이어서 세팅 리더나 기획팀 같은 경우에는 그 창업부가 가고자 하는 방향의 가장 비밀하게 연결된 팀이라고 생각했고, 이제 그 현재 상황을 인식하고.
# [2127.82–2134.34] (spk=5) 방향성을 제시할 수 있는 사람들이 모여있는 집단이니까 같이 하면 좋겠다라는 생각이 들었어요.
# [2134.78–2146.68] (spk=5) 그리고 이제 각자의 업무 목표 같은 경우에는 이제 조직에서 내려온 목표를 기반으로 구성원 개인이 설정할 수 있는 시간을 줘야 된다고 생각했고, 이제 목표가 큰 목표가 정해졌으니까.
# [2146.74–2160.42] (spk=5) 세부적으로 구체적으로 나는 이 여기서 어떻게 이걸 달성할지 방법적인 측면을 리더들도 같이 생각하게 하는 뭔가 큰 틀을 잡아주는. 역할을 해주면 좋겠다라고 생각을 했습니다.
# [2160.93–2175.81] (spk=5) 목표는 아주 중요하다고 생각하고요. 다만 이제 뭔가 가다 보니 방향이 이게 아닌 것 같다라는 판단이 들었을 때 빠로 빠르게 융통성 있게 움직여야 된다고 생각을 합니다.
# [2176.46–2188.49] (spk=5) 그런 목표는 저는 좀 그냥 뭐야 되죠? 너무 베이직하게 접었는데 당연히 맞아야 되고 구체적이고 특정 가능하다. 그래서 성 달성 가능해야 된다고 생각했어요.
# [2188.49–2200.23] (spk=5) 저는 오히려, 그리고 이제 당연히 기장이 있어서 이 안에 달성하겠다고. 이렇게 정하면 어 뭐가 됐든 그래도 뭔가 다들 공감해주는 목표가 되지 않을까라고 생각했습니다.
# [2201.02–2203.03] (spk=5) 우리 조직의 목표는 저는 에이티에스.
# [2203.14–2204.14] (spk=6) 생각하고 썼는데.
# [2204.74–2216.77] (spk=5) 괜찮다고 생각했고요. 이제 숫자도 구체적이고 측정 가능하고 맨날 달성하면 되니까 그렇게 생각했습니다. 그래서 왜 이 억이지 했을 때 저번에 실장님도 좀 너 왜 이 억이야?
# [2216.82–2229.92] (spk=5) 약간 이런 얘기를 하시긴 했는데. 저는 그냥 그 첫 이역 달성이 그런 상징성을 갖고 있다고 생각하고. 그 달성했을 때 오느 개대인별로의 성취감이 있을 것 같아요. 그리고 또 해로 목을 잡을 때.
# [2230.46–2236.22] (spk=5) 만약에 달성했다면 이제 우리 이렇게 했으니까 더 높여질 수 있어라든지 뭐 그런 근거로 삼을 수 있을 거고.
# [2236.70–2243.13] (spk=5) 다만 좀 아쉬웠던 건 이 팀원들이 과목에 되게 많이 나왔지만 누군가 납득하지 못할 수 있잖아요.
# [2243.20–2258.22] (spk=5) 그래서 이 사람들도 진심으로 움직이게 하려면 이협 달성을 위한 이유도 같이 나왔으면좋 좀 더 공감하지 않을까 생각했어요. 예를 들어서 우리가 이 억, 지금 뭐 일 억 육천을 달성하고 있는데.
# [2258.41–2265.61] (spk=5) 여기서 사천을 더 하게 되면 흑자가 아 이익이 얼만큼 늘어들고, 그래서 흑자 전원을 이만큼 기한다.
# [2265.61–2273.96] (spk=5) 뭐 이런 식으로라도 설명이 붙으면 아, 내가 그럼 이 안건에서 얼마를 더 걸려되겠다 하고 달려가지 않을까 하는 생각이 들었습니다.
# [2274.40–2287.46] (spk=5) 그리고 지금 조직의 목표를 달성하는 데 가장 필요한 영량은 어 네, 그 조직 기획팀의 기획팀이 목표가 이제 밀접하게 연결될 수 있도록 의사결정하는 것.
# [2287.63–2299.93] (spk=5) 우선순위 빠르게 판단해서 쳐내는 역량이 필요하다고 생각했고요. 이제 그 목표랑 동계되지 않은 분들의 마음을 움직일 수 있도록 그 교집파을 빨리 찾아서 설득하는 역량이 제일 필요하지 않을까.
# [2300.13–2302.18] (spk=5) 뒤에피인 관점에서 적어봤습니다.
# [2303.91–2304.67] (spk=4) 어국이다.
# [2311.58–2324.13] (spk=0) 뭔가 제가 느꼈을 때는 뭔가 지수님의 대부분의 그 이 적어주신 거는 뭔가 지수님이 생각하는 목표보다 더 뭔가 정해져 있는 그까.
# [2324.13–2340.95] (spk=0) 절대적인 상위 목표가 있는 상태에서 그 하위 목표에 대해서 쓴 듯한 느낌이 좀 들었어요. 뭔가. 그래서 뭐 아까 뭐 조직이 추구하는 방향과 맞아야 되고 그니까 모든 거는 이 전제하에 그래서 뭐 달성.
# [2340.95–2347.77] (spk=0) 가능하고 막 약간 이렇게 써주신 건가라는 생각이 드네요. 음 그 그런 거 맞나요? 기술님.
# [2349.56–2360.27] (spk=5) 어, 어딜 봐든 더상위는 있는 거잖아요. 제가 대표가 아닌 이상 그 조직의 큰 조직의 목표가 있을 거고, 그거에 따라서 그 조직이 추구하는 방향을 맞추는 거고.
# [2360.46–2369.91] (spk=5) 조직의 정의가 어디냐에 따라 다를 거거요. 물론 제가 좀 더 이제 기획 파트라는 치후단계 있다 보니까 그런게 할 수 있을 거 같아요. 응응, 그.
# [2371.63–2384.32] (spk=0) 그런 부분이 그니까 뭔가 틀렸다 이런 게 아니라 아, 뭔가 제가 생각하는 이 답변을 써야지 할 때 생각했던 관점이랑 어 되게 다른 것 같다 해서 뭔가 되게 오히려 또 좋았어요.
# [2385.71–2399.10] (spk=0) 왜냐면은 또 뭐 이제 여기에 계신 분들은 막 이제 뭐 사업부 리더 뭐 정말 신규 프로젝트 리더 막 이런 분들이다. 보니까 정말 거기서 현장에서 실망하면서 움직이는 이제 뭐 중간 리더분들이라든지.
# [2399.14–2408.62] (spk=0) 파트장분들의 관점이 이제 또 알아야 되는 포인트도 있는 것 같아서 지수님 통해서 네 들을 수 있어서 되게 좋은 것 같습니다.
# [2412.54–2414.64] (spk=1) 네, 다른 분들.
# [2415.57–2416.14] (spk=4) 네.
# [2417.31–2417.74] (spk=1) 어
# [2421.59–2422.45] (spk=0) 어, 그.
# [2424.57–2425.65] (spk=5) 오 다시 에이 다시.
# [2426.77–2427.33] (spk=4) 오 다시.
# [2431.75–2443.84] (spk=4) 네, 제가 최근에 굉장히 어쨌든 지수님은 저랑 같이 이제 딩을 구성해주고 계시는 분이시니까. 아, 이걸 제가 좀 제가 최근에 가장 많이 고민하는 포인트이기도 해요.
# [2443.98–2458.52] (spk=4) 어, 이걸 어떻게 팀원분들께 왜 우리가 이걸 해야 되고 하는 것들을 가장 잘 전달할 수 있을까 하는 것들을 되게. 요즘에 많이 고민을 하고 제가 잘 못하고 있다는 사각도 좀 있고.
# [2460.03–2461.06] (spk=1) 그런 생각이 들어서.
# [2462.02–2468.35] (spk=4) 약간 어 뼈의 없신 것 같은 느낌이었고요. 감사하고요.
# [2472.24–2473.79] (spk=1) 아니, 당연히 알죠, 알죠?
# [2474.32–2476.02] (spk=4) 그 아죠, 네.
# [2476.87–2477.11] (spk=1) 그리고.
# [2477.90–2478.24] (spk=5) 어
# [2478.77–2479.42] (spk=4) 약간.
# [2479.85–2481.54] (spk=0) 음.
# [2482.00–2486.99] (spk=4) 얼마 전에 엊그제트가 면접을 한 분 봤는데 그분이.
# [2487.44–2488.63] (spk=5) 회사에 어떤 걸
# [2488.63–2501.44] (spk=4) 원하냐, 그니까 자기가 이제 일을 하는 회사에서 어떤 것들이 좀 이렇게 그 갖춰져 있으면 좋겠냐. 뭐 시설적인 거라든지 아니면 사의 뭐 방향성 이하는 방법.
# [2501.44–2514.48] (spk=4) 그런 것들 다 포함해서 였는데 그분 답변 중의 하나가 정보가 되게 투명하게 공개됐으면 좋겠다는 말씀을 하셨어요. 그래서 저는 그 대답을 조금 약간 놀랐거든요.
# [2514.55–2518.25] (spk=4) 그 놀랐다는 그 포인트가 왜 놀란 건지 설명하기가 되게 어려운데.
# [2518.63–2519.15] (spk=5) 어
# [2520.15–2524.67] (spk=4) 일단 최근에 제가 그 제가 있는 상황.
# [2524.92–2525.56] (spk=3) 속에서.
# [2526.40–2529.04] (spk=0) 어 뭐라 뭐라고 하면.
# [2529.04–2529.60] (spk=4) 좋을까요?
# [2529.92–2530.55] (spk=0) 그.
# [2532.60–2543.01] (spk=4) 제가 저에게 입숙된 모든 것들이 다 제가 저희 팀원분들한테 전달하지 못하는 상황도 분명히 있었고. 음, 그런데 그거를 아, 그렇네.
# [2543.04–2548.40] (spk=4) 이게 정말 단순히 정말 현악에 계신 그 팀원분들 뭐 정말 중간이더분들.
# [2548.40–2557.16] (spk=4) 레벨에서는 그게 전달이 안 된 상태에서 그냥 약간 어쩌면 공압적으로 이렇게 우리가 지금 해야 되니까 이렇게 하자라는 방향이.
# [2557.48–2569.16] (spk=4) 지금 저는 그게 맞다고 생각해서 약간 그런 식으로 움직이기도 했었던 부분이 없지 않아 있거든요. 근데 그까 제가 생각했던 그 이게 맞다, 지금 상황에선 이게 맞다라고 생각했던 거랑.
# [2569.72–2573.00] (spk=4) 근데 그럼에도 불구하고 그렇지 않을 수도 있겠구나라는 거를.
# [2573.20–2584.08] (spk=4) 이게 좀 약간 그때도 되게 이렇게 약간 깨우치 느낌이 들어서 그 답변을 지금 몰랐었는데, 네, 그 그 비슷한 문양인 것 같애요, 어, 그래서.
# [2584.08–2584.76] (spk=5) 이거를.
# [2584.79–2598.59] (spk=4) 어떻게 잘 전달하고 공감제를 형성할 수 있을까 하는 거를 뭐 어떻게 취득할 수 있을까요? 연습 연습 연습일 거고. 네, 그 그런 생각이 좀 많이 들었습니다. 음 네.
# [2600.86–2601.12] (spk=0) 네.
# [2601.70–2603.94] (spk=4) 이는 하지기만 네, 거장입니다.
# [2605.74–2606.86] (spk=6) 어려운 것 같아요.
# [2607.52–2620.38] (spk=0) 리더는 너무 외롭고 불안함을 초출하면 안 되는데 설득근 해야 되고 뭔가 조급한 모습을 보이면 안 될 것만 같고. 근데 조급한데 어떡하지 막 이러.
# [2622.43–2623.47] (spk=0) 이런 생각을 드는?
# [2625.25–2625.61] (spk=1) 미도.
# [2626.21–2640.48] (spk=3) 약간 얘기 듣다 보니까 저도 좀 많이 신경쓸. 예전에는 막 신경을 쓴다는 느낌은 아니었는데, 그까 뭐랄까 무슨 일이 닥쳤을 때 저는 되게 침착한 편이거든요.
# [2640.59–2648.00] (spk=3) 사실 제 성격상, 그래서 뭔가 갑자기 목 회사의 목표가 바뀌었다 했을 때 그렇게 저한테 타격감이 없기는.
# [2648.00–2648.51] (spk=4) 해요.
# [2649.12–2659.99] (spk=3) 그래서 항상 조급함도 없었고, 뭔가 불안함도 없었고. 그래서 그게 팀원들한테 표시가 많이 안 났던 것 같은데 이게 되게 중요한 거긴 한 같더라고요.
# [2660.15–2672.08] (spk=3) 요번에 저희 신규 프로젝트를 하면서 약간 팀원분들한테 피드백을 받 이번 운논을 해보면서 느끼는 거는 그 제가 되게 막 불안함이라던가. 막 힘들다는.
# [2672.27–2672.53] (spk=5) 그런.
# [2672.53–2684.27] (spk=3) 표현을 많이 안 하는데 그게 오히려 이분들한텐 되게 많이 도움이 됐다라는 이야기를 좀 많이 들었어요. 네, 물론 막 직접적으로 프리님이 불안해하지 않아서 다행이에요.
# [2684.27–2691.86] (spk=3) 이렇게 하는 게 아니라 뭔가 어플레이님이 그렇게 생각한다고 하니까 어, 저도 안심이 돼요. 이런 피드백을 되게 많이 받았거든요.
# [2692.68–2706.31] (spk=3) 아, 그래서 뭔가 네, 뭔가 이 맥락과 맞는진 모르겠으나 어쨌든 뭔가 리더는 확실히 그런 자세가 좀 많이 필요하고 되게 중요하구나라는 거를 좀 요새 많이 깨닫고 있는 것 같애요.
# [2706.31–2711.46] (spk=3) 음, 그래서 물론 저도 사람인지라, 그 시디와 일을 할 때 이제.
# [2711.55–2712.83] (spk=5) 번쩍번쩍 이제 그런.
# [2713.12–2722.33] (spk=3) 마음이 들 때가 요즘엔 조금 있는데. 네, 그럴 때마다 조금 더 신경써서 팀원들이랑 커뮤니케이션 할려고 많이 노력을 하고 있 있는 거 같애요.
# [2722.49–2723.68] (spk=5) 음 네.
# [2724.91–2727.64] (spk=3) 이렇게 그냥 막 생각의 흐름을 막 얘기해도.
# [2727.64–2728.95] (spk=1) 되는 거죠? 네, 됩니다.
# [2729.51–2732.57] (spk=5) 네, 기옥 기옥님.
# [2734.15–2748.11] (spk=2) 그 리더 혼자는 절대 무린 것 같고, 리더를 서포트해주는 이제 사람들이 꼭 이제 많으면 많을수록 좋을 것 같다는 생각을.
# [2748.15–2748.43] (spk=1) 요즘.
# [2748.43–2748.72] (spk=2) 들어서.
# [2748.72–2749.19] (spk=1) 많이.
# [2749.83–2753.30] (spk=2) 느끼고 있고요. 더금 큰 조직일수록 네.
# [2757.32–2759.37] (spk=1) 다시 생각나서 또 말씀드렸서.
# [2759.37–2761.39] (spk=2) 알았다 까먹었네, 네.
# [2762.40–2767.08] (spk=6) 어, 그럼 저는 이젠 맨 마지막에 육 다시.
# [2767.08–2769.53] (spk=5) 이 육사시 부분에서.
# [2770.15–2776.63] (spk=6) 어, 백 번 공감을 하고 이제 목표 같은 거는 뭐 이렇게 얘기를 해도 공감을 못하는 사람.
# [2777.10–2777.57] (spk=1) 정말.
# [2777.62–2784.30] (spk=6) 많겠죠? 어, 이거 내가 왜 해야돼 뭐 이단 내가 밥벌이가 안돼 해야지 하면서 하시는 분들도 많을 텐데 이거를.
# [2784.30–2799.63] (spk=6) 이제 대수님 생각에는 마음을 움직일 수 있도록 뭔가 이 액션을 한다고 하는 게 뭔가 구체적으로 뭔가 생각하시는 게 있나요? 아무래도 이제 피엠 역량으로 쓰신 거 같아가지고.
# [2801.30–2815.22] (spk=5) 저는 일단 사람 성형을 보고 하긴 하는데요. 좀 성과에 따라 움직이시는 분들은 좀 웃기긴 하지만 이거 매출 이만큼 뭐.
# [2815.22–2821.95] (spk=5) 예를 들어 삼천 만 에 버는 콘텐츠인데, 어느 매출 콘텐츠보다 굉장히 높은 목표다.
# [2822.52–2823.20] (spk=1) 말씀하면.
# [2823.72–2825.14] (spk=5) 우리 매달 산양.
# [2827.64–2836.92] (spk=5) 하면서 이제 좀 그런 식으로 풀어나가거나 아니면 걱정이 많으신 분들은 좀 더 이제 어떤 게 걱정되는지 물어보면 분명히 다 해소할 수 있는 걱점들이거든요.
# [2837.26–2843.16] (spk=5) 그래서 그런 것들 풀어주는 형식으로 사랑, 바인, 사랑으로 움직이고 잖아요.
# [2843.96–2844.86] (spk=4) 응 아.
# [2845.64–2860.20] (spk=1) 응, 전 그 지수님 글 중에서. 또 또 인제 조직의 역량에 대한 부분인데 지금 상황이 좀 다를 것 같아요.
# [2860.33–2869.09] (spk=1) 이제 그 컴퍼니 차원에서와 또 인제 기획팀과 서비스팀, 각자 좀 다른 다른 정체성을 가지고 있기 때문에 다를 것 같은데.
# [2871.11–2888.17] (spk=1) 저는 어 기획 팀이기 때문에 우선 어 기획을 잘 해야 되지 않나라는 생각이 들었어요. 그래서 이제 기획 역량 자체에 대한 이야기는 어 좀 없는 것 같애서.
# [2888.24–2901.57] (spk=1) 그니까 이제 일단 이거 흐름이 목표 때 목표에 대한 흐름이어서 그럴 수도 있는데, 어, 그까. 사실 의사결정을 잘하면 그니까 결국 기획을 잘한다는 거는 성과가 나는 기획을 한다라는 거잖아요.
# [2901.80–2915.36] (spk=1) 성과가 나는 기획을 하기 위해서 그러면 뭘 잘해야 되나라는 고민이 기획팀 자체에 필요하지 않을까. 음 예를 들어서 의사 의사결정을 잘하고 우선순위 판단을 잘하면 성과가 나나.
# [2916.12–2921.96] (spk=1) 어, 그니까 협업자들하고 마음을 움직여고 교집합을 찾아내는 거는 성과를 낼 수 있겠죠. 왜냐.
# [2922.18–2938.45] (spk=1) 뭐 속도를 빠르게 한다거나 퀄리티를 나오게 한다거나 아니면은 뭐 이게 어 뭐 원활하게 진행을 해서 뭐 시간을 확보한다던가 있지만, 근본적으로 그럼 기획을 잘한다는 건 뭐지, 그니까 성과를 내는 기획이라는 건 뭐지?
# [2938.45–2947.32] (spk=1) 성과를 내는 기획을 할려면 어디에 집중해야 되는 거지, 우리의 역량은 어디로 계속 강화해야 되는 거지? 지금 우리는 이제 리더로서의 이제 리더집 역량을 강화하고 있는 거잖아요.
# [2947.66–2961.26] (spk=1) 근데 그럼 기획팀을 이끄는 기획 리더로스는 기획자들의 역량을, 기획자들의 역량은 어, 어느 방향으로 강화가 돼야 되는 걸까 라는 고민이 좀 필요하지 않을까 싶었어요.
# [2961.71–2976.11] (spk=1) 제 어, 그런 생각들을 좀 해보시면 좋지 않을까 어 싶습니다. 개인적으로는 기옥님은 생각이 다시 안 나요. 아니면 안 난 걸로 아, 네네.
# [2978.59–2987.39] (spk=1) 아, 안 난 걸로 아, 예, 예, 알겠습니다. 그러면 음 시오리삼걸로 넘어가볼까요?
# [2988.15–3004.32] (spk=6) 네, 네, 저는 일단 목표의 역할은 네 무엇인가 했을 때 일단 내가 뭘 해야 될지. 이 목적을 달성하기 위해서의 길를 약간 명확하게 해주는 그런 방법이라고 생각을 했고요.
# [3004.76–3019.77] (spk=6) 그리고 일단 국제적으로 무엇을 하고 뭐 얼만큼 뭐 해야 되고 얼마나 걸리거든. 이 소스를 이 파악을 하는데, 이 또 필요한 그런 거를 이제 빠르게 수립하기 위해서 하는 것이라고 생각을 했습니다.
# [3020.43–3031.43] (spk=6) 그리고 이제 목뼈은 누가 하냐 했을 때는 아무래도 이 되게 높은 이 조직을 운영하시는 분들이라든지.
# [3031.50–3042.50] (spk=6) 저는 조금 최대하게 생각을 했을 때는 이제 컴퍼니장이라든지 팀장, 파트장 같은 무슨 장, 이렇게 보는 사람들, 이런 단위를 이끄는 사람들이라고 생각을 했어요.
# [3043.43–3056.21] (spk=6) 그리고 이제 코코네 그룹이라고 하면은 뭐 회자님이 하시거나 엠이면 대표님이 하시고 엠 에이디 면은 기원님이 하시고. 서비스 팀이면 제가 하고 뭐 그 음연팀이면 뭐 책하고 막 그런 식일 것 같아요.
# [3056.40–3064.23] (spk=6) 그리고 네, 왜라고 생각을 했을 때는 일단 여러 한 명. 저희가 혼자서 일을 할 때도 목표가 어느 정도 필요할 것 같은데.
# [3064.28–3080.24] (spk=6) 여러 한 명이면은 더욱더 이제 어 중심이 되는 이 뭐 골이라고 하면 이제 목적지 같은 게 있어야 이제 어. 네, 우리는 여기로 가야 해라고 생각을 해서 움직일 수 있다고 생각을 했고요. 그리고 일단.
# [3081.22–3081.61] (spk=1) 어
# [3082.61–3092.18] (spk=6) 그 목표를 일단 팀 전체적으로 파악을 하고. 어, 이 사람에게 결정하고 이 방향을 제시하는 사람이 있어야 이제 뭔가?
# [3092.21–3101.42] (spk=6) 아, 이 사람은 나는 따라가면 되는구나 해야 이렇게 각각으로 이제 가면 안 되잖아요. 그래서 일단 한 명 네 세워가지고 이 사람한테 다 같이 간다.
# [3101.66–3112.03] (spk=6) 네라는 느낌을 이제 약간 그림적으로 저는 상상을 했던 것 같애요. 그리고 이제 세 번째로 목표는 네 중요서로 저는 표시를 해 봤어요.
# [3112.14–3117.24] (spk=6) 별로 네 표시를 해봤는데, 매우 중요한 다섯 개, 그리고 다섯 개를 네 했습니다.
# [3117.28–3128.02] (spk=6) 왜 왜 이렇게 중요한가 했으시 까 어, 아까는 약간 좀 반복되는 이야기기는 한데, 목적지가 있으면은 일단 거기까지. 내가 어떻게 가면 되고.
# [3128.05–3135.53] (spk=6) 뭐 구체적으로 뭐 얼만큼 걸리고 뭐 반보 뭐 배 타고 가냐, 자전거 타고 가냐 뭐 너무 머니까 차 타고 가냐.
# [3135.53–3142.84] (spk=6) 막 이런 식으로 계획을 세울 수 있을 것 같아서 일단 효율적으로 네 행동을 할 수 있다고 생각을 했어요.
# [3142.99–3155.13] (spk=6) 근데 이 혈율이라는 게 일단 어 실패를 하면 비혈율이고 이런 게 아니라 어 이렇게 하면 갈 수 있고 뭐 없고 이런 거를 판단을 할 수 있는 그런 효율이라고 보시면 좋을 것 같습니다.
# [3155.64–3157.47] (spk=6) 그리고 이제 얼만큼 중요한가?
# [3157.70–3172.47] (spk=6) 저는 약간 이 문장이 이렇게 하나씩 대답하는 스타일이어가지고 하나씩 생각을 했을 때 얼마나 중요한가 했을 때는 일단 어 개개인의 모티베이션에 저는 크게 자유를 한다고 생각을 해요.
# [3172.66–3185.05] (spk=6) 그냥 자, 이제 뭐 유아이 작업해주세요. 해서 그냥 아, 뭐 이건 공지 써야지 해서 작업하는 거라. 아, 이걸 어떻게든 사람들이 이 보기 쉽게 아니면 이제 좀 더 화려하게 보고.
# [3185.47–3186.10] (spk=5) 어
# [3186.62–3198.63] (spk=6) 뭔가 이 가차를 더 구매할 수 있게 한다든지, 뭔가 이런 뭘까? 그냥 주어진 일을 하는 게 아니라 이거를 위해 나는 이거를 이만큼 해야 한다라는 걸 스스로 이렇게 느낄 수 있는.
# [3199.05–3207.07] (spk=6) 그런 게 목표라면은 이제 오티베이션까지 네 연결이 된다고 생각을 해서 되게 굉장히 중요한 부분이라고 생각을 했습니다.
# [3348.53–3362.22] (spk=6) 이게 명확해야 될 거고, 그리고 일단 가설 같은 것도 어, 뭔가 뭐지 이 가설도 되게 많이 애매했던 거 같고. 그래서 이걸로 뭐가 되는 건지 이런 게 좀 많이 부족했던 거 같아서.
# [3362.66–3370.82] (spk=6) 네, 이거는 저도 네, 아직은 다시 못 고치고 있어가지고 네 고쳐서 생각을 하고 있습니다. 그리고 이제.
# [3373.01–3381.23] (spk=6) 네, 그리고 이제 제가 목표란 목적이란 단어를 되게 많이 헷갈리게 쓰고 있었던 것 같기는 해요.
# [3381.63–3394.05] (spk=6) 네, 당연히 어느 정도는 이해를 하고 있는데 정확히 목쿄인지 이건 목적인지 이런 걸 다 이렇게 생각을 하다가. 네, 어제 약간 검색하면서도 약간 멘붕이 빠지고 그랬는데 이따 이제.
# [3396.02–3396.53] (spk=1) 이.
# [3397.21–3408.30] (spk=6) 뭐 매출이라든지 이런 거에 대해서 아, 우리 그렇게 해야 해라고 했을 때 이제 사실 뭔가 약간 와닿지 않는 부분도 조금 네 있는 것 같애요.
# [3408.42–3418.92] (spk=6) 아까 지수님도 비단네 이야기를 마지막에 해주시긴 했는데, 이에약간 공감이 좀 더 될 수 있게 해야 되지 않을까라는 생각을 하고 있습니다. 네, 그리고 네.
# [3418.92–3429.47] (spk=6) 마지막으로 우리가 필요한 이유는 제 십이 빠졌는데 리더십 입니다. 침내에서 리더십이 좀 많이 네 빠지는 거 같아요.
# [3429.47–3439.59] (spk=6) 약간 팀에서 우리 뭐 뭐 운연 팀을 이걸로 뭐 이번 이번 달에 뭐 어떻게 하자, 뭐 유알이 팀뭐 뭐 어떻게 하자 이렇진 않는 것 같애요.
# [3440.23–3450.42] (spk=6) 네, 그래서 이런 부분에서도 이 뭐 갑자기 유아이 팀에서 아, 우리 이렇트 전화 하자 해서만 했을 때 사실 뭘 해야 될지 아마 모르시는 것 같고.
# [3451.03–3456.11] (spk=6) 그리고 또 이제 이런 부분에서도 내가 뭔가 기여할 수 있는 게 좀 애매할 수 있어요.
# [3456.11–3463.99] (spk=6) 왜냐하면 저희 같은 경우에는 어 선품체작님이라는 그 그림, 그리고 이거를 직접 판매를 하시는 분들이 계시다 보니까.
# [3464.32–3470.05] (spk=6) 내가 할 수 있는이 뭔지 모를 것 같다라는 생각도 이야기를 하면서도 많이 느꼈던 것 같아요.
# [3470.71–3481.49] (spk=6) 뭔가 이제 삼성체자팀이 아니어도 아이템을 만드는 분들이 아니어도 뭔가 이 동기부여가 되는 부분이 많이 좀 부족한 것 같아가지고.
# [3481.51–3494.27] (spk=6) 이더맨 그런 카트산도 그렇고 뭐 저 같은 우 서비스 팀장도 그렇고. 좀 더 이 사람들한테 동기부여를 할 수 있는 네 부분이 이제 가장 필요하면서도 가장 부족한 부분이라고 생각을 했어요.
# [3500.27–3505.97] (spk=0) 오 번에서 시 월 이상이 세웠 세운 목표라는 게 지난번에 쓰신 거 말씀하시.
# [3506.07–3517.67] (spk=6) 네, 맞아요. 매출을 이제 그렇게 올리는 거랑, 그리고 이제 팀베이하 팀베이딩 하는 거랑 하는데, 약간 팀베이팅 같은 것도 이제 아, 저희 뭐 이렇게 확게해요.
# [3519.16–3531.05] (spk=6) 어 어 이런 느낌인 것 같고 이래서 뭔가가 이렇게 달라졌다라는 거를 확 그냥 네. 가시적으로 볼 수 있는 부분이 필요하다. 인 거 같애요.
# [3533.49–3541.83] (spk=0) 그리고 저도 사실 목적이란 목표를 좀 그 의미를 구분하고 쓰는 거에 대해서 저도 어제 한번 검색했었거든요. 목표랑 목표에 뭐가 다르지?
# [3542.09–3554.36] (spk=0) 근데 제가 이해한 바로는 아까 시오리상이 예시로 들어주신 것처럼 뭐 예를 들어 건강해진다. 약간 이런 게 저는 좀 약간 목적 같은 거라고 느꼈어요.
# [3554.39–3558.82] (spk=0) 그래서 건강해지려면 이제 뭐 사람마다 다르겠지만 누군가는 아.
# [3558.82–3570.99] (spk=0) 체중 감소라는 목표가 생길 수도 있고, 아니면 누구는 근력 증진이라는 목표가 생길 수도 있고, 약간 목표는 좀 네, 고체적인 네, 그런 거 아닐까? 약간 이런 생각도 들어요.
# [3575.40–3578.79] (spk=1) 그 저는 그.
# [3580.04–3583.74] (spk=2) 이 번 목표를는 누가 수립하는 것인가?
# [3584.45–3584.89] (spk=1) 저는.
# [3585.43–3587.63] (spk=2) 어 목적을 달성하고자.
# [3587.63–3588.57] (spk=1) 하는 자.
# [3589.91–3604.93] (spk=2) 라고 생각했거든요. 뭐. 컴퍼니, 팀, 파트 등 단위에서 이끄는 자만이 목표를 수립하는 건 아니라고 저는 생각을 했어요. 어 뭐 네, 저는 그렇게 생각했고 목표란 게 큰 목표 아래 뭐 아래.
# [3604.97–3618.67] (spk=2) 조직별로 큰 목표를 달성하기 위해서 작은 목표들이 되게 많이 있다고 생각 해서. 그렇다면 이제 개인도 각자 다 목표가 있어야 세워야 되고 한다고 생각해서.
# [3618.99–3631.92] (spk=2) 뭐 예를 들면은 뭐 엠 엘 디 뭐 수익성 뭐 엠, 엘 디. 흑자 전환이라는 목표가 있으면 고 고 밑에 수익성 개선하기. 위해서 뭐 케이아이 엔 정비하고 뭐 조정기 빌딩하고.
# [3632.57–3632.95] (spk=1) 뭐.
# [3633.64–3643.97] (spk=2) 상하이 아웃소싱한다. 뭐 이런 목표들이 있으면 그 뭐 상하이 아웃소싱이라는 목표에 개인은 뭐 상하에서 뭐 출장 기간 중에 어디까지 교육을 해서 뭐 언제까지 가찰를 내게 한다.
# [3644.00–3653.14] (spk=2) 요런 목표, 세부적인 목표들이 있기 때문에 다 모두가 다 목표는 예, 세워야 된다라고 예 생각을 저는 했습니다.
# [3654.74–3667.36] (spk=6) 아, 개개인의 그런 목표도 있고, 아무래도 그 조직 약간 뭐랄까. 포 포더 같은 느낌, 뭔가 이렇게 어 큐이 있고 이렇게 알갱니는 다 같이 그냥 각자 생각하는 네.
# [3669.30–3676.74] (spk=2) 어, 그 목표에 이제 언라인 되는 게 가장 중요하지 않나라고 생각을 했습니다.
# [3685.18–3687.23] (spk=3) 음 어, 네, 저도.
# [3688.44–3689.51] (spk=1) 어 네, 어
# [3690.88–3704.68] (spk=3) 네, 저도 되게 공감이 되네요. 그 음 목적을 달성하 하고자 하는 사람. 리더뿐만 아니라 모든 사람이 다 네 출입을 해야 된다는 게 되게 공감이 많이 되는 되는 게.
# [3705.62–3713.06] (spk=3) 어쨌든 저도 리더로서 팀원들 집주인한테 목 목표 네 목표 어 막 갑자기 그 단어가 어렵네요.
# [3713.36–3730.17] (spk=3) 목표를 네 세워서 주기는 하지만 제가 주면서도 동시에 그거를 이제 수립을 아, 그거를 이제 달성을 하려고 하는 그 팀원들. 개개인도 스스로 본인의 목표를 세울 줄 알아야 하고.
# [3730.49–3745.89] (spk=3) 그거를 세워 일 차로 세워서 리더랑 같이 상의해서 좀 더 명확하게 정하는 네 것도 되게 중요하다라는 게. 네, 저도 어렴풋이 그거를 생각하고 있었는데. 지금 얘기를 하면서 더 뚜렷해진 것 같애요.
# [3745.89–3758.10] (spk=3) 음 음, 그래야 좀 더 팀원들도, 결국 팀원들도 결국에는 주체적으로 스스로 세울 줄 알아야 한다. 네, 그러면은 리더도 좀 더 힘이 되는 것 같고.
# [3758.86–3765.78] (spk=3) 네, 더 목표를 달성하는 데에 좀 더 빠르게 갈 수 있는 네, 그런 그림이 되는 것 같네요.
# [3766.84–3767.10] (spk=1) 응.
# [3778.53–3784.05] (spk=1) 다 다 아니잖아, 다음 분 다 데요.
# [3786.98–3787.94] (spk=1) 어
# [3791.61–3791.76] (spk=1) 그.
# [3794.53–3797.05] (spk=4) 좀 그 뭐랄까.
# [3799.05–3802.58] (spk=4) 얘기하는 그 레벨이 다른 얘기일 수도 있는데.
# [3805.20–3805.47] (spk=1) 어
# [3807.87–3823.98] (spk=4) 제 이전 직장원 같은 경우에는 그 반기로 나눠서 반기별로 개인의 목표를 다 세우게 했었어요. 응, 아, 근데 그게 되게 그냥 무턱 빼고 자기 목표 세워 이게 아니었고, 아, 뭐.
# [3823.98–3836.76] (spk=4) 물론 저희랑 이제 업체도 다르고 이제 그 다루는 상대도 달랐기 때문에 그게 똑같이 적용될 수는 없다고 생각하지만, 우리는 올해 이만큼을 할 거야.
# [3836.81–3846.33] (spk=4) 근데 되게 매출이 없어요, 매출이없는데 그 매출 이만큼을 해야 되니까 각 팀별로 이제 그 나눈 나누어지죠. 자, 기네 티문 얼마 니네 팀문 얼마 이네 티 얼마.
# [3846.61–3854.19] (spk=4) 그럼 이제 그 이 각 팀별로 할당되 그 내용을 또 그 개개인이 또 금액으로 나눠서 가지는 약간 되게 명확한.
# [3855.31–3855.76] (spk=1) 어
# [3858.14–3866.95] (spk=4) 그런 구조가 되어있었었거든요. 근데 처음에 안 가르쳐줘요. 우리가 얼마를 해야되고 약간 이런 걸 안 가르쳐주고.
# [3870.83–3877.94] (spk=4) 작년에 그 왜 아까 어딘가에서 그런 말이 나왔던 거 같은데, 아, 지숙님이었나? 우리가 이번에 이 억을 했으니까. 자, 그럼 그 다음에는 요만큼 더할 수 있을 거야라.
# [4024.46–4034.64] (spk=0) 컴 그 사람한테는 뭐 삼 점을 올려 라는 케이피알를 줘. 그럼 그 사람은 그냥 애스토어 리뷰만 신경쓰면 돼. 물론 그걸 리뷰 스토어 점수를 올릴려면 다른 거를 해야겠지.
# [4034.67–4051.04] (spk=0) 약간 뭐 약간 이런 식으로 정말 구체적인 케이피아이 를 개개인 한 명 한 명한테 다 주라고 했던 적이 있어요. 근데 뭔가 반 년 만에 잘 안 되고 흐질부질했던 것 같고. 왜냐면 그때 당시에 뭔가?
# [4051.49–4058.57] (spk=0) 일단 서울 기준에서는 뭔가 그 케이피 아이 를 어떻게 설정을 해줘야 되며 그 케이 피 아이를 이루기 위해서.
# [4058.61–4065.89] (spk=0) 그 멤버가 뭘 해야 되는지 막 자세히 조언해주고 막 리딩해줄 수 있는 막 그런 역량도 없었고 맞아요. 문서화도 했어요.
# [4066.16–4074.73] (spk=0) 그래서 그때 브이 원 브이 플러스 브이 브이 브이 아이 피 뭐 약간 네 브이쓰 리 이런 게 그때 나왔던 거였어요. 그래서 뭐.
# [4074.74–4088.26] (spk=0) 예를 들어 씨 오 리상은 뭐 디에이 티형 평균 디 에이 를 천 으로 올려 뭐 약간 이런 이렇게 되는 거죠. 그럼 막 누구는 미테이션을 걸려고 막 약간 이렇게 네 그랬었는데 뭔가 제대로 안 됐어요.
# [4088.94–4094.88] (spk=0) 네, 근데 그것도 하나의 방법이 될 수 있을 것 같긴 한데 맞죠. 맞아 브이원 담당자 막 이런 거 그.
# [4096.25–4107.06] (spk=4) 그데 제가 중군 항망으로 그냥 단순히 수퍼 평점에 올라가야 우리 다운로들도 많이 해줄테니까. 나는 그 그렇게만 개별적으로 이어지는 성화라고 해야 되나?
# [4108.10–4109.22] (spk=6) 그러면 안될거 같고.
# [4110.04–4118.18] (spk=4) 정체적으로 이뤄야되는 우리 목적은 있는거아요? 그거 위해서 그거 하나하나가 도움이 줄거 이렇게 놓출 수 있는 글이면 저는 그것도 나쁠 거 같진 않거.
# [4120.44–4123.18] (spk=4) 응, 응, 근데 되게 뭐라 뭐랄까.
# [4125.64–4135.41] (spk=4) 많이 다르긴 해요. 그니까 저희도 그런 식으로 목표를 설정하고 갈 수 있을까라는 걸 그대로 적용해 봤을 때 어딘가에서 아 이래서 안 되고 이래서 안 되고 라는까 포인트가 나오더라고요.
# [4136.35–4140.57] (spk=4) 그래서 어 어렵다 네.
# [4140.87–4158.53] (spk=5) 그 님이 아까 초기에 그 다 이제 매출 이만큼인데 너는 이만큼 발성 발생 이렇게 부여를 한다고 하셨잖아요. 네, 그까, 지금 저 흑자 전원을 계속 들으면서 저는 이제 그 리더 완전 창의 리더.
# [4158.67–4171.33] (spk=5) 지금 회의까진 안 들어가서 모르는 걸 수도 있는데. 혹시 그러면 사업제 별로 저 흑자 달성을 하기 위해 아, 흑자 전환을 하기 위해서 우리는 이만큼 달성해야 돼 라는 지침은 아예 없는 상황인건가요?
# [4171.63–4173.43] (spk=4) 아예 저도 지금 이정이에요.
# [4174.68–4178.31] (spk=5) 아, 그면 이 억을 각장 하면은 승차 전함이 되는 상황인 거예요.
# [4178.49–4187.51] (spk=4) 박자는 아니에요? 에이치 순위는 일단 이 억을 하자. 그리고 뭐 엠엘디는 아까 얘기 나왔던 것처럼 지금 수익 구조를 개선을 해서 어, 그니까 그 업 뭐야?
# [4187.64–4192.31] (spk=4) 명확한 금액이 있지 않고 엠 엘디는 음 수익구조를 일단 개선을 하자인 거구요. 음.
# [4193.03–4200.35] (spk=5) 근데 진정 했자 전환을 하려면 그 금액이 명확해야 되는거 아닐까 하는 생각이 들었어요.
# [4200.57–4202.91] (spk=4) 이 에이치에스디만이 그게 아니라 그니까.
# [4203.35–4205.83] (spk=5) 코네 전체적으로 그쵸, 그쵸.
# [4206.69–4220.26] (spk=1) 근데 제가 여기서 처분을 좀 드리자면 그게 그니까 여러분들이 상식적으로 할당이 된다라고 생각할 수 있지만, 전략은 그렇게 수립될 수가 없는 거잖아요.
# [4220.26–4234.58] (spk=1) 왜냐하면 전략은 어느 정도의 실패도 가정을 해야 되거든요. 그러면 그니까 뭐냐면 다 똑같이 이 억을 달성해 인력 구조가 같으니까. 이런 방식으로 인제 목표가 할당되고 수립되는 방식은 아니고.
# [4235.10–4249.24] (spk=1) 어, 일단 어, 이제 근거와 이런 것들을 토대로 봤을 때. 에이치 에스디 가 이 억을 이 억 엔을 찍으면 다른 프로젝트들의 성과가 미진하더라도 에이치 에스디 만으로 커버가 가능하다라는 의미를.
# [4249.24–4258.25] (spk=1) 가지고 있는 거고 센트 같은 경우에는 센트는 글로벌 시장의 규모를 우리가 측정할 수 없잖아요. 그러니까 지건 예측하는 것 자체가 좀 어려운 거긴 해요.
# [4258.32–4269.68] (spk=1) 그렇지만 가시적인 목표로 우리는 천 만 디 에이오로 간다라는 목표. 그니까 어떤 그건 굉장한 근거를 토대로 한 건 아니죠. 이제 비전에 가까운 목표를 가지고 가는 거고.
# [4269.99–4278.58] (spk=1) 어, 그 엠 엘디 같은 경우에는. 엠 엘디가 지금 어떠한 엠 엘 디 의 여러 가지 상황을 봤을 때 어떻게 개선을 해서 뭐.
# [4278.72–4291.07] (spk=1) 에이치에스 랑 똑같은 환경에서 똑같은 매출을 발생시킬 수 있는 어 조직적인 구조 상황이 아니기 때문에 그다음에 이제 뭐 노동집약적이라든가 이런 것들이 많기. 때문에 뭐냐면 수익성 개선한다.
# [4291.12–4306.29] (spk=1) 엠 엘 디는 이미 나온 지표가 그 어 제이피 랑. 티 더블유 외에는 성장의 모멘텀을 찾기 어렵다라는 판단으로 요것들은 축소를 하고 대신에 어 효율화를 통해서 수익성을 만든다.
# [4306.29–4316.42] (spk=1) 그래서 자체적으로는 내부적으로는 일 억 엔 뭐 하반기에는 일 점 사 억엔까지 올리고 그 올리는 과정이 그래서 제가. 지난번에 질문을 드렸던 거죠.
# [4316.60–4320.94] (spk=1) 엠 엘 디에 단순히 일 억엔을 달성하면 되는 것이냐, 그게 아닐 것이다.
# [4320.97–4330.83] (spk=1) 결국은 그 비용 구조를 어떻게 개편을 해야 수익 구조를 개편해야 이 일 억엔이라는 숫자가 의미가 있을 것이냐라는 어 목표를 가지고 있는 거잖아요.
# [4331.31–4341.88] (spk=1) 음 그까 조직의 상황마다 다르지만 전략적으로 봤을 때는 어 큰 전략에서 솔직하게 말씀드리자면 센트를 통해서. 신규 모멘텀만 확보한다.
# [4342.09–4353.10] (spk=1) 어, 그다음에 에이치 에스디 로 어 다른 프로젝트들의 전략이 어 워킹하지 않았을 때 어 최대한 커버할 수 있는 그림을 그려본다인 거고.
# [4353.38–4366.23] (spk=1) 엠 엘 디 는 수익 극대화, 그니까 수익성 전환을 해본다, 수익성 전환을 한다. 그래서 자생력을 가지게 한다. 근데 여기서 제 이건 계속 제 생각인데 의미부여가 저 될 것 같은 게 뭐냐면.
# [4366.42–4376.56] (spk=1) 아웃소싱을 통해서 그림을 그린다라는 것은 미래 가치가 되게 높은 것이다라고 저는 생각이 들어요. 성장 그림까지도 그릴 수 있다. 요런 전략들을 가지고 있다고 저는 봐요, 예.
# [4379.31–4382.88] (spk=5) 아, 그럼 학자전는 달성을 위한 뭔가 각 컨폰니 목표가.
# [4383.39–4397.99] (spk=1) 있는 거네요, 그쵸 있죠? 예, 각각의 목표가 있그걸 여쭤거. 예, 예, 그 개인 아까 선민님이 이제 개인의 목표를 세우게 했다라고 하는데, 사실 저도 인제 넷마블에서 동일한 경험들이 있었고.
# [4397.99–4405.96] (spk=1) 그때는 이제 일 년에 두 번을 해요. 두 번을 하는데 어 상반기 하반기 하고 두 번인가 두 번 이상 했던 것 같아요.
# [4405.96–4419.03] (spk=1) 그니까 수립하고 상반기에 한번 평가하고, 하반기에 수립하고 하반기에 또 평가하고 하는데 지표가 여러 가지가 있어요. 지표를 일단 할당해 주지 않아요. 그니까 마찬가지예요.
# [4419.03–4435.98] (spk=1) 뭐 우린는 이 억엔이니까 이거게 이런 게 아니라 케이피아을 막 이렇게 하다를 해주는게 아니라 자신이 스스로 세우는 거예요. 자, 그 이 프로젝트가 결국은 이런 아, 그리고 저게 있었어요.
# [4435.98–4442.46] (spk=1) 인제 그 아. 넷마블은 프로젝트마다 피 엘씨 워크샵이라는 걸 해요.
# [4442.82–4454.76] (spk=1) 일 년에 몇 번씩 하는데 피 엘씨 워크샵이 뭐냐면 이제 지표라든가 고객 그 분석, 고객 그 동향이라든 이런 것들 다 끄집어내놓고 워크샵을 해서 계속 이제 종합적으로 다 시나리오를 보고.
# [4454.76–4463.80] (spk=1) 그래서 우리는 그다음에 이런 전략을 가질 거야라는 것들을 지표를 엄청 많이 꺼내놓고 보면서 이렇게 얘기를 하거든요. 그러다 보니면 이제 전체적인 이제 목표가 수립이 돼요.
# [4463.94–4473.29] (spk=1) 그 과정을 통해서 그 수립에 본인이 기여하는 역할에 대해서 본인 스스로 케이피아이 를 정량적으로 배정을 하고 정성적인 것도 배정을 해요.
# [4473.48–4488.80] (spk=1) 정량적 정성 두 가지를 다 하는데 사실은 어 관리하기에 굉장히 좋은 시스템이라고 생각이 들고 그 시스템이 중간에 어. 어떠한 실행의 결과가 나올 때마다 변경을 할 수 있어요.
# [4488.88–4498.53] (spk=1) 그걸 맞춰 탄력적으로 바꿀 수가 있는 거죠. 근데 그래서 저도 이것이 가지는 의미가 뭘까라고 생각하면 실무에서 일하기가 굉장히 용이하다.
# [4498.56–4510.55] (spk=1) 의외로 의외로 이게 어떤 그 조직 전체의 매니지먼트나 관리적인 측면도 있지만, 담당자인 내가 정확하게 길을 잃지 않고 업에 집중하는데 상당히 도움이 되더라.
# [4510.58–4519.28] (spk=1) 저한테는 개인적으로 왜 그렇게 생각하냐면 그렇게 한다고 해서 조직적인 전체의 성과를 반드시 이게 견인하느냐, 그렇지는 않아요.
# [4519.39–4533.37] (spk=1) 어, 넷마블은 지금 상황이 별로 안 좋은데 어 제가 봤을 때는 어 테크닉적인 부분, 그니까 넷마블에 있어 보면 뛰어나죠. 일단 기본적인 개인지가 다 뛰어나.
# [4533.97–4542.48] (spk=1) 왜냐하면 이제 공채를 통해서 들어올 때부터 되게 걸러지고 걸러지고 그니까. 근데 근데 경영적인 부분이 제가 봤을 때는 좀 되게 약한 거 전략적인 부분이라든가.
# [4542.51–4554.43] (spk=1) 왜냐하면 이제 너무 성과에 집착하다 보니까 여기에서는 이제 창의적인 게 필요한데 창의가 안 돼. 왜 안 되냐면 린네볼이 뭐 한 달에 천 억 찍어버리니까.
# [4554.52–4568.77] (spk=1) 그다음부터 모든 프로젝트가 안정적인 수익과 성과를 추구하다 보니까 다 린네볼을 카피하는 거예요. 그래서 심지어 리니지 그니까 넷마블식 알피지 구조라는 워딩이 생겨나.
# [4568.87–4579.36] (spk=1) 우리는 아니야라고 얘기하지만 고객들을 뜯어보면 다 똑같네 이 이렇게 나오는 거거든요. 그래서 참 계속 이 대는 딜레마가 있는 것 같아요.
# [4579.45–4593.94] (spk=1) 아이러니사 뭐 제일 의견은 그렇고 그 시 월 이상에 두 가지 저도 이제 두 가지 얘기가 있었는데 이미 하나는 나왔어요.
# [4593.94–4603.58] (spk=1) 리더십은 누가 아그 목표는 누가 수립하는가에서 어 표면적으로는 리더들이 수립을 하는 게 이제 일반적이죠.
# [4603.58–4618.84] (spk=1) 그런데 그 수립하는 과정에 조직원들을 참여시키면 참여시킬수록 어 목적의식과 동기부여에 상당히 도움이 된다라고 합니다. 그리고 공유와 공감대를 앞단에 형성하는 데 상당히 유리하고요.
# [4618.95–4625.93] (spk=1) 조금 저도 이제 다른 결의 얘기인데 제가 아이티에 처음에 들어왔을 때 일을 어떻게 해야 되는가 에서 또 딜레마 같은 얘기를 할게요.
# [4627.05–4635.40] (spk=1) 우리 이제 린스타트업 얘기하면서 무조건 빨리 실행해라고 하잖아요. 근데 사실 가설 없이 실행되는 경우도 되게 많아 그거는 아무 의미가 없는 건데.
# [4635.88–4649.71] (spk=1) 근데 한편으로는 뭐냐면 목표라든가 이거에 대해서 충분히 고민을 하고 수립해 놓은 경우에 어 이제 그 조직이 이 업무가 진행되는데 용이하다라는 이론도 있어요. 그러니까 어디 에너지를 쏟느냐.
# [4649.74–4662.32] (spk=1) 통상 그때만 하더라도 이십 년 전이어서 그럴지도 모르는데 통상 앞단에 왜 무엇을? 여기에 대한 고민 없이 일단 하고 보다 보니까 중간에 발생하는 수많은 문제점들을 해결을 못하는 거예요.
# [4662.81–4670.42] (spk=1) 그래서 이제 어려움에 빠진다라는 이론도 있던 때가 있었습니다. 그러니까 이게 그러면 어, 그럼 어떻게 해야 되지?
# [4670.47–4677.37] (spk=1) 양자를 선택을 하는 게 아니라 조직과 조직이 그런 그렇게 일을 할 수 있는 역량을 갖췄느냐.
# [4677.57–4688.56] (spk=1) 그리고 우리가 어떠한 것을 추구하느냐에 따라서 선택할 수도 있고, 중간 지점을 찾을 수도 있고 그렇다는 생각이 들어요. 어, 확실히 답은 없다라고 생각드는 게.
# [4688.64–4698.70] (spk=1) 그 많은 책에서도 경영의 얘기를 한 하나 하나의 정답. 절대 없고 모순은 사업을 하면서 모순은 수도 없이 발생한다.
# [4698.70–4709.12] (spk=1) 이 모순이 발생할 수 있다라는 것들을 조직 구성원들이나 이 사람들이 이해하지 못하면 이거는 그니까 그까 세상은 그렇게 돌아가지 않는 거죠.
# [4709.32–4719.82] (spk=1) 심지어 세상 성공도, 성과도 절대 하나의 요인으로는 성공하지 않는다라는 게 인제 정론이다, 이런 얘기들이 있었습니다.
# [4722.10–4733.35] (spk=1) 야, 그리고 이제 아, 몇 명한 건가, 이제 기 예, 기용님 넘어가 볼까요? 네, 저.
# [4733.43–4746.37] (spk=2) 저는 이제 목표 목표의 역할은 이제 어 보달해야 될 곳이 명확 해야 되고. 그리고 이제 그 지속적인 동기 부여를 이제 할 수 있게 한다고 생각하고요.
# ...
# [5880.43–5893.71] (spk=1) 그래도 좀 비슷한 가치관을 가진 사람들이 함께 일하는 형태였으면 좋겠다. 그럴려면 우리가 추구하는 가치관이 어떤 건지, 어느 정도는 좀 어 좀 밝히는 게 필요하다.
# [5893.71–5903.64] (spk=1) 그리고 그런 사람들, 그리고 저는 그게 또 약속이라고 생각을 하거든요. 예를 들면 우리는 근데 그게 또 조직의 정체성하고 다 연결이 저는 된다라고 생각을 하는 거예요.
# [5903.64–5912.57] (spk=1) 예를 들면 픽사 같은 경우에는 되게 창의적인 것이 중요하기 때문에 뭐 다양성을 존중하고 그다음에 뭘 하고 뭘 하고가 있는 거예요.
# [5912.57–5923.25] (spk=1) 이제 기본적인 역량적인 것도 있고, 그것들을 추구하는데 어, 아니야? 나는 나는 다양성을 존중하고 싶지 않어. 나는 그냥 명확한 뭐 뭐 이것만 하고 싶어.
# [5923.28–5934.05] (spk=1) 그런 사람은 그 조직에 성과에 안 맞는 거죠. 그러니까 애초에 그런 사람을 채용하지 않도록 노력을 해야 되지 않은가라는 생각을 가지고 있어.
# [5934.12–5937.19] (spk=1) 제가 왜 이런 생각을 가지고 있었냐면 비슷한 고민이 있었어요.
# [5937.19–5949.31] (spk=1) 저는 저를 가장 힘들게 하는 게 제가 일을 시작할 때만 하더라도 상사들이 다양 다양성을 이제 받아줘라라는 얘기들을 엄청 많이 했었어요.
# [6082.47–6087.69] (spk=1) 너는 왜 그래라고 생각해 넌 어떻게 그래? 그래서 심지어 저한테 그런 얘기를 하는 사람도 있어요.
# [6087.69–6097.87] (spk=1) 야, 직장을 직장으로 다녀야지, 그렇게 하면 너 나중에 상처봐, 너 뭐 이런 얘기도 들어보고 했는데. 저는 그때 너무 재미있게 일을 했, 행복하게 일을 했고, 성취감도 있었어서.
# [6098.62–6109.95] (spk=1) 다시 그런 환경에서 일할 수 있다면 어디든 가겠다인데 그런 환경을 찾을 수 없겠더라고요. 직접 경험해보지 않고서는 그 회사를 경험해보지 않고서는 너무.
# [6109.95–6115.88] (spk=1) 그래서 포기를 하다가 흘러흘러 여기까지 왔다. 음.
# [6117.90–6130.90] (spk=1) 그래서 때에 따라 아까 전에도 얘기했지만 때에 따라 다른거지만 어 사람은 변하지 않더라. 그래서 그 사람을 그렇기 때문에 이제 이걸 냉소적으로 보자는 게 아니에요.
# [6131.00–6136.82] (spk=1) 더 더 그래서 사람한테 관심을 가지고 도대체 사람이라는 게 어떻게 구성돼 있지를 봐야 될 것 같아요.
# [6141.52–6151.09] (spk=1) 아, 알겠습니다. 그러면 시간이 얼마 안 남았으니 선비님 얘기로 어, 우리 풀림 님이 안 해준 덕분에 시간이 딱 맞게 끝날 것 같습요.
# [6152.82–6153.10] (spk=4) 네.
# [6153.58–6154.07] (spk=1) 돌려 아닌까요?
# [6155.77–6156.31] (spk=3) 어
# [6159.87–6160.98] (spk=0) 가셔야 되나 가셔되.
# [6160.98–6164.15] (spk=1) 응, 넹 엇 네.
# [6166.02–6166.57] (spk=4) 네.
# [6166.60–6167.71] (spk=1) 고생이는.
# [6169.05–6178.04] (spk=4) 아까 그 목표 목적 뭐 그런 정의 관련한 그런 얘기들도 나왔었지만, 네, 저는 이 두 개를 떼어놓고 생각할 수 없다고 생각을 하거든요.
# [6178.68–6190.32] (spk=4) 목표라는 거는 제가 오히려 목 목적이 조금 더 상의되념낌, 그거를 달성하기 위해서 이제 우리가 만들어야 되는 것들이 목표라고 생각을 해서 이렇게 적어봤고요.
# [6190.62–6199.18] (spk=4) 래, 예를 들어서 설명하자면 저희가 연내에 흑자전활를 하자라는 게 이제 목적이고. 그러기 위해서 자이 체스기에서는 이런 위슈를 만들어놨다라는 게 목표고.
# [6199.52–6207.57] (spk=4) 그래서 좀 더 그룹자 전체적으로 보려면 뭐 글로벌 시장에서 이 인으로 하나의 장론로서 좀 자유잡게 하자라는 그런 큰 그림을 그리고 있으니까 그러기 위해.
# [6207.66–6214.35] (spk=4) 팬트행결이라는 서비스를 성공시키자라는 게 목표라고 생각을 했어요. 네, 그래서 이런 것들을 결금 누가 수립을 하는가?
# [6214.86–6220.05] (spk=4) 왜 그 사람이 해야 될까라는 부민에서 봤을 때 저도 비슷한 맥령으로 조직히 이어가 해야 된다고 생각을 했고요.
# [6220.47–6226.10] (spk=4) 아까도 얘기를 했지만 그 목표라는 거는 약간 위에서 흐르는 개념이 아닐까라고 저는 생각을 했어요.
# [6226.12–6234.03] (spk=4) 그래서 우리한테 좀 기대해 보자면 뭐 지에 의역이라는 목표를 가지고 반도식기 그 목표 수치에 기여할 수 있는 능력이나 가능성 같은 거에 맞춰서.
# [6234.23–6239.76] (spk=4) 그게 합성이 되어야 그래도 어느 정도는 실현이 가능한 그림이라고 생각을 해요. 저는 이게 되게 중요하다고 생각해요.
# [6239.77–6249.10] (spk=4) 그러니까 실현이 가능한 정도의 목표만 설정을 해야 된다는 게 아니라, 그 애초에 그럴려면 좀 더 그 상의의 목표가 조금 더 커야겠죠.
# [6249.66–6260.67] (spk=4) 그 그거를 설정하는 그게 굉장히 중요하다고 생각을 하고 그러고 나서. 이제 하위조직에 할상되는 목표는 이제 그거를 상 달성하기 위한 그 신향 가능성, 그니까 그 신향 가능성이라는 게 목표에.
# [6260.70–6267.64] (spk=4) 상위하에 따라서 굉장히 그게 다르다고 생각을 해요. 그래서 이런는 게 좋지 않을까라고 생각을 했고.
# [6267.82–6275.64] (spk=4) 이런 그런 조직에 결국엔 영향이나 그런 가능성의 정도 같은 것들이 그 목표를 실현하는 데 굉장히 중요한 키가 될 텐데.
# [6275.94–6285.26] (spk=4) 그런 것들을 매번 항상 고민하고 하는 것들은 리더의 몫이라고 생각을 했기 때문에 네, 그래서 리더들이 해야 된다고 생각을 했습니다. 그 목표는 중요한가, 그게 중요한 가.
# [6285.32–6286.70] (spk=3) 얼마나 중요한가 생각을 했.
# [6287.68–6297.58] (spk=4) 이건 좀 약간 좀 막그했는 데요이건 좀 중요하다고 생각을 했고. 어쨌든 궁극적인 그 목적을 달성하기 위해서 우리가 만들어내야 되는 그 하나하나의 정제를 목표라고 생각을 했기 때문에.
# [6297.84–6303.94] (spk=4) 그게 없으면 어 그 목적을 최종적으로 달성할 수가 없다고 생각을 했어요. 물론 좀 길이 다른 방법이 있을 수도 있지만.
# [6304.02–6315.19] (spk=4) 그게 아까 얘기했던 나왔던 것처럼 뭐 중간에 음 방냥 이렇게 뭐 비트 그니까 뭐냐 바꿀 수도 있는 거고 이게 아니다. 자, 빨리 전환을 하자라는 그런 방법들이 여러 가지가 있겠죠.
# [6315.60–6322.93] (spk=4) 어쨌든 그런 것들이 다 잘 이루어져야 목적을 달성할 수가 있으니까 목표게 중요하다고 생각을 했고요. 자, 그런 그 목표는 어때해야 되는가라고.
# [6322.94–6323.15] (spk=1) 했을.
# [6323.20–6330.96] (spk=4) 때는 저도 이것도 비슷한데 어 그 오픈 결국에 그게 하나하나 이뤄가는 그림이라고 생각을 하거든요.
# [6331.05–6339.66] (spk=4) 그래서 그것들을 자, 우리자 이번에 이거 했으니까 그다음 자, 이렇게 그런 식으로 좀 다음에 약간 저는 그 지금 얘기를 하면서.
# [6340.30–6350.11] (spk=4) 우리가 되게 그 광업 중심적으로 얘을 한다면 실장님의 고맥주가 딱 떠오르는데 제가 되게 그런 음단이어서 그여이 다 떠오르는데요. 네, 그 그런 게 그래도 어느 정도 좀 있어야 될 것 같아요.
# [6350.23–6353.29] (spk=4) 그런 측정을 할 수 있어야 정향적이와야 좋을 것 같다고.
# [6353.31–6354.07] (spk=0) 생각을 하고요.
# [6354.73–6356.03] (spk=4) 지금 저희 조직의 목표는?
# [6356.95–6357.21] (spk=0) 네.
# [6357.99–6366.47] (spk=4) 어 세어만이라는 목적 달성을 위해 에이치 스 디 가 해야 되는 것들은 이업이라는 목표가 있는 거고 굉장히 희혈이 뚜렷하고 그니까. 음.
# [6366.50–6373.58] (spk=4) 저희가 지금 평소에 해오던 것들에 대비해서 달성이 불가능한 수준도 아니라고 생각하고, 그래서 이후 목표라고 생각을 합니다.
# [6374.08–6381.03] (spk=4) 어, 지금 저희가 그 이억이라는 목표를 달성하기 위해서 가장 필요한 조직 역량은 저도 아까 주랑 비슷한 맥락인데요.
# [6381.11–6390.66] (spk=4) 네, 우선순위 결정하고 되게 해야 되는 일들이 많으니까 그 달성해야 되는 목표가 굉장히 많으니까. 그 목표 이억이라는 목표를 달성하기 위해서 해야 되는 그 목표들이 굉장히 많으니까.
# [6390.88–6399.06] (spk=4) 그런 것들을 결정 순위를 결정을 하고 시행에 옮기는 역량이 가장 중요한 차이지 않을까라고 생각을 했습니다. 네 이상입니다.
# [6406.41–6416.04] (spk=6) 저도 마지막에 말씀하신 이제 되게 어찌보면 당연하긴 한데 생각보다 이제 잘 정리가 안 되는 그런 우선순위 같은 게.
# [6416.29–6428.58] (spk=6) 이제 아, 나는 이 목표고 이거 있고 이거 있고 하면은 이렇게 막 이렇게 많은 목표들이 있는데. 뭘 먼저 하고 이런 게 생각보다 쉽게 놓치는 부분인 것 같았어요.
# [6428.74–6438.48] (spk=6) 저한테도 그렇고 뭔가 이거랑 이걸 할 거야. 하고 아, 뭐부터 하지 이런 느낌인데 뭐부터 하지가 아니라 이걸 이거를 하고 이거 하면 연결이 되고 이거 되고가.
# [6438.48–6442.69] (spk=6) 이런 식으로 약간 동동을 잘 하는 것도 되게 중요한.
# [6443.62–6444.15] (spk=0) 것 같다.
# [6444.15–6444.49] (spk=6) 생각이.
# [6444.49–6444.81] (spk=0) 들었는?
# [6450.07–6462.13] (spk=4) 네, 그사 순위를 결정하는 판단 기준을 결과적으로는 되게 두돌래표긴 한데 목표라고 생각을 하거든요. 아까 처음에 한조님 말씀하신 것처럼 네.
# [6462.66–6463.12] (spk=3) 그래서.
# [6464.24–6468.64] (spk=4) 물론 거기에 따라야 되고. 다만 그게 제일 기준이기 이기는 하지만.
# [6469.23–6469.44] (spk=3) 어
# [6473.41–6473.72] (spk=3) 그.
# [6475.94–6488.60] (spk=4) 달성해 나가야 되는 그 작은 단위의 목표들을 하나하나 이렇게 삼년 관계. 지금 치월리상 말씀하신 것처럼 그런 것들을 따져봤을 때 분명 분명 서로서로 영향을 주는 부분이 있을 거라고 생각을 해요.
# [6489.06–6502.71] (spk=4) 그래서 그런 순서랄까. 그 연관관계에 더군다나 저희 같은 서비스를 하고 있는 상황에서는 그런 것들이 그런 것들도 당연히 굉장히 중요하게 생각을 해야 되는 네 부분이라고 음 공감합니다.
# [6511.13–6530.11] (spk=3) 저 어 시간이 없는데 신규 프로젝트 경험이 있으신 분들한테 여쭤보고 싶은데요. 그 여러분들의 그 우선순위를 결정하는 그런 뭔가 기준 어, 여러분들만의 기준이 있으신지 좀 그런 게 궁금합니다.
# [6532.07–6545.39] (spk=3) 물론 우선순위를 결정할 때 이게 어 진짜 그 성과를 결과 성과를 생각하면서 하긴 하겠지만, 결국에는 그것도 어떻게 보면은 주관도 포함이 될 거라고 생각이 들긴 하거든요.
# [6547.03–6558.33] (spk=3) 근데 그게 어떤 뭔가 본인만의 그런 게 있으신지 좀 궁금해요. 뭔가 고민이 될 때 어떤 기준이 있는가? 음, 한슬님이랑 실장님께.
# [6559.26–6575.31] (spk=0) 뭐 그니까 제가 질문을 다 이해했는지 모르는데 뭐. 예를 들어 메타리브리 프로젝트를 예로 들면은 저는 그냥 모든 선택과 우선순위를 설정을 할 때 어, 그냥 머릿속에 계속 있었던 거는.
# [6575.67–6590.11] (spk=0) 코콘의 그룹사가 이 블록체인이랑 웹쓰리 서비스를 처음 만드는 거라서 아무런 노하우가 없는데 어떻게든 이 스타트를 끊어보려고. 메타리브리 프로젝트를 시작을 한 거고 나한테 맡긴 거다.
# [6590.17–6603.39] (spk=0) 그냥 이거 하나만 머릿속에 있었어요. 그러다 보니까 약간 제 머릿속에 생각든는 거는 스피드가 좀 가장 중요했던 것 같고, 그니까 이게 성공해야지라는 생각은 머릿속에 없었어요.
# [6604.05–6607.58] (spk=0) 오히려 아, 빨리 실패하자가 더 가까웠고.
# [6607.96–6608.53] (spk=6) 그리고 두.
# [6608.53–6609.15] (spk=0) 번째는.
# [6609.75–6610.28] (spk=3) 그냥.
# [6610.82–6623.45] (spk=0) 근데 이 실패가 의미가 없으면 안 되니까. 이 실패가 분명히 밑거름이 되려면은 무조건 측정을 다 해야 된다. 그래서 난 사실 사실 그때도 뭘 측정해야 될지 도대체 모르겠어.
# [6623.64–6629.92] (spk=0) 나중에 이 지표들을 가지고 어떻게 해석할지도 모르겠고, 뭐 어떻게 판단을 해야 될지도 일도 모르겠어.
# [6630.05–6631.03] (spk=1) 그럼 모든.
# [6631.03–6632.95] (spk=0) 걸 다 기록해 이래서.
# [6632.95–6633.71] (spk=6) 그냥 기록에.
# [6633.71–6640.06] (spk=0) 좀 우선순위를 줬던 것 같기도 하고요. 스피드와 기록, 네, 이랬던 것 같네요.
# [6640.74–6651.97] (spk=1) 복합적으로 생각. 인제 케이스마다 다를 텐데 이제 저기는 실패를 전제로 하고 갔기 때문에. 그렇고. 만약에 이제 성과 자체가 이제 에 있어야 된다라고 하면 복합적이라는 얘기를 왜 했냐면.
# [6652.27–6663.99] (spk=1) 예를 들면 이 안과 이 안에서 선택을 할 때 그 안이 어느 정도의 변수를 가지고 있느냐. 이게 지금 도전이 필요한 시기냐, 아니면 안정적인 확보가 필요한 거냐, 그 상황에 따라서 다 다를 것 같아요.
# [6664.14–6669.76] (spk=1) 그 조직의 지금 목표와 성과에 따라서 그래서 어, 지금은 새로운 그니까 조직의 여유가 있고 이렇게 해.
# [6669.79–6675.65] (spk=1) 그럼 이런 도전 자체 새로운 시도 가능성은 낫지만, 이거 자체가 의미 있을 때는 거기에 우선순위를 두는데 아니야?
# [6675.75–6685.06] (spk=1) 지금 반드시 이걸 이뤄야 돼라고 할 때는 고거 그렇다라고 하면은 도전보다가는 지금 안정적으로 숫자를 채워나가는 우선순위를 선택할 수도 있죠.
# [6685.13–6696.38] (spk=1) 그니까 목표랑 상황에 상황과, 그리고 그 진행하는 그 안건에 어 주변 사항들. 예를 들면 이 개발에 대한 변수가 있어 없어 이런 것도 있잖아요. 이거는 그냥 개발하면 돼, 근데 이거는 아니야.
# [6696.49–6706.24] (spk=1) 개발을 어떻게 할지도 고민이 돼야 돼. 그러면은 어떻게 할지라는 변수까지 있어버리는 건데 도전이 되게 큰 거야. 그럼 그 변수를 다 해칭하고 갈 거야, 아니야?
# [6706.46–6714.31] (spk=1) 지금은 이 변수를 다 케어할 수 있는 여유가 안돼. 그럼 이 안정적으로 할 수 있는 어, 그냥 개발만 하면 돼 물리적으로 시도만 하면 의미가 있는 거야.
# [6714.40–6722.60] (spk=1) 그럼 이건 해 이런 그때그때마다의 의사결정의 기준들이 계속 바뀌는 것 같아요. 그게 인제 성과와 목적에 따라서 바뀌는 것 같아요.
# [6725.34–6739.08] (spk=1) 네, 일단 지금 칼같이 다 나가셔야 되나요? 마무리를 어 마무리를 하고 싶은데 이제 풀림님은 나가야 되는 거죠. 그럼 풀림 나가세요?
# [6739.52–6755.96] (spk=1) 어, 제가 마지막 당부는 아니고 부탁 뭐 읍소 읍소를 이렇게 한번 드리면서 마지막으로 이제 짧게 해볼게요. 사 분 안에 이래서 결론 결론부터 얘기하지 말아야지. 재밌있게.
# [6755.96–6766.96] (spk=1) 그래서 제가 주말에 그 알뜰 별잡을 봤는데 거기서 그 제가 좋아하는 그 교수님이 물리학 교수님이 그 얘기를 하더라고요. 그 사람 얘기에 다 동의하는 건 아니에요.
# [6766.96–6773.14] (spk=1) 근데 뇌가 어 텍스트를 볼 때랑 아닐 때랑 뇌의 작동 방식이 다르대요.
# [6773.17–6785.66] (spk=1) 그니까 인간이 아피엔스가 논리적인 사고가 가능해진 것은 텍스트가 생겨나고 나서부터 뇌가 그걸 해석하기 위해서 논리라는 개념이 그때부터 생겼대요. 그래서 이제 이 교수는 걱정하는 거예요.
# [6785.66–6794.50] (spk=1) 요즘은 이제 사람들이 책을 안 보고 이제 유튜브만 보고 이러니까 혹시 이렇게 뇌 작동 방식이 바뀌는 건 아닐까라는 건데. 사실 거기에는 동의하지는 않아요.
# [6794.98–6801.61] (spk=1) 다만 제가 얘기하고 싶은 건 텍스트를 볼 때랑 텍스트를 쓸 때랑 그렇지 않을 때랑은 전혀 다르다는 거예요.
# [6802.37–6810.81] (spk=1) 그렇기 때문에 되게 큰 의미가 있는 거고, 그리고 제가 지금 계속 며칠째 같은 책을 추천하고 있어요. 그 책을 추천할려고 하는 얘기예요.
# [6811.35–6823.35] (spk=1) 지금 이제 크레마에 있어서 너무 읽기가 쉽고 어 다들 한번 읽어보셨으면 좋겠고. 이게 또 어떤 의미가 있냐면 넓게 보면 우리 지금 매니지먼트가 뭔지 모르잖아요.
# [6823.60–6834.81] (spk=1) 모르는데 이것들을 그냥 목차만 쓱 보고 대충 보더라도 아, 우리가 매니지먼트를 할려면 이런 영역의 것들을 다른 사람들은 이렇게 고민을 해 갖고 있구나라는 걸 알 수 있을 거예요.
# [6835.11–6845.02] (spk=1) 그걸 다 하라는 게 아니라 그중에서 나한테 필요한 걸 찾아서 깊이 들어가는데 볼 수 있고. 시야가 일단 넓어지면 여러분들은 지금 매니지먼트를 공부해 본 적도 없고, 배워본 적도 없고.
# [6845.23–6851.74] (spk=1) 지금 회사에서 주어지니까 그 일을 하는 건데 이제 성장을 해야 된다라고 하니까 그럼 뭐부터 해야 되지, 답답할 거 아니에요?
# [6852.00–6865.75] (spk=1) 그럼 시야를 넓혀서 아, 대학에 갔더니 이런 걸 가르키는구나처럼 아, 매니지먼트는 이런 것들을 하는 거구나라고. 어 크레마로 안 보고 돈 펑펑 쓰고 그럴 거야 이렇게 농답이었어요.
# [6865.78–6878.80] (spk=1) 예, 예, 그런 거예요. 왠제 그래서 그렇게 봐주고 또 하나가 뭐냐면 되게 재미있는 게 오늘도 얘기를 쭉 들으면서. 여러분들도 이제 처음에는 그 생각을 못 했지만.
# [6878.80–6888.43] (spk=1) 이렇게 질문을 제가 던지니까 그 질문에 답을 하고 자기의 업무에 맞춰서 생각하다 보니 자연스럽게 또 다른 질문이 인제 생기잖아요. 기용님들 다 여러분들은 어떻게 생각하세요?
# [6888.80–6898.73] (spk=1) 여러분들은 어떻게 생각하세요도 좋은데 이거를 그럼 다른 사람도 비슷한 고민을 했을 거잖아요, 그게 없을까요? 그 고민이 고스란히 다 책에 있을 거예요.
# [6898.73–6909.11] (spk=1) 심지어 이 사람들은 되게 우리처럼 제 생각은 이래요가 아니라 되게 깊이 있게 고민하고 생각을 했을 거잖아요. 짧게 생각해보면 이런 거예요. 우리는 다 생각이 있어요.
# [6909.56–6920.06] (spk=1) 우리 자, 주관이 있잖아요, 리더로서 주관이 있어요. 내 주관이 있어 이거는 뭐냐면 기준이 나한테는 최소한 적용되는 이야기야 나한테는 최소한 적용되는 방법이야. 그럼 궁금할 거잖아요.
# [6920.09–6930.00] (spk=1) 조직을 움직여야 되니까 다른 사람도 그럴까 궁금하잖아요. 그래야지 다른 사람도 움직이고 성과가 나고 내가 하는 일의 역할을 수행하는 거니까 궁금할 거잖아요.
# [6930.35–6942.14] (spk=1) 그것들을 일일이 가서 물어보고 테스트 해보는 것도 방법이지만, 비슷한 고민을 한 사람이 세상에 얼마나 많겠어요. 심지어 그걸 더 정립을 해서 방법문으로 제시를 하고 있는 아하 그렇구나.
# [6942.34–6958.15] (spk=1) 근데 나한테는 이게 맞네. 이렇게 써볼 수 있다는 거예요. 책을 공부하라는 얘기가 막 막 학습을 하라는 게 아니라 내 내가 필요한 데를 어 가지고 쓰는 것으로써 책을 한번 이렇게 강요해 봅니다.
# [6958.87–6959.98] (spk=1) 어, 배고파 예.
# [6962.24–6967.86] (spk=1) 그래서 이렇게 마무리를 하고 음 다음 주에 봐요.
# [6970.19–6971.17] (spk=1) 수고하셨습니다.
# [6973.52–6976.31] (spk=3) 수고 아이 왜
# [6977.09–6982.27] (spk=1) 머리가 아프지 여기 공기가 안통한가, 아니.
# Full text:
#  네, 사실 제가 지난번에 에폴라랑, 에이패스비, 에이아이 공강의 목표를 쓴 게 있었는데, 사실 이제 저는 그거를 제가 직접 설정하지는 않았어요. 왜냐하면은 사실 종일 대표님으로부터 그냥 너 이거 해라고 탁 그냥 부여를 받았기 때문에 제가 하지 않아서 여기에 피엠 이 한다라고 딱 못 쓰겠더라고요. 그래서 앞에 프로젝트를 발휘하고 추진한자 그까 동일 대표님을 네 생각을 하면서 이렇게 쓴 거죠. 네, 그리고 사실상 피엠이 하긴 해야죠. 그래서 목적 달성 인무를 위임받아 프로젝표를 맡게 된 비엠 교육을 받고 있는 우리 네 해래서 좀 앞으로도 제가 목표를 아무리 받아도 내가 그거를 약간 이게 말이 되는 목표인가. 정말 이게 근거가 있는 건가라고 좀 다시 회고를 해야 되는 네 생각을 하게 됐고요. 네, 그리고 저는 이 질문을 다른 분들이랑 읽다 보니까지 제가 좀 잘못 이해했다고 생각했는데 저는 목표를 설정하는 것이 중요하다라고 해정을 해서. 네, 막 이 썼어요. 네, 그래서 사실 일 번이랑 좀 겹친다고 생각도 들었고, 네, 그래서 뭐 이거는 그냥 넘어갈게요. 네, 일 번이랑 거의 비슷한 얘기라서 네, 그리고 좋은 목표는 어때야 되는가? 이 좋은이라 게 좀 네 좀 어려웠는데. 사실 이제 뭐 형희 질장님이랑 원언언 하면서 좀 얘기했던 거를 갖고 왔는데 아까도 얘기한 것처럼. 근거 기반으로 네 목표를. 설정을 해야 되고 약간 무작정 뭐 백배 백 배 달성 막 약간 이런 것들은 그냥 무대거잖아요. 네, 거기까지 도달하기 위해서 어떤 계획을 해야 될지, 뭐 이렇게 지침이 되는 것도 아니고. 해래서 근거 기반으로 설정해야 그 목표를 달성하기 위한 계획도 세워질 수 있을 것 같아서. 네, 그리고 멤버들도 이해를 할 수 있겠죠. 그랬고, 그리고 근거를 기반으로 했다고 해서 좀 이거는 저희가 간과하면 안 되는 것 같은데. 현실적이고 달성, 회범직함, 약간 이런 쉬운 목표는 좋은 목표가 아닌 것 같애요. 네, 그래서 도전 인식이 생겨야 되고, 그다음에 그냥 뭐. 예를 들어 하루에 세 끼 먹기 아, 새 끼 좀 어려울 수 있죠. 뭐 하루에 두 끼만 먹기 약간 이런 것들은 되게 현실적이고 달성할 수 있지만, 때로는 누군가에게는 한 끼만 먹는 사람한테는 뭐 목표가 될 수 있다고. 하지만 사실 그게 두끼 먹었다고 해서 성취감이 생기거나 이러진 않잖아요. 그런 것처럼 저는 뭐 영양을 뭐 더 골고루 먹는다, 운동을 뭐 매일 삼십 분씩 한다. 뭐 약간 이런 게 좀 좋은 목
현실적이고 달성하기 쉬운 것은 좋지 않은 목표다라고 하셨는데. 너무 거리가 먼 목트인 경우에는 누군가한테는 아니 협업자들에게는 저게 될까 하는 의구심도 심어줄 수 있을 거 같거든요. 그런 그렇게 갈라오면 또 오히려 약간 서로 다른 귀을 갖게 되고 막 좀 인식이 맞지 않을 때도 있을 거라고 생각하는데 그것 어떻게 생각하시는지? 궁금합다. 네, 그래서 제가 이거를 먼저 쓴 이유가 이거를 전제로 하고 그다음이라고 생각을 해주시면 될 것 같아요. 그러니까 사실 제가 앞부분에까 앞부분도 제가 그렇게 얘기했잖아요. 백배 달성, 이런 목표는 좋은 목표가 아니라고. 왜냐하면 근거 없이 정말 터무늬 없는. 높은 목표는? 그 그 목표를 설정한 리더도 이 백배 달성을 위해서 우리가 어떤 거를 할 수 있습니다. 라고 구체적인 계획을 못 세울 거예요. 왜냐면은 애당초 근거 기반으로 설정한 목표가 아니기 때문에. 네, 그래서 저는 네, 그래서 네 지수님이 생각하시는 거에 완벽하게 네 동의를 하고요. 네, 근데 뭐 이게 사실 체감하는 거는 사람마다 다를 수는 있을 것 같긴 해요. 뭐 아무리 근거 기반으로 해서 뭐 나는 두 배가 될 것 같애 했는데, 누군가한테는 어 나는 두 배도 안 될 것 같은데 어 약간 그 그렇기 때문에 이제 뭐 네, 뭐 그 그 뭐지? 인식하고 약간 받아들이는 갭은 계속 줄이기 위해서 약간 리더가 좀 노력해야 되는 부분인 것 같긴 해요. 네, 저도 한때 그 두 배 설정이라는 거를 주장하는 리더 밑에서 일해본 경험이 있기 때문에. 네, 얼마나 네 다들 기억하시죠? 아마 에이체 수디는 기억하실 거예요. 아, 네, 선미님은 기억 네 안 계셨던 때긴 한데 네, 근데 그때는 저한테 설명을 안 해주셨거든요. 그분이 그 두배 달성을 어떤 근거로 설정을 했는지 물론 계획은 있었어요. 대만 진출이라는 계획은 있었는데, 대만 진출을 하면 그게 뭐 몇 퍼센트 매출이 성장하는 거라고 생각하는지. 뭐 그러면은 그 뭐 목표 디행유는 몇인지 막 이런 것들은 제가 제대로 설명을 들은 적이 없었어가지고 좀 그게 아쉬웠던 것 같애요. 약간 근거 기반이면서 너무. 현실적이지 않고 도저을 블라이시키는 자체가 좀짜 어려운. 맞아요. 결국 밸런 밸런싱에데 아어요, 네. 지금 이 얘기를 듣고 저도 어제 제가 막 작성을 하면서 생각했던 것들을 좀 떠올려 봤는데. 그 저는 개인적으로 코코네가 엠 뿐만이 아니라 전사적으로 그걸 음 잘하는 편은 아니라고 생각을 해요. 방금 한선생님 말씀하신 것처럼 뭐 두 배를 하자라든지 응, 뭐 디에이유 뭐 업상이를 직자라든지 그런 목표를 지금까지 저희가 들어왔는데, 뭔가 그거를 달성하기 위한 그래도 어느정도의 지침이라고 해야되나요? 이 정도 규모에 이제 회사가 됐으면 그런 것들이 조금 그래도 따라줘야 되는 어느  ...
#
# Transcription saved to /content/drive/MyDrive/output/sample.txt

# %%
# ============================
# 5. 감정(SER) 분석: HuBERT 기반
# ============================
# RTZR에서 사용한 정제 오디오(audio_for_asr)를 그대로 사용
y_ser, sr_ser = librosa.load(audio_for_asr, sr=16000, mono=True)
duration_ser = len(y_ser) / 16000.0
print(f"Loaded for SER: {audio_for_asr}, sr=16000, duration={duration_ser:.2f}s")

model_id = "superb/hubert-large-superb-er"
config_ser = AutoConfig.from_pretrained(model_id)
print("SER labels:", config_ser.id2label)

ser = pipeline(task="audio-classification", model=model_id, top_k=None)

def slice_audio(y, sr, start_s, end_s):
    i0 = int(max(0, start_s) * sr)
    i1 = int(min(len(y) / sr, end_s) * sr)
    return y[i0:i1]

def predict_emotion(wave_1d, sr=16000):
    if len(wave_1d) < int(sr * 0.3):  # 0.3초 미만은 스킵
        return {"label": "unknown", "score": 0.0, "probs": {}}
    out = ser({"array": wave_1d, "sampling_rate": sr})
    top = max(out, key=lambda d: d["score"])
    probs = {d["label"]: float(d["score"]) for d in out}
    return {"label": top["label"], "score": float(top["score"]), "probs": probs}

segment_emotions = []
for seg in segments_to_use:
    start, end, text = seg["start"], seg["end"], seg["text"]
    w = slice_audio(y_ser, 16000, start, end)
    pred = predict_emotion(w, 16000)
    segment_emotions.append({
        "start": start,
        "end": end,
        "text": text,
        "speaker": seg.get("speaker", None),
        "emotion": pred["label"],
        "confidence": pred["score"],
        "probs": pred["probs"],
    })

print("\n[DEBUG] SER 예시 5개:")
for s in segment_emotions[:5]:
    print(f"[{s['start']:.2f}-{s['end']:.2f}] spk={s['speaker']} "
          f"{s['emotion']} ({s['confidence']:.2f}) :: {s['text']}")
print(f"... 총 {len(segment_emotions)}개 세그먼트")
# Out:
# Loaded for SER: /content/drive/MyDrive/data_MP3/PMCT_cleaned.wav, sr=16000, duration=6982.29s
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# SER labels: {0: 'neu', 1: 'hap', 2: 'ang', 3: 'sad'}
# pytorch_model.bin:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/212 [00:00<?, ?B/s]
# Device set to use cuda:0
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# [DEBUG] SER 예시 5개:
# [0.20-9.14] spk=0 sad (0.51) :: 네, 사실 제가 지난번에 에폴라랑, 에이패스비, 에이아이 공강의 목표를 쓴 게 있었는데, 사실 이제 저는 그거를 제가 직접 설정하지는 않았어요.
# [9.74-22.05] spk=0 sad (0.59) :: 왜냐하면은 사실 종일 대표님으로부터 그냥 너 이거 해라고 탁 그냥 부여를 받았기 때문에 제가 하지 않아서 여기에 피엠 이 한다라고 딱 못 쓰겠더라고요.
# [22.59-32.42] spk=0 hap (0.50) :: 그래서 앞에 프로젝트를 발휘하고 추진한자 그까 동일 대표님을 네 생각을 하면서 이렇게 쓴 거죠. 네, 그리고 사실상 피엠이 하긴 해야죠.
# [32.42-45.00] spk=0 sad (0.58) :: 그래서 목적 달성 인무를 위임받아 프로젝표를 맡게 된 비엠 교육을 받고 있는 우리 네 해래서 좀 앞으로도 제가 목표를 아무리 받아도 내가 그거를 약간 이게 말이 되는 목표인가.
# [45.09-50.63] spk=0 hap (0.41) :: 정말 이게 근거가 있는 건가라고 좀 다시 회고를 해야 되는 네 생각을 하게 됐고요.
# ... 총 781개 세그먼트

# %%
# ============================
# 6. 텍스트 감성 분석 (XLM-R sentiment)
# ============================
txt_model_id = "cardiffnlp/twitter-xlm-roberta-base-sentiment"
tok = AutoTokenizer.from_pretrained(txt_model_id)
txt_model = AutoModelForSequenceClassification.from_pretrained(txt_model_id)
txt_model.eval()

id2label_txt = {0: "negative", 1: "neutral", 2: "positive"}

def text_sentiment(s):
    if not s.strip():
        return {"label": "neutral", "score": 0.0}
    inputs = tok(s, return_tensors="pt", truncation=True, max_length=256)
    if torch.cuda.is_available():
        txt_model.to("cuda")
        inputs = {k: v.to("cuda") for k, v in inputs.items()}
    with torch.no_grad():
        logits = txt_model(**inputs).logits
    probs = torch.softmax(logits, dim=-1).squeeze().tolist()
    idx = int(np.argmax(probs))
    return {"label": id2label_txt[idx], "score": float(probs[idx])}

for it in segment_emotions:
    ts = text_sentiment(it["text"])
    it["text_sentiment"] = ts["label"]
    it["text_sentiment_conf"] = ts["score"]
# Out:
# config.json:   0%|          | 0.00/841 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]

# %%
# ============================
# 7. 감정 라벨 리매핑 (통일 태그)
# ============================
label_map = {
    "happiness": "happy",
    "sadness": "sad",
    "anger": "angry",
    "disgust": "disgust",
    "fear": "fear",
    "surprise": "surprise",
    "neutral": "neutral",
    # 필요시 추가
}

def remap(label):
    if label is None:
        return "unknown"
    l = label.lower()
    return label_map.get(l, l)

for it in segment_emotions:
    it["emotion"] = remap(it["emotion"])

# %%
# ============================
# 8. 전체 요약 + CSV 저장
# ============================
def summarize(items, key="emotion"):
    seq = [it[key] for it in items if it.get(key) and it[key] != "unknown"]
    if not seq:
        return "No clear emotion detected."
    counts = Counter(seq)
    top, cnt = counts.most_common(1)[0]
    preview = " → ".join(seq[:5] + (["..."] if len(seq) > 5 else []))
    return f"Dominant({key}): {top} (count={cnt}). Early trend: {preview}"

print("\n", summarize(segment_emotions, key="emotion"))
print(summarize(segment_emotions, key="text_sentiment"))

csv_path = "/content/drive/MyDrive/output/ser_segments.csv"
Path(csv_path).parent.mkdir(parents=True, exist_ok=True)
with open(csv_path, "w", newline="", encoding="utf-8") as f:
    w = csv.writer(f)
    w.writerow(["start","end","speaker","emotion","confidence",
                "text_sentiment","text_sent_conf","text"])
    for it in segment_emotions:
        w.writerow([
            f"{it['start']:.2f}",
            f"{it['end']:.2f}",
            it.get("speaker", ""),
            it["emotion"],
            f"{it['confidence']:.4f}",
            it.get("text_sentiment",""),
            f"{it.get('text_sentiment_conf',0.0):.4f}",
            it["text"]
        ])
print("Saved:", csv_path)
# Out:
#  Dominant(emotion): sad (count=531). Early trend: sad → sad → hap → sad → hap → ...
# Dominant(text_sentiment): neutral (count=527). Early trend: neutral → negative → neutral → neutral → negative → ...
# Saved: /content/drive/MyDrive/output/ser_segments.csv
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2691130495.py in <cell line: 0>()
#      39     # 상단에 전체 요약 먼저 적기
#      40     f.write("=== Summary ===\n")
# ---> 41     f.write(summary_emotion + "\n")
#      42     f.write(summary_sentiment + "\n\n")
#      43
#
# NameError: name 'summary_emotion' is not defined
