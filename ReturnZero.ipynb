# %%
# ============================
# 0. 구글 드라이브 마운트
# ============================
from google.colab import drive
drive.mount('/content/drive')

# (선택) 드라이브 구조 확인
# !ls -lah /content/drive
# !ls -lah "/content/drive/MyDrive"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# total 16K
# dr-x------ 4 root root 4.0K Nov 24 02:14 .Encrypted
# drwx------ 6 root root 4.0K Nov 24 02:14 MyDrive
# dr-x------ 2 root root 4.0K Nov 24 02:14 .shortcut-targets-by-id
# drwx------ 5 root root 4.0K Nov 24 02:14 .Trash-0
# total 265K
# -rw------- 1 root root  176 Nov 21 02:43 '11 21 헤세드 인적사항 사본.gsheet'
# -rw------- 1 root root  176 Mar 29  2025 '5 11 업데이트 버스킹 Song List 추천.gsheet'
# drwx------ 2 root root 4.0K May  7  2025 'Colab Notebooks'
# drwx------ 2 root root 4.0K Nov 24 02:51  data_MP3
# drwx------ 2 root root 4.0K Nov 13 06:40  data_MP4
# drwx------ 2 root root 4.0K Nov 13 07:30  output
# lrw------- 1 root root    0 Nov 19 02:15  멀티캠퍼스_LLMs_Llama_index -> /content/drive/.shortcut-targets-by-id/1L_SL2y6c8AjDF5Plju0IaQnV4pi-pBmJ/멀티캠퍼스_LLMs_Llama_index
# -rw------- 1 root root 247K Nov 14 08:04  퍼실AI_baseline.ipynb
# -rw------- 1 root root  176 Nov 17 11:01 '헤세드 라인연결 가이드.gslides'
# -rw------- 1 root root  176 Oct 31 03:50 '헤세드 인적사항 복사본.gsheet'

# %%
# ============================
# 1. 패키지 설치
# ============================
# Whisper는 안 쓰니까 제거, 대신 requests만 추가
# !pip -q install moviepy requests
# !pip -q install transformers accelerate librosa soundfile torchaudio

# %%
# ============================
# 2. import
# ============================
import os
from pathlib import Path
import mimetypes
import json
import time
import getpass

import numpy as np
import torch
import librosa
import soundfile as sf
import requests

from transformers import (
    pipeline,
    AutoConfig,
    AutoTokenizer,
    AutoModelForSequenceClassification,
)

from collections import Counter
import csv
import math

# %%
# ============================
# 2-1. 리턴제로 STT 클라이언트 정의
# ============================
class RTZROpenAPIClient:
    """
    리턴제로 파일 STT용 최소 클라이언트
    - /v1/authenticate : JWT 발급
    - /v1/transcribe   : 파일 STT 요청
    - /v1/transcribe/{id} : 결과 폴링
    """
    def __init__(self, client_id: str, client_secret: str,
                 base_url: str = "https://openapi.vito.ai"):
        self.base_url = base_url.rstrip("/")
        self.client_id = client_id
        self.client_secret = client_secret

        if not self.client_id or not self.client_secret:
            raise ValueError("RTZR CLIENT_ID / CLIENT_SECRET가 비었습니다.")

        self._sess = requests.Session()
        self._token = None

    @property
    def token(self) -> str:
        """현재 JWT 토큰을 반환, 없거나 오래되면 /v1/authenticate로 갱신"""
        # expire_at 기준으로 30분 전이면 다시 받기 (공식 샘플과 유사 로직)
        if self._token is None or self._token.get("expire_at", 0) < time.time() - 1800:
            resp = self._sess.post(
                f"{self.base_url}/v1/authenticate",
                data={
                    "client_id": self.client_id,
                    "client_secret": self.client_secret,
                },
            )
            resp.raise_for_status()
            self._token = resp.json()

        access = self._token.get("access_token")
        if not access:
            raise RuntimeError("authenticate 응답에 access_token이 없습니다.")
        return access

    def _auth_headers(self):
        return {"Authorization": f"Bearer {self.token}"}

    def transcribe_file(self, file_path: str, config: dict) -> dict:
        """ /v1/transcribe 로 파일 STT 요청 """
        url = f"{self.base_url}/v1/transcribe"
        with open(file_path, "rb") as f:
            files = {"file": (os.path.basename(file_path), f)}
            data = {"config": json.dumps(config)}
            resp = self._sess.post(url, headers=self._auth_headers(),
                                   files=files, data=data)
            resp.raise_for_status()
            return resp.json()  # {"id": "..."} 형태

    def get_transcription(self, transcribe_id: str) -> dict:
        url = f"{self.base_url}/v1/transcribe/{transcribe_id}"
        resp = self._sess.get(url, headers=self._auth_headers())
        resp.raise_for_status()
        return resp.json()

    def wait_for_result(self, transcribe_id: str,
                        poll_interval_sec: int = 5,
                        timeout_sec: int = 3600) -> dict:
        """폴링하면서 completed/failed 될 때까지 기다렸다가 결과 리턴"""
        deadline = time.time() + timeout_sec
        while True:
            if time.time() > deadline:
                raise TimeoutError("STT 결과 대기 중 timeout")

            result = self.get_transcription(transcribe_id)
            status = result.get("status")
            if status in ("completed", "failed"):
                return result

            time.sleep(poll_interval_sec)

# %%
# ============================
# 3. 입력 미디어 설정 (비디오 or 오디오)
# ============================
media_path = "/content/drive/MyDrive/data_MP3/sample3.mp3"
desired_audio_path = "/content/drive/MyDrive/data_MP3/extracted_audio.mp3"  # 비디오일 때만 사용

def is_audio(path: str) -> bool:
    mt, _ = mimetypes.guess_type(path)
    return (mt or "").startswith("audio")

if is_audio(media_path):
    # 이미 오디오 파일이면 추출 생략
    audio_path = media_path
    print(f"[SKIP extract] Detected audio file. Use as-is: {audio_path}")
else:
    # 비디오면 moviepy로 오디오 추출
    from moviepy.editor import VideoFileClip
    Path(Path(desired_audio_path).parent).mkdir(parents=True, exist_ok=True)
    clip = VideoFileClip(media_path)
    if clip.audio is None:
        raise RuntimeError("이 비디오에는 오디오 트랙이 없습니다.")
    clip.audio.write_audiofile(desired_audio_path)  # 확장자에 따라 자동 인코딩
    clip.close()
    audio_path = desired_audio_path
    print(f"[EXTRACT] Audio saved to: {audio_path}")
# Out:
# [SKIP extract] Detected audio file. Use as-is: /content/drive/MyDrive/data_MP3/sample3.mp3

# %%
# ============================
# 4. 리턴제로 기반 텍스트 인식
# ============================
clean_audio_path = "/content/drive/MyDrive/data_MP3/cleaned_sample.wav"

# 4-1) 오디오 전처리: 16kHz 모노 + 앞/뒤 무음 제거 + 노멀라이즈
y, sr = librosa.load(audio_path, sr=16000, mono=True)
raw_duration = len(y) / sr
print(f"[DEBUG] 원본 오디오 duration = {raw_duration:.2f} s")

# 앞/뒤 무음만 제거 (중간은 건드리지 않음)
y, _ = librosa.effects.trim(y, top_db=30)

peak = np.max(np.abs(y))
if peak > 0:
    y = y / peak

Path(clean_audio_path).parent.mkdir(parents=True, exist_ok=True)
sf.write(clean_audio_path, y, 16000)
audio_for_asr = clean_audio_path

clean_duration = librosa.get_duration(path=audio_for_asr)
print(f"[DEBUG] 정제된 오디오 duration = {clean_duration:.2f} s")

# 4-2) RTZR API 키 입력 (환경변수 우선, 없으면 직접 입력)
if "RTZR_CLIENT_ID" in os.environ and "RTZR_CLIENT_SECRET" in os.environ:
    RTZR_CLIENT_ID = os.environ["RTZR_CLIENT_ID"]
    RTZR_CLIENT_SECRET = os.environ["RTZR_CLIENT_SECRET"]
    print("[INFO] 환경변수에서 RTZR CLIENT_ID/SECRET을 읽었습니다.")
else:
    RTZR_CLIENT_ID = input("RTZR CLIENT_ID를 입력하세요: ").strip()
    RTZR_CLIENT_SECRET = getpass.getpass(
        "RTZR CLIENT_SECRET를 입력하세요 (입력 시 화면에 표시되지 않습니다): "
    ).strip()

client = RTZROpenAPIClient(RTZR_CLIENT_ID, RTZR_CLIENT_SECRET)

# 4-3) STT 설정 (화자 분리 ON)
#   - Somm ers 모델 + GENERAL 도메인 기준
SPEAKER_COUNT = 0  # 0이면 화자 수 자동 추정

config = {
    "model_name": "sommers",          # 또는 "whisper"
    "domain": "GENERAL",              # 회의/콜이면 "CALL" 고려
    "use_diarization": True,          # 화자 분리
    "diarization": {"spk_count": SPEAKER_COUNT},
    "use_paragraph_splitter": True,
    "paragraph_splitter": {"max": 80},
    "use_itn": False,
    "use_disfluency_filter": False,
    "use_profanity_filter": False,
    # 필요하면 옵션 추가 가능 (keywords, use_word_timestamp 등)
}

print("[DEBUG] RTZR STT config:")
print(json.dumps(config, ensure_ascii=False, indent=2))

# 4-4) STT 요청 + 결과 대기
submit_resp = client.transcribe_file(audio_for_asr, config)
transcribe_id = submit_resp.get("id")
print(f"[INFO] STT 작업 ID: {transcribe_id}")

if not transcribe_id:
    print("[ERROR] transcribe_id가 없습니다. 응답 전체:")
    print(json.dumps(submit_resp, ensure_ascii=False, indent=2))
    raise SystemExit

print("[INFO] 결과 대기 중 (5초 간격 폴링)...")
rtzr_result = client.wait_for_result(transcribe_id, poll_interval_sec=5, timeout_sec=3600)

print(f"[DEBUG] RTZR status = {rtzr_result.get('status')}")

# 4-5) RTZR 결과 → Whisper 스타일 segments_to_use로 변환
utterances = rtzr_result.get("results", {}).get("utterances", [])
print(f"[DEBUG] 총 utterance 개수 = {len(utterances)}")

segments_to_use = []
for utt in utterances:
    start_ms = int(utt.get("start_at", 0))
    dur_ms = int(utt.get("duration", 0))
    start_s = start_ms / 1000.0
    end_s = (start_ms + dur_ms) / 1000.0
    text = utt.get("msg", "").strip()
    spk = utt.get("spk", 0)

    segments_to_use.append({
        "start": start_s,
        "end": end_s,
        "text": text,
        "speaker": spk,  # 나중에 화자별 분석용으로 사용 가능
    })

if segments_to_use:
    last_end = segments_to_use[-1]["end"]
    print(f"[DEBUG] 마지막 세그먼트 end = {last_end:.2f} s")

    print("\n[DEBUG] 처음 5개 세그먼트:")
    for seg in segments_to_use[:5]:
        print(
            f"  [{seg['start']:.2f}-{seg['end']:.2f}] "
            f"Speaker={seg['speaker']} :: {seg['text']}"
        )

    print("\n[DEBUG] 마지막 5개 세그먼트:")
    for seg in segments_to_use[-5:]:
        print(
            f"  [{seg['start']:.2f}-{seg['end']:.2f}] "
            f"Speaker={seg['speaker']} :: {seg['text']}"
        )

# 콘솔에 구간별 자막 형태로 출력
for seg in segments_to_use:
    print(f"[{seg['start']:.2f}–{seg['end']:.2f}] (spk={seg['speaker']}) {seg['text']}")

# 전체 텍스트 합치기
full_text = " ".join(seg["text"] for seg in segments_to_use)
print("Full text:\n", full_text)

# 텍스트 파일로 저장
output_txt_path = '/content/drive/MyDrive/output/sample.txt'
Path(output_txt_path).parent.mkdir(parents=True, exist_ok=True)
with open(output_txt_path, 'w', encoding="utf-8") as f:
    for seg in segments_to_use:
        f.write(f"[{seg['start']:.2f}–{seg['end']:.2f}] (spk={seg['speaker']}) {seg['text']}\n")

print(f"\nTranscription saved to {output_txt_path}")
# Out:
# [DEBUG] 원본 오디오 duration = 3951.06 s
# [DEBUG] 정제된 오디오 duration = 3951.06 s
# RTZR CLIENT_ID를 입력하세요: wtVlucULYnE0c0ATqMlq
# RTZR CLIENT_SECRET를 입력하세요 (입력 시 화면에 표시되지 않습니다): ··········
# [DEBUG] RTZR STT config:
# {
#   "model_name": "sommers",
#   "domain": "GENERAL",
#   "use_diarization": true,
#   "diarization": {
#     "spk_count": 0
#   },
#   "use_paragraph_splitter": true,
#   "paragraph_splitter": {
#     "max": 80
#   },
#   "use_itn": false,
#   "use_disfluency_filter": false,
#   "use_profanity_filter": false
# }
# [INFO] STT 작업 ID: 2V1MdYJ1R1-zRV6h_HkaEg
# [INFO] 결과 대기 중 (5초 간격 폴링)...
# [DEBUG] RTZR status = completed
# [DEBUG] 총 utterance 개수 = 441
# [DEBUG] 마지막 세그먼트 end = 3950.15 s
#
# [DEBUG] 처음 5개 세그먼트:
#   [0.53-11.29] Speaker=0 :: 국내 의료계가 또다시 슬렁이고 있습니다. 더블유 티 오 를 중심으로 한 커센 개방의 파고가 그동안 공공제로 분류되어 왔던 의료계에도 숨가쁘게 밀려오고 있기 때문인데요.
#   [12.83-21.44] Speaker=0 :: 국민의 생명과 직접 연계된 이 문제. 정부는 물론 당사자인 의료계도 너무 안이하게 대처하고 있는 게 아닌가 하는 비판이 일고 있습니다.
#   [22.21-32.85] Speaker=0 :: 그래서 오늘 난상 토론에서는 의료서비스의 기본을 다시 한번 고민해 보고 개방협상에 임하는 우리의 대응방안을 심도 있게 고찰해 보도록 하겠습니다. 난상토론 잠시 후에 뵙겠습니다.
#   [33.43-44.49] Speaker=0 :: 먼저 이렇게 자리해 주신 토론자 여러분들께 감사를 드리면서 어 치과의사협회와 한의사협회에서는 협회 내부의 입장이 정리된 관계로 오늘 토론회 이렇게 참석을 해 주셨습니다만 아.
#   [44.49-52.11] Speaker=0 :: 또 그 이외에 국내 의료서비스 분야에는 대안의사협회라든가 대한병원협회, 그리고 대한 간호사협회 등 관련 협회들이 많지 않습니까?
#
# [DEBUG] 마지막 5개 세그먼트:
#   [3905.31-3911.62] Speaker=0 :: 더블유 티 오 전문직 서비스. 시장개방 협상 분야는 크게 변호사와 의료서비스로 요약할 수 있습니다.
#   [3912.27-3921.15] Speaker=0 :: 그런데 법률 서비스의 경우 법무부는 변호사 협회와 이미 오래전부터 작업반을 구성해서 대응택을 철저하게 준비해 온 것으로 알고 있습니다.
#   [3922.07-3930.04] Speaker=0 :: 의료서비스 개방협상이 본격화되고 있는 지금 묻겠습니다. 보건복지부는 관련 협회와 어떤 관계에 서 있습니까?
#   [3930.89-3938.07] Speaker=0 :: 국민의 건강과 생명을 아전인수격으로 해석해서 서로 혹시라도 대립관계에 서 있지는 않습니까?
#   [3938.87-3950.15] Speaker=0 :: 의약분업을 통해서 엄청난 혼란을 겪어야 했던 국민으로서는 심히 걱정하지 않을 수 없는 부분입니다. 의료시장 개방 문제를 짚어본 난상토론. 오늘은 여기서 접겠습니다. 안녕히 계십시오.
# [0.53–11.29] (spk=0) 국내 의료계가 또다시 슬렁이고 있습니다. 더블유 티 오 를 중심으로 한 커센 개방의 파고가 그동안 공공제로 분류되어 왔던 의료계에도 숨가쁘게 밀려오고 있기 때문인데요.
# [12.83–21.44] (spk=0) 국민의 생명과 직접 연계된 이 문제. 정부는 물론 당사자인 의료계도 너무 안이하게 대처하고 있는 게 아닌가 하는 비판이 일고 있습니다.
# [22.21–32.85] (spk=0) 그래서 오늘 난상 토론에서는 의료서비스의 기본을 다시 한번 고민해 보고 개방협상에 임하는 우리의 대응방안을 심도 있게 고찰해 보도록 하겠습니다. 난상토론 잠시 후에 뵙겠습니다.
# [33.43–44.49] (spk=0) 먼저 이렇게 자리해 주신 토론자 여러분들께 감사를 드리면서 어 치과의사협회와 한의사협회에서는 협회 내부의 입장이 정리된 관계로 오늘 토론회 이렇게 참석을 해 주셨습니다만 아.
# [44.49–52.11] (spk=0) 또 그 이외에 국내 의료서비스 분야에는 대안의사협회라든가 대한병원협회, 그리고 대한 간호사협회 등 관련 협회들이 많지 않습니까?
# [52.58–61.99] (spk=0) 아, 오늘 이 자리에 저희가 출연 요청을 드렸지만, 협회 측 사정상 아, 이 자리에 나오지 못하셨습니다. 이 점 양해의 말씀을 구합니다. 예, 뭐.
# [61.99–70.48] (spk=0) 앞서 모두에서 보셨던 것처럼 그 의료시장 개방 협상이 본격화되고 있습니다. 아, 이번 협상을 이 자리에 오신 토론자분들께서는 어떻게 보고 계신지?
# [71.19–79.79] (spk=0) 노 박사님께서는 아무래도 그 병원 경영자 입장에서 말이죠. 이번에 진행되고 있는 그 더블유 티 오 의료시장 개방협상을 어떻게 보고 계시는지요?
# [80.50–89.05] (spk=1) 에 개방 협상이 만약에 개방 쪽으로 결론이 난다고 할 것 같으면 아마 가장 큰 영향을 받는 게 병원 분야인 것 같습니다.
# [89.80–106.98] (spk=1) 병원은 그 병원 운영 자체뿐만 아니라 그 속에 구성원들이 의사 간호사, 그리고 또 병원 행정서비스. 그 외에 또 전산망이라든지 이런 여러 가지들이 다 동시에 개방되는 그런 우려가 있기 때문에.
# [107.54–117.56] (spk=1) 그거에 의해서 아마 병원계에 승자와 패자가 갈라지는 그러한 굉장한 위험성도 내포하고 있다고 생각해서 예의 주시하고 있는. 상태입니다.
# [117.72–131.00] (spk=0) 예, 천 박사님 뭐 한의사 분들도 어 더블유 티 오 시장 개방에 관한 어떤 입장이랄까요, 이것이 참 남다를 것 같은데요. 어떻게 이 협상을 준비하고 계신지요? 예, 뭐.
# [131.00–142.10] (spk=2) 저희들은 구십 년대 초부터 한의학의 세계화를 주창을 하고, 세계 각국의 한의학을 보급하기 위해서 상당히 노력을 해 왔습니다만. 막상 이제 시장 개방이라고 하는 문제가 현실적으로 닥치니까.
# [142.52–153.81] (spk=2) 회원들의 여론은 지금 두 가지로 나옵니다. 젊은 층을 중심으로 적극적으로 해외시장을 개발해야 된다는 입장과 또는 저 보수적인 입장에서 국민 건강의 어떤 그런 수준을 유지하기 위해서.
# [154.17–162.60] (spk=2) 어떤 그 개발? 도상국에서 우리나라로 유입되는 인력에 대해서는 상당한 경계를 가지고 어 주의를 기울여야 된다는 두 가지 입장이 나오고 있습니다.
# [162.98–173.74] (spk=2) 더군다나 이제 한의학이라고 하는 이제 분야가 우리나라에는 한의사 제도가 있지만, 선진제국에는 한의사라고 하는 제도 자체가 없기 때문에. 어떤 그 한의사라고 하는 제도.
# [173.90–183.15] (spk=2) 분류 코드 자체를 유엔에서 좀 만들어줘서. 한의사들의 친구사가 아닌 또 다른 유사. 의료업자가 아닌 의료인으로서 각국의 진출할 수 있는 어떤 이런?
# [183.15–193.83] (spk=2) 이제 국제 협상을 통해서 지위를 보장받아야 되겠다는 입장도 있고, 또 이제 한의학은 좀 특수적으로 국내적인 기반이 상당히 취약합니다. 관련 법규가 여러 가지로 미배한 점이 많기 때문에.
# [194.13–203.12] (spk=2) 이번 더블유 티 오. 어떤 협상을 통해서 국내 법령을 좀 정비해서 한의학이 새롭게 도약할 수 있는 기회로 마련하자는 지금 준비를 열심히 하고 있습니다.
# [203.15–209.67] (spk=0) 네, 안 교수님, 교수님께서는 대학교 교수이기도 하시지만, 동시에 성형외과 전문의이신 걸로 알고 있습니다. 그렇습니다.
# [209.86–220.15] (spk=0) 아, 의사의 입장에서 어, 또 병원 경영자와는 좀 다른 뭐랄까 입장이랄까, 의견을 갖고 계실 것도 같은데. 더블유 티 오 개방 협상을 의사 입장에서는 어떻게 보고 계시는지요?
# [221.16–232.63] (spk=3) 우선 제 사견으로는 지난 한 세기 동안, 아니 한 세대 동안 삼십 년 동안 우리나라 발전의 근간은 결국은 교역이 아니었지느냐. 우리가 그것을 근간으로 해서 이때까지 발달했고.
# [233.11–240.69] (spk=3) 또 의학을 보더라도 우리나라 의학의 수준이 올라간 것은 어떤 형태든 간에 교류를 통해서 여기까지 올라온 것입니다.
# [241.40–248.61] (spk=3) 그래서 결국은 더블유 티 오 가 이제 전 세계에서 피할 수 없는 대세이고, 또 그것을 원치 않는다 하더라도.
# [249.03–257.30] (spk=3) 와이 투 케이처럼 가장 최악의 상황을 미리 대비해야 되기 때문에 저는 개방을 전제로 두고 거기에 대비해야 된다고 생각이 됩니다.
# [257.43–266.60] (spk=0) 예, 이 박사님 예, 어 치과 의사도 어 참 뭐랄까 준비가 참 필요한 부분이 아닐 수 없을 것 같고요.
# [267.22–273.60] (spk=0) 또 그 거센 개방의 파도에 맞서서 국내적으로, 또 국제적으로 여러 가지 그 상황을 예의 주시하고 계신 걸로 알고 있는데.
# [273.94–279.95] (spk=0) 치과회사 협회는 이 더블유 티 오 개방에 관하여서 어떻게 준비를 하고 있고, 또 어떤 입장이신지가 궁금합니다.
# [281.22–296.48] (spk=4) 어 치과 의료라는 것은 좀 어 타과에 비해서 약간 그 의료의 차이점이 있습니다. 그 어 환자와 대면에서 직접 모든 시간을 의사가 시술하고 환자 모든 시간을 같이 하는 아 좀.
# [296.51–309.53] (spk=4) 의류의 특수성이 있는 분야가 치과 분야입니다. 아, 그래서 아마 어, 이 토론회를 보시는 분들 중에서 치과를 많이 그 당기셨던 분들은 어 아마 기대반 또 어 기후반.
# [309.53–317.06] (spk=4) 이런 아마 시청자분들도 아마 그런 기분을 가지고 계실 텐데, 저희 치과의사들도 마찬가지입니다. 지금 아직까지는 혼란스럽고요.
# [317.56–328.01] (spk=4) 어 또 어 서비스 분야가 그 성격이 짙은 분야이기 때문에 저희 치과의사들도 상당히 혼란스럽지만 지금 우려가 깊어지는 그런 분위기인 것 같습니다.
# [328.01–341.18] (spk=4) 그래서 어 일단은 어 치과 특수 분야에 있어서 어 몇 가지 좀 가로막고 있는 그 장애물들이 있습니다. 그런 거가 좀 치워지지 않는 한은 개방에 좀 회의적이지 않은가. 예, 그런 분위기인 것 같습니다.
# [341.35–341.75] (spk=4) 예.
# [342.49–350.06] (spk=0) 그래서 지금까지 네 분 토론자께서는 아무래도 그 병원 경영자라든가 또는 이제 의사 한의사, 치과의사 입장에서 말씀해 주셨는데.
# [350.49–358.84] (spk=0) 사실 그런 어떤 그 의료 담당자의 어떤 입장도 중요하지만, 아, 국민의 입장에서 생각하는 부분도 상당히 중요하지 않을 수 없고요.
# [359.21–362.65] (spk=0) 그런 측면에서 오늘 토론은 여기부터 시작해보면 어떨까 싶습니다.
# [362.65–372.48] (spk=0) 아, 과연 이 의료서비스라고 하는 것이 공공제로서의 어떤 성격을 계속해서 강조해야 할 것인지, 아니면 이 분야에 관하여서 소위.
# [372.48–384.12] (spk=0) 그 시장경제 원리를 도입을 해서 어떤 서비스의 질적 개선을 좀 도모해야 할 것인지 제 이 부분에 관한 논의로 시작을 했으면 좋겠는데. 왕 교수님, 교수님께서는 아무래도 경제학자이시고 따라서.
# [384.18–392.81] (spk=0) 의료서비스의 어떤 그 질적 개선을 위하여서 어떤 시장경제 원리의 도입에 찬성하시는 입장이신 걸로 알고 있는데 어떻습니까?
# [392.81–398.49] (spk=0) 인제 그 의료서비스 분야가 공공재로서의 성격을 계속해서 유지해야 할 걸로 보십니까? 어떻습니까?
# [400.14–411.59] (spk=5) 에 공공제라는 것실. 은행도 공공업인데 공공적인 성격이 큰데 은행은 다 열해야 된다고 나 지금 다 그렇게 합의를 보았습니다. 이거 이것도 마찬가지입니다.
# [411.95–421.48] (spk=5) 우리가 적은 비용으로 보다 질 좋은 서비스를 어떻게 하면 제공하느냐 이거든요. 그런데 우리나라 지금 의료서비스는 완전히 사회주의적인 에 제도 의료제도입니다.
# [421.83–440.00] (spk=5) 그러니까 수가도 병원 수가도 정해놓아가지고, 병원 대학 큰 병원들이 이익을 남기지 못하고 의사 의사 중요한 뭐 저 심장의과라든가 중요한 그 뇌라든가 이런 데는 지금 삼 디 업종으로 돼 가지고 의사들이 가질 않고 이게 저기 가격 체계가 맞지 않아서 그래요.
# [440.00–443.89] (spk=5) 인센티브 유인 유인과 경쟁 체제가 안 되어 있다는 이겁니다.
# [443.89–458.22] (spk=5) 그래서 그 시장경제로 해야 되고, 특히 또 소비자들은 또 이 다양한 것을 선택할 수 있고, 또 어 또 이 딴 것은 이제 이제 포기하더라도, 또 돈은 많이 들더라도 보다 질이 높은 서비스를 원하는 사람들이 많습니다.
# [458.56–468.50] (spk=5) 그래서 그런 걸 제공하는 것이 이 자본주의과고, 그리고 경쟁과 유인이 없으면은 인센티브 제도가차 없으면은 이 사회가 잘 발전을 하지 않습니다. 의료제도 마찬가지라고 봅니다.
# [469.30–474.01] (spk=0) 인센티브 제도를 강조하셨는데요. 홍 교수님, 홍 교수님께서도 그와 같은 입장에 찬성하시는지요?
# [474.42–487.77] (spk=6) 어, 지금 그 어, 여기 그 어, 그 이 그 의료시장 개방이라고 하는 데 대해서 어 국가가 참으로 인제 그 의사 선생님들이라든가 병원분이라든가 어. 굉장히 걱정을 많이 하시는데.
# [488.26–498.13] (spk=6) 불행하게도 철학계는 거기에 대해서 아무런 준비가 안 돼 있다고 얘기를 우선 드려야 되겠고요. 어, 그렇지만은 이제 그 조금 어 근본적으로 생각해 볼 때 어.
# [498.13–509.23] (spk=6) 제가 볼 때는 이 논의의 그 저기 패턴 자체가 굉장히 마음에 안 들어요. 왜냐하면은 어, 의료시술을 베푸는 분들이라든가 전문가들한테만 자꾸 그 걱정스러운 눈길을 던지지.
# [509.64–516.11] (spk=6) 정작 의료 서비스를 받아야 하는 환자나 국민 입장에서 어떻게 생각하는지는 지금 전혀 묻고 있지 않다. 이겁니다.
# [516.75–523.39] (spk=6) 어, 실질적으로 그 아까 우리 왕 선생님께서 우리 그 나라가 그 의료서비스 체계라든가 이런 게 인제.
# [523.39–534.77] (spk=6) 사회주의다, 이렇게 뭐 여러 가지 이렇게 얘기를 하셨지만은 어 우선 가장 먼저 그 의료서비스의 그 출발점은 우선 죽건 어 죽음의 그 위기에 처해 있거나.
# [534.80–543.77] (spk=6) 아니면 고통에 처해 있는 사람들이 의료 시술을 에 그 의료 서비스에 접근할 수 있느냐, 없느냐. 이것이 서비스의 제 일, 차적인 조건이라고 생각합니다.
# [544.32–557.37] (spk=6) 그렇다고 한다면은 과연 의료시장 개방이 이와 같은 환자들 또는 의료를 필요로 하는 사람들의 접근 가능성을 갖다가 과연 높이느냐, 낮추느냐 하는 이 부분부터 얘기를 시작해야 되는데.
# [557.71–570.95] (spk=6) 제가 볼 때는 의료서비스를 그 기술을 독점하고 있는 분들은 걱정을 해도 거기에서 이제 실제 질병을 고쳐야 한다든가 이 그 수금의. 위기에서 벗어나야 할 분들의 안부는 전혀 안 묻는 것 같아요.
# [570.95–581.97] (spk=6) 굉장히 섭섭하다는 생각이 듭니다. 그런 점, 그런 점에서 제가 볼 때는 일단은 뭐가 되는가 하면은 이게 그 인센티브다. 뭐다 하기 이전에 국민의 그 직접적인 생명과 그니까.
# [582.01–591.15] (spk=6) 의료의 존립 근거에 대해서부터 먼저 생각을 해서 그걸 기초로 해서 다른 분야를 좀 생각을 하면은. 저는 아주 문제는 간단하게 풀릴 수 있다고 생각합니다. 저희가 이.
# [591.20–594.00] (spk=0) 자리에 홍 교수님을 모신 이유가 바로 거기에 있지 않겠습니까?
# [594.41–600.83] (spk=0) 아무그래도 환자 입장에서 또는 철학자 입장에서 좀 다양한 목소리를 수용하기 위해서 홍 교수님 모신 거고요, 저도 그렇습니다, 말씀하십시오, 왕 교수님.
# [601.20–603.29] (spk=5) 아, 저도 그 소비자 입장에서 말씀드리겠습니다.
# [603.33–610.20] (spk=0) 네, 뭐 지금 홍 교수님께서 어 좀 제의하신 문제에 관하여서 왕 교수님께서는 어떻게 생각을 하시는지 뭐.
# [610.20–621.73] (spk=0) 의료서비스와 관련하여서 인센티브의 재를 도입해야 된다라는 입장보다는 일단 그 근본적으로 어 이 시장개방 협상이 국민의 입장에서 어떻게 받아들여져야 할 것인가라는 문제를 제기해 주셨는데.
# [622.58–631.80] (spk=5) 소비자 입장에서는 어, 그 기본적인 거, 아주 기본적인 거. 그런 것은 이제 정부에서 제공하고 또 기본적인 저 어, 그 의료보험, 공공의료보험으로 제공하고.
# [631.96–641.04] (spk=5) 또 고급 서비스 이런 것은 역시 그 좀 다양한 이런 어 서비스를 위해서 개방이 되어 지 않냐 그겁니다. 그러니까 우리 두 가지로 나눠야 될 것 같아요.
# [641.08–645.84] (spk=5) 아주 기본적인 거, 그러니까 가난한 사람한테는 정부가 어 나눠주지 않습니까?
# [646.18–655.99] (spk=5) 음식, 음식들을, 그리고 또 어, 그런 그런 아주 기본적인 것이 있는 사람들은 그 외에 인제 돈 주고, 사서 먹고 마찬가지로 의료서비스도 그렇게 에 다뤄야 된다고 생각합니다.
# [656.36–662.77] (spk=6) 그 점에서 인제 제가 조금 우려를 표명하는 것이 이런 게 있습니다. 어, 실질적으로 그 저기 뭡니까?
# [662.77–671.60] (spk=6) 국민들한테 그 정부가 많은 걸 나눠준다, 이렇게 인제 얘기를 하시는데 어 가령 예를 들어서 먹을 걸 나눠주는 데는 전문가의 개입이 그렇게 필요하지 않습니다.
# [672.04–681.60] (spk=6) 근데 인제 그 지금 현재 이 의료시장 개방 문제를 놓고 어 그 소위, 그 그 의료 분야에 다섯 개 이익 단체들이 움직이기 시작을 했는데요.
# [682.10–694.51] (spk=6) 어, 제가 그걸 갖다가 자세하게 추적을 하지는 못했습니다마는 어 대체로 제가 봤을 때 모든 그 그 협회라든가. 의사협회, 병원협회, 간호사협회 등등 모든 협회가 어.
# [694.54–702.41] (spk=6) 의료인 전문가들이 존립 자체를 최우선적으로 생각을 하고 있다는 겁니다. 그리고 무엇보다도 그 이 의료서비스 같은 경우는.
# [703.05–713.80] (spk=6) 전문가들이 개입이 없으면은 정부가 그것을 아무리 의지를 갖고 있더라도 국민들한테 그 서비스를 베풀 수 없다는 굉장히 경직되고 비탄력적인 성격을 뛰고 있다는 거죠.
# [714.26–721.56] (spk=6) 이랬을 때 제가 볼 때는 이런 부분들이 또다시 말하자면은 의료, 그 그 재작년에 그 의료 대란이라든가.
# [721.63–729.88] (spk=6) 어느 면에서는 인류 역사상 초유의 의사총파업이라고 하는 그런 악몽 같은 시절을 저희가 겪었습니다마는 그런 부분에 있어 갖고.
# [729.88–736.73] (spk=6) 과연 이것이 또다시 어 그 저 외국시장 외국의 경쟁으로부터 보호한다는 명목 하에 또.
# [736.76–743.11] (spk=6) 의사분들이라든가 하는 이런 전문가 독재 형태로 나타나지 않을까 하는 우려를 어, 저로서는 그 지울 수가 없다는 겁니다.
# [743.83–761.29] (spk=1) 거 의료인 입장에서 좀 말씀을 드리겠어요. 우선 그 우려하실 필요가 전혀 없다는 겁니다. 지금 문제는 의사도 국민을 위해서 존재하는 겁니다. 의사가 된 이상 어떤 사람이 조금 사람 중에 조금.
# [761.29–771.76] (spk=1) 탤런트가 의학 쪽에 있어 가지고 사람을 생명을 지키는 데 너가 직분을 주어서 이렇게 하는 거란 말이죠. 그니까 국민 없이 의사끼리 살 수가 없는 거죠.
# [772.12–783.75] (spk=1) 그러니깐 국민을 위하다는 점에서는 의사에서 한 번도 벗어난 적이 없습니다. 또 정부도 국민을 위해서 존재하는 겁니다. 또 그니까 원래 존재하는 가치는 국민입니다.
# [784.07–792.35] (spk=1) 근데 지금 문제는 국민이 불만을 표시하고 있습니다. 의료에 대해서 대단히 불쾌하다 이 말이죠. 또 의사도 마찬가지로.
# [792.53–799.49] (spk=1) 이 의료에 대해서 굉장히 우리가 좋은 진료를 하고 싶은데, 뭔가 걸림돌이 많아서 제대로 안 되고 있다고 불만을 내세우고 있습니다.
# [799.95–813.42] (spk=1) 정부는 정부대로 돈이 너무 많이 들어서 좀 싸게 공급을 국민에게 하고 싶은데 안 되고 있다고 그다. 모든 이 나라를 구성하고 있는 이 세 삼 자가 모두 반 이 불만에 차 있단 말이죠.
# [813.67–826.44] (spk=1) 이거는 뭐냐면 의사의 잘못도 아니고 정부의 잘못도 아니에요. 시스템의 잘못이에요. 그러니깐 우리 마음의 심성은 환자를 어떻게든 생명을 지키고 건지고 살리는 일에 몰두하고 있어요.
# [826.85–839.25] (spk=1) 그거에 대해서는 개방이 되든 안 되든 돈을 받든 안 받든 우리는 그거는 틀림없이 해요. 그러니까 그걸 염려하는 게 아니라 다만 그걸 어떻게 효율적으로 하는 것이 시스템에 적합하냐.
# [839.79–851.10] (spk=1) 그것이 개방 체제가 시스템에 적합하냐. 아니면 클로즈드 그니까 폐쇄된 뭐 대원군 시절로 돌아가서의 체제가 더 합리적이냐 이런 얘기를 하자는 거지.
# [851.64–855.36] (spk=1) 우리가 근본적으로 국민을 외면하고 살 생각은 한 번도 해본 적이 없습니다.
# [855.36–860.39] (spk=6) 저도 그 주관적인 동기에 있어서는 그 저기 선의 동기를 전혀 의심하지는 않습니다. 병원의.
# [860.39–872.55] (spk=1) 존재 가치도 없어져도 좋다는 겁니다. 다만 국민이 건강하면 병이 없다면 병원이 있을 이유가 없죠. 레저타운이 많아지면 되죠. 건강하지 않기 때문에 있는 거죠, 교님.
# [872.55–878.87] (spk=3) 말씀하시 조금 바로잡을 게 있어서 아까 세계 역사 초위의 파업이라고 말씀하시는데.
# [879.71–889.37] (spk=3) 실제로 일본에서도 이보다 더 극심한 파업이 있었고, 그것은 의권이 침해 당했을 때 전문가 집단으로서 표현할 권리는 있습니다. 그다고 보고 예.
# [889.55–896.88] (spk=3) 또 제가 레지던트를 캐나다에서 했는데, 천 구백, 팔십 육 년, 캐나다, 온타리오주 전체 한 달간 파업을 했었습니다.
# [897.23–898.41] (spk=6) 근데 전국적이지는 않았죠.
# [898.50–909.83] (spk=3) 전국적이지 않고 그거은 국가의 개념이 희박한 나라기 때문에 그렇게 될 수가 없고. 그 나라에서 천 구백, 육십 칠 년에 또 그 아, 그게 마니터버 주에서 또 한 달 동안 파업을 한 적도 있고.
# [910.31–918.72] (spk=3) 그다음에 이스라엘에서도 최근에 파업을 한 적이 있었고, 프랑스에서는 가장 최근에 파업을 할까 말까 하다가 정부에서 조치를 바꾸는 바람에. 유보된 적이 있습니다.
# [919.33–929.88] (spk=3) 우리 의사들이 환자 이익을 위해서 정부가 잘못한다고 그럴 때 그것이 대화로서 해결이 안 될 때는 정 그 분위기 자체가 그렇게 만들은 것입니다. 우리가 하고 싶어서 한 게 아니라.
# [930.80–939.11] (spk=2) 어, 저희들이 물론 이제 의사고 전문직이지만은 지금 이제 노 박사님께서도 말씀하셨지만 국민을 위해서 존재한다는 입장에서.
# [939.56–946.67] (spk=2) 어떤 그 이 더블유 티 오 서비스 협상 개방이라고 하는 어떤 이면을 우리가 한번 좀 고찰를 해 볼 필요는 있다고 봅니다.
# [947.09–958.91] (spk=2) 이게 물론 세계적인 기준을 마련하고 자유무 무역 거래를 이제 활성화시키고 해서 전 전 세계 시민이 다 같이 발전할 수 있고. 혜택을 고루 누를 수 있다고 하는 좋은 어떤 취지가 있지만.
# [959.25–968.96] (spk=2) 또 다른 측면에서는 그 안티 더블유, 티 오 라는 어떤 그룹에서 활동하는 걸. 제가 이렇게 보니까 이것이 어떤 그런 좋은 미명하에 어떤 그.
# [968.96–976.26] (spk=2) 선진국의 다국적, 초국적 기업들의 어떤 기업 활동을 보장하기 위한 어떤 각국이 갖고 있는 규제를 철폐하는 쪽에서.
# [976.63–981.27] (spk=2) 어떤 이용이 악용이 될 수 있는 소지도 있다는 점에서 우리가 충분히 주의를 하셔야 되고.
# [981.67–990.86] (spk=2) 이 개방이라고 하는 어떤 이런 서비스 수준이 향상되고 질이 높아지고 하는 문제가 있지만, 거기에 따르는 필연적인. 어떤 재정의 악화 문제는 우리가 고려를 하셔야 되고.
# [991.14–997.00] (spk=2) 결국 재정 부담이 늘어난다는 것은 곧바로 국민들 부담으로 이어지게 되고, 국가 재정에 또 위험을 줄 수 있기 때문에.
# [997.38–1008.01] (spk=2) 우리가 어떤 각 직역 간의 의사든, 한의사든, 치과의사든, 간호사든, 각 직위역 간의 어떤 이런 어 이익보다는 국가적으로 재정위기라든지 의료의 질을. 어떻게 관리를 하고.
# [1008.19–1015.37] (spk=2) 정말로 국민들이 세계적 수준의 어떤 서비스를 받을 수 있는가에 대해서 우리가 좀 관심을 어 가지고 연구를 많이 해야 된다고 생각하는 것입니다.
# [1015.37–1016.46] (spk=0) 왕 교수님 네.
# [1016.91–1029.20] (spk=5) 그게 가장 중요한 건 이 질이 문제지 않습니까? 우리도 제 어느 정도 사니까 질이 문제인데, 이게 이제 과거 역사상 쫙게 좀. 연구한 바에 의하면 질은 경쟁이 없으면 질이 안 된 질이 높아지지 않는다.
# [1029.25–1033.94] (spk=5) 그겁니다. 그래서 이 우리나라 이제 제조업보다도 서비스업이 많이 낙후돼 있어요.
# [1034.03–1046.07] (spk=5) 서비스업이 그 여러 가지 저 외국하고 비교해 보면은 뭐 은행도, 교육도 뭐 교육평준화니 뭐 저 어 교육 수준이 많이 낙후돼 있어요. 정치니 이런 게 외국과 경쟁이 자동차 같은 거 뭐.
# [1046.07–1053.02] (spk=5) 전자 삼성전자 이런 건 경쟁이 잘 되니까 발전하는데 외국 수준을 따라가는데 이건 경쟁이 없으면 그냥 그대로 낙후된 사회 있단 말입니다.
# [1053.02–1061.02] (spk=5) 그러면 경쟁하면 금방 우리가 올라 올라잡을 수 있고, 또 우리가 재정부담은 늘어나는 건 당연히고. 우리도 우리 우리 자본과 우리우, 의류, 어 기관.
# [1061.53–1073.89] (spk=5) 또 의사들이 또 외국에 가서 또 일할 수 있기 때문에 그건 그게 재정부담이라고 할 수만도 없는 것입니다. 그리고 또 매년 일 조 원 이상씩 또 리 저 예, 그런 비용이 이미 든다고 하지 않습니까?
# [1073.93–1080.92] (spk=5) 사람들이 해외에서 진료를 받으니까 그런 사람들이 여기서 어 받으니까 의 그런 뭐 큰 부담이 되는 것도 아니죠, 어떻게 보면?
# [1080.92–1088.88] (spk=2) 좋은 측면에서는 뭐 부담없이 잘 해결할 수도 있지만은 실제로 외국 외국의 어떤 자본이 투입이 돼 가지고. 병원이 고급화가 되고.
# [1089.11–1095.88] (spk=2) 또 고급 의료 의료장비들이 수입이 되고, 또 고가약재가 들어오고 이랬을 경우에는 이것이 재정 부담으로 늘어날 수가 있거든요.
# [1096.06–1109.52] (spk=2) 그래서 지금 정부에서도 대응을 하는 것이 지금 우리가 지금 현재 우리나라 의료보험 체제는 이게 건강보험의 의사들이 강제로 당연히 가입을 하게 돼 있지만, 이것이 인제 외국에서 요구할 때는 지금 우리나라 공공.
# [1109.79–1114.88] (spk=2) 그런 이제 말하자면 건강보험 가지고는 사실 이익이 발생할 수가 없습니다.
# [1115.05–1122.63] (spk=2) 그럼 이 사람들이 지금 요구하는 것이 사보험을 요구한다든지 이런 부분에 대해서는 당연히 우리 어떤 국민들의 부담이 늘어난다고 보셔야 되겠고요.
# [1123.78–1131.82] (spk=1) 의견 다릅니다. 천선생님 말씀하시는데 그 외국에 개방하면 의료비가 늘어난다고 그러는 게 지금 저는 이해가 잘 안 가요.
# [1132.48–1142.67] (spk=1) 그러니까는 외국이 들어온다고 해서 경쟁이 치열해지면 더 싸질 수도 있는 거예요. 네, 지금 외국의 약도 선생님 한번 생각해보세요.
# [1143.41–1156.21] (spk=1) 우리는 싼 약을 위해서 처방하는 게 환자한테 도움이 안 된다고 생각하면 할 수 없어요. 이 세상에 건강을 위해서는 이 세상에 가장 좋은 거를 최선을 그 환자에게 하는 것이 의사의 본분이에요. 그죠.
# [1156.65–1164.62] (spk=1) 그러니까 이 세상에 한국이 없더라도 미국 땅에 있는 의료보면 그것이 가장 이 환자에게 적절하다고 생각하면 우리는 그걸 제공하고 싶어해요.
# [1165.36–1174.80] (spk=1) 다만 그것은 미국 사람 손에 하면 비용이 많이 드실 거예요. 그러나 우리 손에 의해서 하면 훨씬 싸게 할 수도 있고, 교육받아서 하면 그거 해요.
# [1175.17–1187.48] (spk=1) 그러니깐 저는 이 의료비가 상승한 것이 우리 의사들은 병도 똑같이 생기고 우리가 돈 더 갖지도 않았는데, 갑자기 돈이 낭비가 많아졌어요. 이런 낭비 요인들은 우리 전문가들이 같이 해야 돼요.
# [1187.53–1200.76] (spk=1) 시스템의 잘못이지, 우리 본성의 잘못이 아니에요. 네, 어딘가 약국에 갔든 한의사에 갔든 어딘가에 루수된 이렇 낭비된 요소가 있어요. 저는 그건 눈에 보여요.
# [1201.00–1212.61] (spk=1) 그렇지만 그것을 개선하는 데 우리가 적극적인 노력을 안 하는 거지. 우리가 개방했다고 해서 보다 싼 값의 양질의 진료를 제공할 수 있겠다는 확신이 있기 때문에 말씀을 드리는 거예요.
# [1213.17–1224.83] (spk=6) 그 그 점에 대해서 저는 그 아까 왕 선생님 말씀도 그렇고 그 노원장님 말씀도 그렇고 어 어떤 특정 분야에 있어서 경쟁을 통해서 비로소 질적인 그 그 상승이 이루어지고.
# [1225.32–1234.94] (spk=6) 그리고 그다음 그런 개방을 통해 갖고 보다 나은 그 처방을 받을 수 있다라고 하는 그 점에 있어서는 어 저도 시장경제를 신봉하는 입장에서 아주 전적으로. 찬성을 드립니다.
# [1235.53–1245.63] (spk=6) 중요한 것은 뭐가 되는가 하면은 이 그 저기 생명 현상이라고 하는 것이 어. 소위 말해서 일반적인 어떤 소비상품과는 다른 대상이 된다는 겁니다.
# [1246.08–1262.83] (spk=6) 그리고 또 중요한 것은 뭐가 되는가 하면은 어, 우리 원장님의 저는 앞으로 원장님, 그 경영하시는 병원에 꼭 가겠습니다마는 어 가령 그 환자에게 가장 좋은 약이라 할지라도 환자가 부담할 능력이 없으면은 쓸 수 있게 됩니까?
# [1262.83–1272.68] (spk=6) 못 쓰게 됩니까? 저는 그걸 여쭤보고 싶습니다. 써야 됩니다. 써야 되는데 지금 현재 몇 가지 지금 그니까 시스템 문제가 나왔을 때 네, 제가 볼 때는 소비자 입장에서 또는 제가.
# [1272.68–1278.86] (spk=6) 그 항상 그 그 그 의사 선생님들의 도움을 필요로 하는 입장에서 얘기 드릴 때 병원에 가기가 두려워요.
# [1278.90–1288.50] (spk=6) 왜 그런가 하면은 만약에 내가 나한테 내 재정으로서 부담할 수 없는 처방이 내려졌을 때, 그럴 때 나는 어떻게 해야 되느냐에 대해 갖고.
# [1288.54–1298.21] (spk=6) 병원 현재 우리나라 시스템에서는 가령 의사 선생님들이 마인드라든가, 아니면은 그 보험체계라든가 어디에서도 거기에 대한 답을 들을 수가 없거든요.
# [1298.63–1306.47] (spk=6) 그래서 결국은 뭐가 되는가 하면 진단조차 혹시 큰 병 진단 나지 않을까. 뭐 이런 두려움들을 저뿐만 아니라 많이들 갖고 있다고 생각을 합니다.
# [1306.74–1314.85] (spk=6) 그러니까 시스템의 얘기를 한다고 했을 때 단지 어떤 의약품이라든가 하는 이런 어떤 물질적 요인만이 아니라 생명이라고 하는.
# [1314.85–1327.08] (spk=6) 그러니까 상품화할 수 없는 그 부분에 대한 일종의 그 그 존엄성이 기본적으로 갖추어진 위에 이 시스템이 짜여져야 되느냐, 아니면 병원의 영리라든가 이런 걸 중심으로 해서 시스템이 짜여져야.
# [1327.08–1340.05] (spk=6) 되느냐에 대해 갖고 조금은 이제 우리가 좀 우리나라 그 의료 체계나 의료 전달체계를 생각을 할 때 어, 그 말하자면은 좀 이게 지금 이 시장 개방을 계기로 해서 좀 근본적으로 해야지.
# [1340.32–1350.32] (spk=6) 나중에 그 저쪽에서 들어올 때 어. 우선 첫째, 결국은 시장 개방 문제의 그 가장 큰 문제는 누가 소비자를 갖다가 어 그 잡느냐 하는 문제. 아니겠습니까?
# [1350.59–1361.48] (spk=6) 그럴 때 제가 볼 때는 과연 한국의 의사분들이 그 한국 의사들을 필요로 하는 의료소비자들이 지지를 받고 있는지에 대해서는. 그리고 굉장히 의심이 된다는 거죠.
# [1361.48–1371.86] (spk=6) 인제 그런 점에서 우리 의사 선생님들이 그동안에 어느 면에서는 어, 그 사적인 경, 그 소유 위주로 해왔던 그 우리 의료 시스템에 상당 부분을 각.
# [1371.86–1379.54] (spk=6) 그 저기 이익 단체들이 서로 벽을 헐고 뭐가 문제인가를 갖다가 국민들 앞에 좀 투명하게 공개를 해줬으면 좋겠습니다. 보면 그와 관련해서.
# [1379.54–1387.77] (spk=0) 사회자가 잠깐 정리해 말씀을 드리면은요. 국민의 생명과 건강이 궁극적인 목적이라는 데 대하여 저는 뭐 각 협회나 정부 어느 누구도 이견이 없으리라고 생각을.
# [1387.77–1388.75] (spk=6) 합니다 론은요?
# [1390.18–1403.76] (spk=0) 문제는 다만 그것을 구현하는 그 방법이랄까, 그 시스템적인 측면에 있어서 과연 그 공공성이라고 하는 성격을 강조해서 어, 계속해서 그 시스템을 구축해 나갈 것인가, 아니면 그 시스템 또는 수단이라고 하는 것을.
# [1403.79–1410.28] (spk=0) 시장 경제 원리를 도입해서 어, 어떤 그 질적 개선을 도모할 것이냐라고 하는 방법적인 차이 아니겠습니까, 근데.
# [1410.28–1413.68] (spk=6) 공공성과 시장성이 그렇게 충돌한다고는 저 생각하지는 않습니다.
# [1413.92–1416.17] (spk=0) 하지만 구체적으로 충돌되는 부분이 나타나고 있는.
# [1416.96–1425.06] (spk=3) 예, 하고 있는 것 같은데요. 말씀하신 거는 지금 제도하에서도 공공성이 보장되지 않고 있다라고 말씀하셨습니다. 저로서는 그런.
# [1425.06–1425.94] (spk=6) 부분이 상당히 인제.
# [1426.22–1435.46] (spk=3) 바로 그 점 때문에 우리가 개방을 하면 오히려 이 제도에서 벗어나 더 공공성을 강화시킬실 수도 있지 않냐 하는 겁니다. 예, 선생님께서 말씀.
# [1435.46–1443.94] (spk=3) 우리가 월드컵을 하거나 올림픽을 하면서 한 번씩 나라의 수준이 올라가듯이 더블유 티 오 를 맞이하면서 일부 개방도 열고.
# [1443.97–1450.76] (spk=3) 또 공공도 갖추면서 그 얘기는 어떻게 보면 또 인제, 평등과 자유라는 게 충돌할 수 있습니다.
# [1451.06–1459.11] (spk=3) 우리 지금 정부는 어떤 평등의 또는 공공성에 강조를 하다 보니까 결국은 교육과 의료가 다 하향 평준화돼 버리고 말았습니다.
# [1459.58–1465.83] (spk=3) 그래서 거기에 많은 불만을 가진 사람들이 해외로 유학을 가거나 어릴 때부터 아니면 해외 진료를 찾아 쫓아가고 있습니다.
# [1466.30–1479.26] (spk=3) 그것을 우리가 좀 더 자유스럽게 해서 또 그 좋은 고급 서비스를 리하는 사람들한테 서비스를 제공하고 거기서 남는 이윤 창출액 일부를 또 떤 그 밑에 사람으로 돌려쓸 수 있다거나 저는 그렇게 안 해도.
# [1479.26–1486.81] (spk=3) 사실 지난 이 정부에서 한 은행을 살리기 위해서 십 일 조를 부어놓고 아직도 몇 조를 더 넣어야 된다고 알고 있습니다.
# [1487.30–1492.39] (spk=3) 의료의약분호 사태가 났을 때 우리가 오 조 정도 가지고 오 조 정도면 해결할 수 있다고 그러는데.
# [1492.78–1500.96] (spk=3) 돈은 이때 어디를 먼저 쓰냐가 그게 결정이 안 됐기 때문에 지금 이 당장에서도 해결을 할 수 있는데도 못하고 있다고 봅니다. 니까.
# [1500.96–1511.76] (spk=3) 그 공공의료에 관한 강화 부분은 사실은 지금이나 개방이 되어도 얼마든지 우리가 훼손 안 시키고. 잘해볼 수 있는 부분입니다. 사실은 저는 그렇게 생각합니다.
# [1511.76–1511.94] (spk=0) 네.
# [1512.02–1512.33] (spk=3) 교수님.
# [1512.85–1513.03] (spk=4) 예.
# [1513.61–1521.12] (spk=5) 중요한 것은 뭐 내가 내가 필요한 것을 내가 선택하느냐, 그러나하면 정부가 선택하느냐 이 문제라고 봅니다.
# [1521.36–1529.69] (spk=5) 그리고 사회주의적인 사고방식은 정부가 알아서 내가 필요한 걸 갖다 주겠다 이겁니다. 그러니까 너는 가만히 있어라, 입다 물고 있어라. 정부가 알아서 디 필요한 걸 지주마.
# [1530.17–1541.62] (spk=5) 그런데 아니, 우리 우리나라 지금 지금까지 시스템이 그렇습니다. 그런데 이게 이제 우리가 개방을 하게 되면은 내가 어 많은 다양한 서비스 중에서 내가 알아서 선택하는 겁니다.
# [1542.36–1549.17] (spk=5) 그래서 내가 뭐 어 집을 팔아서라도 내 암을 고치겠다 하면 고칠 수 있는 거고, 또 서비스가 많기 때문에 더 갑이 가격이 싸지는 거고.
# [1549.51–1557.53] (spk=5) 또 그렇 지금 지난번에 의학분업사대로 파업이 있었지만, 저는 개방을 일찍 했더라면 저는 절대 그런 파업이 있을 수가 없다고 봅니다.
# [1557.53–1568.43] (spk=5) 왜냐하면 그전에 이미 그 외국 시스템이 외국 사람들이 많이 오고 의사들이 오고 오기 때문에. 바로 우리도 선진 선진국식으로 바꾸지 않으면 이 망한다 이런 것 대해서 다 바꾸게 됩니다.
# [1568.73–1578.98] (spk=5) 선진국 저 그 법도 배우고요. 연구하고 그래서 바로 하는데 그렇지 않기 때문에 묶어놓기 때문에 이 안에서 뭐 하다가 보니까 이 지금도 문제가 많은 겁니다. 저는 그렇게 봅니다.
# [1579.14–1588.50] (spk=6) 개방의 순기능만 강조를 하셨고, 그 점에 대해서는 저도 전적으로 동감합니다. 근데 재미있는 것이 뭐가 되는가 하면은 우리나라에서 외국에 대해서 배울 때 네.
# [1588.78–1596.50] (spk=6) 열어놓으면은 좋은 것을 배우지 않고 나쁜 것을 배워 갖고 이렇게 악용하는 부분들이 그 우리 안에 분명히 있는 건 사실입니다.
# [1597.00–1604.61] (spk=6) 그 부분에 대해서 그 부분에 대해서 인제 우리 우 의사 선생님들은 그 이전에 기업인들과는 다른 플레이를 보여주리라고 저는 기대를 합니다마는.
# [1604.99–1620.19] (spk=6) 실질적으로 지금 그 현재 이 개방 국면, 그 이 도하선언에 따른 이 그 의료서비스 개방 문제를 도고. 어, 지금 다섯 개, 그 그 의료 관계 단체들이 어, 지금 조율이 잘 안 되는데 제가 사실은.
# [1620.19–1631.81] (spk=6) 오늘 오기 전에 그 제가 지금 굉장히 그 뭐 이 부분에 있어서는 아마추어이기는 합니다마는 그 저기 뭡니까? 어 각 그 저기 그 단체의 그 홈페이지에 들어가 봤어요.
# [1632.19–1642.05] (spk=6) 쭉 봤는데 실질적으로 보면 홈페이지 전면에 이렇게 나와 있는 글들을 보니까는 어, 이게 인제, 그 한마디로 저는 조금 실망했습니다.
# [1642.05–1653.60] (spk=6) 뭐가 되는가 하면은 이와 같은 일이 국민 건강에 궁극적으로 어떻게 되느냐에 대한 조금은 거시적이고 좀 그 그 생명을 책임지고 있는 분들이.
# [1653.63–1667.44] (spk=6) 그 항상 내세우는 그 국민건강이 수호자라는 그 저기 위상에 맞게 조금 이렇게 그 저기 좀 심층적으로 걱정하는 글들이 좀 있기를 바랬는데 거기에 대해 갖고 각 이해관계라든가 이런.
# [1667.44–1678.80] (spk=6) 설문조사가 전면에 뜨고, 그리고 각 그 각 단체가 예외가 없더라고요. 결국은 뭐가 되는가 하면은 의사 선생님들은 걱정을 환자 걱정을 안 하고, 의사 선생님들 자신부터 걱정을 한다.
# [1678.97–1687.54] (spk=6) 하는 이런 그 생각을 하게 되는 것이 우선 그렇고 그러니까는 결국 어, 이것 갖고 국민들이 그 제가 볼 때.
# [1687.82–1698.86] (spk=6) 이 이 의료시장 개방 문제를 갖고 국민적 관심이 커지지 않는 가장 중요한 이유는 결국 그 의사들끼리 얘기다. 결국 그 이런 식으로 하는 무관심 부분야가 분명히 있다는 겁니다.
# [1699.67–1700.81] (spk=0) 네, 강 교수님, 이제.
# [1701.19–1710.59] (spk=5) 우리 북한에서 그 쌀만큼 중요한 건 없을 겁니다. 아마 쌀이 공공성이 대단히 많은 거죠. 쌀 파을먹. 근데 농민들이 왜 그 농사를 제대로 안 짓습니까?
# [1711.62–1722.54] (spk=5) 왜 그 농민, 그 북한에서도 충분히 제도만 좋으면 작업 자주 할 수 있을 텐데, 왜 그렇게 굶줄니까 결국은 그 인센 유인이 없기 때문에 그러죠.
# [1722.54–1731.58] (spk=5) 열심히 일해서 일하면 그 고통을 자가 참고 이기면 그만큼 보수가 나온다. 이 가지고 열심히 이제 자기 자기 것이 돌아오면 열심히 일하고 수확을 많이 낼 텐데.
# [1731.58–1741.81] (spk=5) 그렇지 않기 때문에 자기 옆에 텃밭만 있고 협동자 논의 일을 안 하는 거죠. 우리 저 사람 사람은 그게 기본적인 이 사람들 성향입니다.
# [1741.84–1753.18] (spk=5) 의사 선생님들도 보통 하면은 어려운 그 어려운 수술이면은 거기에 대한 보수를 충분히 우리가 지급을 해야 되는데. 그런 사람이나 피부과 의사나 뭐 성형외과나 뭐 안과나 똑같이 지급합니다.
# [1753.39–1759.70] (spk=5) 그러고 보면은 누가 그런 일을 하겠냐 말이죠. 결국 북한 사람 같이 굶질이게 우리.
# [1759.70–1765.57] (spk=6) 대한민국 의사 선생님들을 북한의 그 굶질이는 농민과 비교한다는 것을 얼마나 많이 받아들이지.
# [1765.69–1769.90] (spk=5) 보 보은 의료서비스가 부족한 것은 북한의 쌀이 부족한 거와 비슷하다. 이겁니다.
# [1770.05–1777.51] (spk=2) 아, 그렇 의료인 입장에서요. 지금 이제 홍 박사님께서도 의사들이 너무 자기들 입장에서만 이 문제를 접하는 것 아니냐.
# [1777.55–1783.25] (spk=2) 말씀을 하시지만 사실은 저희들이 국민 복원을 책임지고 있는 사람들이기 때문에 꼭 그렇지는 않고요.
# [1783.82–1797.34] (spk=2) 어, 아까도 말씀드렸지만은 더블유 티 오 가 분명히 세계화라든지 경쟁을 통한 어떤 질의 향상이라든지 수가에 저하라는 어떤 이점도 있지만, 저희들이 우려하는 것은 진짜 의료인으로서 이 지금 의료 시장이라고 하는 것이요.
# [1797.34–1802.36] (spk=2) 지금 세계적인 흐름이 이제 유럽시기냐, 미국식식기냐 하는 게 해결되지 않은 과제가 있습니다.
# [1802.36–1811.23] (spk=2) 사실은 이게 뭐냐 하면은 유럽은 국가가 적극적으로 개입을 해서 국민들이 의료 접근에 불편함이 없도록 국가가 굉장히 통제를 하는 스타일이고.
# [1811.52–1814.82] (spk=2) 미국식은 이게 굉장히 자유방영혐이고 시장 경제에 맡기는 원리거든요.
# [1815.05–1826.19] (spk=2) 근데 불행히도 우리나라는 지금 미국식이 많이 도입이 돼 있고, 최근에 인제 우리가 전 국민 의료보험을 시행을 하면서 유럽이 들어와서 국가가 국민의 어떤 건강을 책임지겠다고 하는 어떤 좋은 취지로 시작이 되고 있습니다만.
# [1826.19–1834.46] (spk=2) 여러 가지 부작용도 있지만은 이 더블유 티오 체제 문제라는 것도 결국은 제가 생각할 때는 그런. 문제에도 기착할 수가 있다고 지금 생각을 하는 거거든요.
# [1834.59–1843.37] (spk=2) 그래서 한의사 입장에서 이 시장개방 문제에 접근도 해야 되겠지만는 정말 보건의료인으로서 우리나라의 어떤 보건의료 체계를 어떤 식으로 가져가야.
# [1843.58–1848.60] (spk=2) 국민들이 저렴하게 의료에 접근할 수 있고, 진짜 질이 향상될 수 있겠냐 하는 문제도 같이 고민해야 될.
# [1848.60–1850.52] (spk=0) 문제입니다. 이것은 네, 이 박사님 말씀하시죠오 예.
# [1851.41–1867.12] (spk=4) 어이 토론이 너무 이 초반에 진도가 빨리 나간 것 같습니다. 그래서 제가 뭐 이 말을 참 끊고 들어가기가 힘들었는데, 어 제금 왕 교수님한테 하나 그 여쭤보겠습니다. 그 아까 쌀 말씀을 하셨는데요.
# [1867.86–1885.76] (spk=4) 어, 그런 어떤 노력과 대가라는 그 구도가 의료에도 이제 적용이 되겠죠. 부분적으로 근데 어, 혹시 영리성 추구와 공공의료라는 게 그렇게 같이 어느 정도 그 상존이 된다고 생각을 하십니까?
# [1887.70–1903.13] (spk=5) 에 그러니까 아, 결국 결국은 뭐 큰 차이는 없다고 봅니다. 왜냐면 에 이 뭐가 아 뭐냐면 어떤 경쟁이 있어야 발전하는 거고. 어떤 유인이 없이는 거기에 공급이 많아지지 않는다는 겁니다.
# [1903.13–1912.50] (spk=5) 유인이 충분히 있어야 사람들이 글로 간다는 겁니다. 지금 왜 공과대학생들이 우리나라 부족합니까? 그리고 그 공 졸업해야 좋은 직장에 보장이 안 되고, 봉급도 별로 적고 그러기 때문.
# [1912.62–1915.96] (spk=5) 사회적으로 대우가 안 좋으니까 안 가는 거죠. 마찬가지입니 그.
# [1917.08–1924.52] (spk=4) 제 생각에 그런 것 같습니다. 이 지금 더블유 티 오 얘기를 하다가 잠깐 뭐 의약분업이나 무슨 약간 이렇게 가지가 이렇게 쳐졌는데요.
# [1925.07–1936.14] (spk=4) 이 더블유 티 오 체제가 들어오느냐, 마느냐가 결국은 영리성과 공공 어 의료서비스 간에 균형을 얼마만큼 잡느냐가 문제인 것 같구요. 제가 생각할 때는.
# [1936.17–1946.28] (spk=4) 그리고 각 의료단체도 어 영리성 추구, 또 공공의료 옛날에 이렇게 두 가지가 따로 떨어져 있던 거가 인제는 어떻게 하나로 잘 묶어가지고.
# [1946.28–1957.95] (spk=4) 어떤 하나도 처지지 않게 영리성도 추구하고 국민도 편안해야 되고, 공공의료도 더 이상 처지지 않고. 그렇게 가는 모든 이 토끼를 다 잡는 그런 도구로서 하나 더블유 티 오.
# [1957.95–1961.92] (spk=4) 이 체제가 도입이 아마 그 필요하다고 생각하고 있는 것 같습니다. 그래서.
# [1962.66–1962.98] (spk=3) 어
# [1963.63–1971.21] (spk=4) 아직은 저희 그 치과계 말씀을 드리면은 어 사실 공공의료 분야가 상당히 지금 굉장히 취약한 부분입니다.
# [1972.10–1980.88] (spk=4) 지역보건법 같은 경우를 보면, 전국에 있는 보건소 중에 아직도 한 이십 퍼센트 정도는 치과 의사가 배치되어 있지 않습니다.
# [1981.39–1991.41] (spk=4) 그래서 저희는 그 보건복지부나 그런 이제 행정기관의 의견을 낼 때도 지금 이렇게 공공의료 부분이 다른 부분에 비해서 굉장히 취약한 상태인데.
# [1991.75–2002.80] (spk=4) 거기서 어 영리성을 추구하는 해외 병원들이 들어와 가지고 고부가 가치의 전문화 진료를 할 때 그러 이 처진 공공의료는 누가 담당할 거냐.
# [2003.34–2009.34] (spk=4) 이것도 어느 정도 국가에서 정책적으로 좀 채워주고, 어느 정도 경쟁력이 있게 해 놓고.
# [2009.58–2017.93] (spk=4) 그다음에 어 단계를 봐가면서 이렇게 같이 그걸 두 개를 조화해 해야 되지 않겠는가 하는 예, 그런 주장을 하고 있는 것입니다. 예.
# [2018.23–2026.18] (spk=6) 예, 그 저기 그 우리 이 선생님께서 저희 그 저희 그 제가 생각하는 그 원망을 너무나 잘 표현해 주셔갖고.
# [2026.65–2032.36] (spk=6) 어 저로서는 굉장히 고맙습니다마는 한 가지 아까 우리 왕 선생님께서 인센티브 얘기를 하셨는데요.
# [2032.88–2050.51] (spk=6) 어, 우리나라 그 저기, 어 우리나라 그 그 젊은이들이 의사가 되려고 하는 인센티브를 어, 아마 인제 우리 왕 선생님께서는 주로 인제, 그 저기 금전적 내지는 물질적 또는 어, 사회 신분적인 어떤 그런 인센티브를 주로 생각하셨을 겁니다.
# [2051.06–2059.62] (spk=6) 그런데 지금 가령 제가 볼 때는 일종의 가치관이 빈곤인데요. 그렇다고 그런 식으로 인센티브를 계속 공급하다 보면은 의료인이 된다.
# [2059.69–2071.90] (spk=6) 또는 생명을 위해서 봉사한다는 데 대해서 도덕적인 인센티브가 굉장히 지금까지 제가 볼 때는 지금 우리나라의 그 의학, 그 저기 그 교육 관계를 보게 될 때.
# [2072.27–2082.82] (spk=6) 어, 어느 면에서 우리 사회자께서도 인제 그 법을 전공하시기는 합니다마는 어 인신을 다루는 두 분야 우리나라에서 그러니까는 법 분야하고 의료 분야의 인센티브는.
# [2083.15–2092.17] (spk=6) 지금까지 철저하게 제가 볼 때는 빈곤한 가치에 의해서 유지돼 왔다는 말입니다. 저는 그 물질적 인센티브가 없어야 된다는 얘기는 전혀 아닙니다. 당연히 해야 되고.
# [2092.58–2100.78] (spk=6) 그리고 법이나 의료인들이 그 일반 대학 졸업자들보다 대체로 어느 나라든지 간에 수입이 한 두 세 배는 맞는 건 사실입니다.
# [2101.17–2109.79] (spk=6) 근데 저희 같은 경우에는 어느 면에서는 의사분들은 어 제가 이렇게 쭉 드지다 보니깐 의사나 어 그 변호사들라든가 그까.
# [2109.79–2120.22] (spk=6) 어쨌든 사람 몸에 관련된 분들의 그 소득 수준이 실질적으로 보게 되면은 이게 엄청나게 높아요. 그럼 그 정도 돼서도 인센티브 그니까.
# [2120.22–2128.42] (spk=6) 다른 국민들을 볼 때 그 정도 받고도 이거 우리 못 받는다라고 얘기하면 참 다른 국민들은 어떻게 지내야 됩니까? 그런 부분에 있어서는 우리.
# [2128.42–2138.42] (spk=1) 의료인의 입장에서 지금 더블유 티 오 개방이 오르냐, 안 오르냐. 이걸 얘기를 해야 되는데 근본적으로 의사가 잘 됐냐, 못 됐냐 지금 이 말씀을 잠깐 하신단 말이에요.
# [2138.95–2146.27] (spk=1) 그러니까 아까도 근무 처두에 우선 왕 교수님께 의사로서 의사답지 못하게 보인 것에 대해서 죄송스럽게 생각합니다. 부끄럽습니다.
# [2146.90–2159.87] (spk=1) 그러나 저도 저희 집안이 오십 년 넘어 부친 때부터 의사를 해왔지만, 의사가 이 사회의 도움에 의해서 생존해 오고 병원도 키워온 겁니다. 그것이 이 사회를 위해서 좋은 일에 쓰이기를.
# [2159.87–2167.55] (spk=1) 항상 기대하면서 사는 게 의료인이고 의사가 재벌이 돼서 무슨 병원을 큰 무슨 회사를 짓거나 이런 적은 없습니다.
# [2168.02–2174.55] (spk=1) 번 돈을 다 의료의 새로운 기계, 새로운 시설, 새로운 병원을 설립하면서 이때까지 해왔습니다.
# [2175.01–2186.99] (spk=1) 그 점을 국가가 도와준 적 없고, 세금을 도와준 적 없고, 왕 교수님이나 다른 부자가 도네이션 해준 적 없습니다. 다 의사들이 번 돈에 의해서 국민을 위해서 전부 그 자리에 만들어져 있습니다.
# [2187.47–2196.18] (spk=1) 이거를 망각하시고 의사는 우선 무언가 내 마음에 섭섭하게 하고 있다고 생각하시는 걸로 얘기하시면 우선 우선 더블유 티오로 가야겠어요.
# [2196.28–2202.06] (spk=1) 근데 제가 보기에는 의사는 그렇게 근본적으로 좋은 사람이 지 나쁜 사람이 아니라는.
# [2202.06–2209.48] (spk=0) 얘기를 더블유 티 어로 가자고 하셨으니까 잠시 쉬고 잠시 뒤에 더블유 티 어 로 가도록 하겠습니다.
# [2210.92–2217.58] (spk=4) 근데 지금 우리나라 헌법 삼십 육 조에 보면 그 국민의 건강을 국가가 보호하거나 책임지게끔 되어 있습니다.
# [2218.11–2225.78] (spk=4) 그런 헌법조항이 있음에도 불구하고 현재 우리나라 국가예산에서 보건의료, 보건의료 예산이 차지하고 있는 게 영 점 삼 프로밖에 안 되고.
# [2226.33–2236.92] (spk=4) 거기다가 민간병원이 구십 프로 이상을 차지하고 있고, 또 우리가 다달리 보험료를 내지만 실제 병원에 갔을 때 그 특히 외래 같은 경우에 육십 칠 프로를 또 본인이 부담을 해야 되거든요.
# [2238.14–2250.97] (spk=4) 거기다가 또 수가체계가 행위별로 되 있기 때문에. 이게 인제. 그 국가가 의료를 책임지고 있지 못하고 또 행위별 가제 수가제라는 것들이 그 국민들한테 많은 의료 부담을 가중시키고 있거든요.
# [2251.53–2258.18] (spk=4) 그래서 현재 우리가 볼 때는 한국의 의료 의료시장이 상당히 그 돈벌이 중심이고 영기 중심으로 가고 있거든요.
# [2258.69–2271.02] (spk=4) 이런 상태에서 만약에 그 외국 의료기관이 들어오고 또 과잉 경쟁이 더욱더 심화되었을 때. 그나마 십 프로 남짓한 그 의료의 공공성도 결정적으로 파괴될 수밖에 없다라고 생각을.
# [2272.49–2277.09] (spk=0) 예, 그 시장 개방으로 인한 그 공공성 파괴에 대한 우려의 말씀을 잠시 들어보았는데요.
# [2277.53–2283.82] (spk=0) 어 더블유 티 에 관한 논의를 좀 구체화해서 논의를 진행하고자 한다면 결국 그 쟁점은 두 가지로 요약할 수 있을 것 같습니다.
# [2284.33–2294.55] (spk=0) 첫 번째는 지금 그 비영리 형태로 묶여져 있는 병원의 운영이라든가 그 경영을 아. 영리화하여서 어떤 그 투자를 적극적으로 유치해야 할 것인지에 대한 여부가 있을 것 같고요.
# [2295.09–2305.80] (spk=0) 또 다른 한 가지 분야는 의료 인력에 대한 부분인데, 의료 인력이 어떤 해외 유출 또는 유입을 좀 자유롭게 하는 것이 옳은 것이냐. 아니냐, 이렇게 두 가지 아니겠습니까?
# [2306.03–2307.59] (spk=0) 예, 안 교수님 말씀하십시오선.
# [2308.11–2317.57] (spk=3) 자꾸 공공성 훼손의 문제가 나오고 염려 또 우려의 목소리가 나오는데, 과연 우리나라의 진정한 공공의료가 있습니까? 저는 그것부터 대단히 의심스럽습니다.
# [2318.29–2329.41] (spk=3) 비영리 법인은 대부분의 병원들은 다 민간인들이 세운 거고. 그 존립을 위해서는 반드시 공공기관으로 포장되었지만, 이익금을 내야지만 그것이 생존할 수 있게 돼 있습니다.
# [2329.91–2337.82] (spk=3) 그래서 전부 공공기관임에도 불구하고 병원에서는 어떻게하든지 최소의 돈을 들여서 최대의 이익을 창출하려고 노력하고 있습니다.
# [2338.29–2349.70] (spk=3) 의료수가도 워낙 박하기 때문에 그거 역시 진정공공의료기관이 아니고 이제는 보건소마저 경쟁력을 갖추라. 그래서 같이 뛰어들어서 저가에 어떤 그 검진을 해 준다든가.
# [2349.70–2356.32] (spk=3) 그런 걸로 보건소 자체가 또 이익금을 남기려고 노력까지 하고 있습니다. 우리나라에 공공의료가 존재합니까?
# [2356.32–2365.18] (spk=3) 공공의료라는 것은 제가 다른 공공의료를 하 나라에서 살아보면 국가에서 세금을 걷둬서 그 예산을 가지고 그 예산만침 쓰는 것입니다.
# [2365.49–2373.04] (spk=3) 적자가 나던 흑자가 나든 적절하게 운영함으로써 비슷하게 맞춰가면서 이윤의 창출료 관계없이 사는 것입니다.
# [2373.46–2379.17] (spk=3) 그러나 우리가 가지고 있는 그 십 퍼센트의 공공기관도 지금은 이윤을 남기려고 애를 쓰고 있습니다.
# [2379.69–2385.30] (spk=3) 그리고 아까도 얘기했지만 구십 퍼센트의 병원이라든가 의료기관은 바로 민간인들레이에서 이것이 세워졌습니다.
# [2385.30–2392.29] (spk=3) 국가가 세운 게 아니라 그러한 구조를 보면, 이미 공공의료라 거는 더 이상 떨어질래야 떨어질 수도 없는 상태입니다.
# [2392.72–2397.38] (spk=3) 그까 더블유 티 오 가 와서 공공의료가 망가진다 는데 망가질 게 뭐가 더 남은 게 있습니까?
# [2397.38–2407.09] (spk=3) 제가 보기엔 그건 국가에서 아까도 얘기했지만 십 일 조를 한 은행에 쓸 의지가 있다면 국민들을 위해서 한 십 조쯤 써보라, 이겁니다. 옳타게 뭐가 있습니까? 그게 이.
# [2407.09–2409.99] (spk=0) 박사님, 보건소에 관한 부분 걱정하셨었죠, 어
# [2411.36–2423.35] (spk=4) 제가 아까 어 말씀드렸다시피 지금 보건소가 현재 우리나라 상황에서는 뭐 최말단 최전선에 서 있는 아마 공공의료기관을 아마 대표하고 있다고 생각을 합니다.
# [2424.15–2440.36] (spk=4) 어, 근데 어 현재는 예방업무 뭐 교육 업무 그런 데 인제 주 저거를 하고 있죠. 근데 어떤 경제적으로 좀 모자른다든지 좀 낮은 분들은 그 공공의료시설을 이용할 수밖에 없는 상황입니다. 사실은.
# [2440.80–2452.84] (spk=4) 그런데 그 공공의료기관이 어 지역 저 지역보건법 의면는 반드시 치과의사 한 명이 그 근무를 하고 있게 돼 있습니다.
# [2453.17–2466.51] (spk=4) 근데 어, 지금 치과의사가 아까 말씀드렸다시피 이십 이십 퍼센트 정도의 보건소에는 배치를 되고 있지 못하는 사정이 있고요. 또 거기에 더군다나 치과가 의사 혼자 진료하는 건 아니지 않습니까?
# [2466.61–2475.41] (spk=4) 이제 치과 위생사에는 같은 이 파트너와 같이 진료를 하는데, 어떤 뭐 예산 문제 때문에 그런 인력이 충원되고 있지는 못하죠.
# [2475.84–2483.47] (spk=4) 그러면 그분들은 어 치과의사가 없는 데 계시는 그 주민들은 어디를 가야 되겠습니까? 민간병원으로 가야죠.
# [2483.86–2496.50] (spk=4) 민간병원을 가서 어 진료 순서를 기다려서 진료를 하셔야 되는데, 그 민간병원이 그야말로 고 어. 부가가치만을 쫓는 외국계 병원이 들어오면은 허물어질 것은 뻔한 이치거든요.
# [2496.73–2507.28] (spk=4) 그럼 그분들은 공공의료에서도 도움을 받지 못하고 민간의료마저도 도움을 받지 못하는 그런 사태가 발생될 수 있다는 말씀입니다. 그교님.
# [2507.80–2516.33] (spk=0) 철학자께 한 가지 질문을 올리겠습니다. 아. 현행 우리나라 법에는 그 병원의 설립은 비영리로 하도록 되어져 있습니다.
# [2516.93–2524.95] (spk=0) 아, 아마도 그 뜻은 뭐 제가 무지해서 잘 모르겠습니다만 그 공공성이라고 하는 그 기조를 유지하고자 하는 뜻이 아닌가라는 생각을 해보는데요.
# [2525.33–2529.79] (spk=0) 지금 일각에서는 그것에 관한 규제를 풀어서 뭐 규제라는 표현이 어떨지 모르겠습니다만.
# [2530.11–2537.49] (spk=0) 영리 법인화 하는 것을 허용을 하여서 투자를 좀 적극적으로 유치하는 것이 의료서비스 개선에 도움이 될 것이다, 이런 주장이 있단 말이죠.
# [2537.91–2542.06] (spk=0) 철학자께서 보시기에 이러한 주장에 대해서는 어떤 의견을 갖고 계십니까?
# [2542.06–2549.14] (spk=6) 그 철학자가 봐 갖고 절대 그 저기 의료 전문가보다 더 잘 볼 수는 없을 겁니다. 그 점에 있어서는 철에.
# [2549.14–2549.80] (spk=0) 관한 문제니까.
# [2550.55–2559.96] (spk=6) 그 철학의 문제라기보다도 이런 것이 돼 있습니다. 우선 제가 더블유 티 오 개방이 된다고 했을 때 그 그 우려되는 것은 일단 그 저희 지표는 일단 소비.
# [2559.96–2569.47] (spk=6) 그니까 어, 의료를 필요로 하는 사람으로서의 문제고, 그럴 때 일단은 뭐가 되는가 하면은 어 말하자면은 당장 그 그니까는 그 그니까.
# [2569.47–2579.20] (spk=6) 급한 병이라든가 말하자면 원치 않은 죽음이나 고통을 당할 수 있는 일, 차적인 치료에 대한. 접근은 기본적으로 보장을 하고 개방을 하라는 겁니다.
# [2579.89–2590.72] (spk=6) 그러니까는 어, 다시 말해서 아까 저는 안샘님 말씀에 동의합니다마는 안샘님 말씀에 동의합니다마는. 우리나라의 그 의료, 공공보건의료기관의 병상수 기준이.
# [2590.72–2602.42] (spk=6) 제가 이렇게 그 보니까 아까 선생님께서 어 십 퍼센트 더 내려갈 때도 없다. 구 점, 팔 프로. 근데 제가 이제 좀 외람되지만 좀 알아본 걸로는 구 점, 팔 내지 십 오 퍼센트 정도가 되는데.
# [2602.73–2613.56] (spk=6) 오 이 씨 디 국가 중에서는 제일 낮더라고요. 그렇게 됐다고 했을 때 그 가령 또 미국하고 비교해 봐도 미국이 그렇게 그 사적으로 하는데도 미국이 이 뭐 이십 오 점.
# [2613.56–2622.39] (spk=6) 병원수로는 이십 오 점 일 프로 이래 갖고 우리보다는 한 두 배쯤 높게 돼 있고. 어, 유럽에 비하면 뭐 더 비교가 안 되죠. 그렇게 됐을 때, 아니, 제가 말씀하는 게 이런 겁니다.
# [2622.84–2632.23] (spk=6) 뭐가 되는가 하면은 일단 국민들이 일 차적인 진료를 받을 수 있는 그니까 지금까지 호울만 남은 공공의료 부분을 강화하라는 겁니다.
# [2632.81–2639.90] (spk=6) 그리고 나서 고다음에 아까 왕 교수님께서 말씀하셨지만은 어 실제로 의료기술이 발달이라든가 이런 건 경쟁을 해야 되거든요.
# [2640.23–2650.89] (spk=6) 그럴 때는 많은 투자가 필요하고 국가가 그거를 갖다가 가령 지금 어느 면에서는 어 그 상당할 정도로 그 저기 첨단 그 투자가 몇 개 있잖 않습니까? 비 티니 엔 티니 하는.
# [2650.89–2656.80] (spk=6) 이런 부분들, 이런 부분들에 대해서는 유휴 자본을 끌어들일 수 있도록 그거는 완전 경쟁을 하자는 거죠, 그.
# [2656.80–2659.78] (spk=0) 말씀은 영리 법인을 허용할 수도 있다는 말씀이시당연하죠.
# [2659.78–2672.24] (spk=6) 그러니까는 조건부라는 겁니다. 제가 볼 때는 모든 국민들이 일 차적인 진료, 원치 않는 고통과 죽음을 갖다가 맞을 수 있게 되는 기회를 폭 줄여주고 난 다음에 고다음에 고도에.
# [2672.41–2679.70] (spk=6) 그리고 그다음 특수하고 다양한 의료서비스 부분들, 이런 부분들은 제가 볼 때는 경쟁으로 충분히 풀 수가 있다는 겁니다, 지금.
# [2679.74–2685.22] (spk=0) 잠깐만요, 교수님 말씀하신 부분과 관련해서 저희가 인터뷰를 해 보았습니다. 잠시 보고 논의를 계속하겠습니다.
# [2686.45–2686.70] (spk=2) 헐.
# [2687.68–2695.43] (spk=0) 자, 그러면 이제는 그 노 박사님께 병원 경영자 입장에서 병원의 영리화를 찬성하시는지.
# [2695.43–2701.39] (spk=0) 만약에 찬성하신다면 그것이 의료서비스 개선에 어떻게 도움이 될 거다라고 생각을 하시는지 여쭙겠습니다.
# [2701.90–2712.36] (spk=1) 지금 우선 영리법인을 저는 허용하는 걸 찬성하는 사람입니다. 그 이유는 의사 한 사람이 가진 돈이 선생님 생각하시는 것처럼 많지가 않습니다.
# [2713.24–2724.45] (spk=1) 그러니까 그 돈들을 모이면 주라는 형태로 가지고 있게 되면. 그러나 인간은 세 명의 주인이 있으면 그 밑에 놓여는 자유인이라는 로마의 격언이 있습니다.
# [2724.48–2736.41] (spk=1) 그니까 주인을 우리가 현명한 리더를 하나를 만들어서 큰 자본으로 만들어서 효율적인 의료를 서비스하는 겁니다. 그거는 효율적이라는 말은 커스트 이펙티브하다는 얘기입니다.
# [2736.91–2746.56] (spk=1) 비용이 적게 들면서 효율적인 서비스를 하고 싶다는 건데, 이것을 각각의 의원들에게 맡겨 놓다 보니깐 비효율적인 요소가 너무 많답다.
# [2746.90–2756.30] (spk=1) 이게 아까 말씀드린 의사는 그렇게 하고 싶지만 제도가 안 돼서. 국가의 시스템이 잘못돼 있기 때문에 우리가 국민에게 만족할 만한 진료를 못 하고 있는 겁니다.
# [2756.66–2768.72] (spk=1) 이것을 이번 기회에 더블유 티오 개방 체제로 이거는 한국만의 법이 아닙니다. 세계 공통의 법을 만드는 거니까 이 법에 우리는 대통령도 어떻게 할 수가 없어요.
# [2769.29–2773.46] (spk=1) 이거는 내 마음대로가 아니라 울산 시장의 역할 정도밖에 안 된단 말이에요.
# [2773.54–2785.16] (spk=1) 지구촌에서 보면은 그러니깐 국제룰에 따게 되면은 우리가 안 고쳐지는 한국의 시스템이 좀 더 개선되는 시스템으로 되지 않겠냐는 게 개방을 원하는 거고.
# [2785.21–2788.13] (spk=1) 영리 법인을 허용하는 거를 원하는 이유입니다.
# [2788.17–2793.91] (spk=0) 그런데 천 박사님, 이런 건 어떨지 모르겠습니다. 지금 영리 법인을 허용한다는 주장을 말씀해 주셨는데요.
# [2794.74–2810.74] (spk=0) 또 주주의 형태로 이제 투자를 하게 하자라는 말씀하셨는데, 그 말씀은 곧 듣기에 따라서는 마치 기업처럼 뭐 표현이 어떨지 모르겠습니다만 어 새칭 그 장사꾼처럼 운영될 수도 있다는 우려도 생길 수 있을 것 같거든요.
# [2810.74–2811.72] (spk=0) 어떻습니까, 그
# [2811.74–2822.76] (spk=2) 현실적으로요. 영리법인이 설립이 되고, 또 고급 진료가 돼야 될 필요성은 사실은 또 있습니다. 왜냐하면 지금 상당 부분 고급 진료가 지금 해외로 유출이 되고 있거든요.
# [2823.07–2834.88] (spk=2) 국내에서보다는 국외외로 지금 나와서 수술을 받거나 치료하고 오는 사람 경우가 많고. 근데 이제 또 문제는 거기에 따른 문제가 홍콩이나 대만 같은 경우에는. 이제 병원들이 영리법임이나 돼서.
# [2835.34–2845.33] (spk=2) 이제 그 사람들 의사들을 만나보면 하소연하는 것이 의사가 어떤 의료인으로서 독립적인 기능을 하는 것보다는 그야말로 기업. 내에서 어떤 사원 입장에 불과하다.
# [2846.21–2855.27] (spk=2) 상당히 어떤 그 영리 법인을 운영하는 주체에 의해서 의사의 어떤 진료권이 상당히 위축을 받을 수가 있다고 하는 부작용을 지금 나타내고 있습니다.
# [2855.50–2865.81] (spk=2) 그래서 우리가 이 문제를 고민하는 것은 참 두 마리 토끼를 다 잡아야 된다고 하는 어려움이 있습니다. 그래서 어 고급화도 해야 되겠고, 또 공공성도 보장을 해야 되겠고. 또.
# [2865.81–2872.64] (spk=2) 그러면서도 의사가 독립적으로 어, 또 어떤 진료권을 행사할 수 있는 존중도 받아야 되겠는데 게.
# [2872.64–2881.05] (spk=2) 기업화가 되다 보면 아무래도 어떤 기업에서 이익을 중시하는 어떤 풍토에 의해서 어떤 시스템이 움직이기 때문에 개개인의 어떤 의료인에서의 어떤 이런.
# [2881.47–2884.15] (spk=2) 독리성은 조금 훼손될 우려도 사실은 현실적으로 있다고.
# [2884.15–2893.61] (spk=0) 봅니다. 홍 교수님, 병원이 기업화가 되면 지금 천 박사님 말씀처럼 의사가 그 사원의 입장으로 전락할 수도 있을 것도 같고. 그렇다면 뭐랄까요.
# [2893.61–2897.60] (spk=0) 공공성은 그만큼 담보되기가 어렵지 않느냐라는 우려도 가능할 것 같 제가.
# [2897.60–2906.18] (spk=6) 의사가 아니라서 구체적인 상황에 대해서는 뭐라고 얘기할 입장은 아니겠습니다. 근런데 한 가지만 좀 말씀을 드리면 말이죠. 어, 그 저기 뭡니까?
# [2906.23–2911.61] (spk=6) 의사의 그 대상은 아까도 제가 계속 말씀드립니다마는 어.
# [2911.61–2924.05] (spk=6) 어쨌든 그 당연히 의료 상품이라는 측면도 있지마은, 어떤 상품도 대체할 수 없는 일회성, 생명을 다루고 있다는 측면도 분명히 있다는 겁니다. 그랬을 때 공공성 그니까는 앞으.
# [2924.15–2932.14] (spk=6) 저는 우리나라 병원들이 의원분들이 이런 어떤 생명의 관리 측면에서 전국적인 연대 시스템을 갖는 것은 전 백 프로 환영을 합니다.
# [2932.48–2945.90] (spk=6) 그리고 그 시스템을 갖고 저는 외국 어, 그 의료시장까지도 전 넘볼 수 있다는 생각이 들거든요. 그렇다, 무슨 일인가 하면은 한국 의사들 환자들한테 분명히 책임을 지는 훈련이 돼 있다.
# [2946.09–2957.53] (spk=6) 그리고 그것을 잘 효율적으로 그 나름대로 치료를 했던 그게 있다. 그러면 설사 한 국내에서 국내에서 결국 의사는 승부를 뭘로 걸어야 됩니까? 잘 고친다는 걸로 승부를 내야 되지 않겠습니까?
# [2957.89–2962.78] (spk=6) 그럴 때 결국은 공공성과 영리성을 단기간의 입장에서 상충되는 걸로 보지 말고.
# [2963.33–2963.84] (spk=3) 우리.
# [2964.39–2973.53] (spk=6) 의사들이 그 나름대로 생명에 대한 도덕적인 존엄성과, 아울러 고도의 의학구술을 갖다 의학기술을 발달시키는 일종의 하나의 장으로 봐서.
# [2973.76–2982.56] (spk=6) 한국 전체를 말하자면 일종의 글로벌 한 일종의 의료, 그 포럼으로 만들어서 퇴기 시장 경제에 한번 나서보자는 거죠.
# [2982.76–2987.93] (spk=0) 네, 논의가 지금 뜨거워지고 있는데요. 지금 시각 여덟 시 사십 팔 분입니다. 난상토론 잠시 후에 뵙겠습니다.
# [2988.79–2996.09] (spk=0) 아, 좀 전에 그 의료시장 개방으로 인하여서, 또 특히 그 병원이 영리 법인화될 때 있을 수 있는 문제점을 잠깐 보았는데요.
# [2996.45–3000.32] (spk=0) 안 교수님, 이러한 우려점에 대하여서 교수님께서는 어떤 생각을 갖고 계시는지요?
# [3001.02–3011.77] (spk=3) 글쎄요, 그 윤리적인 문제를 자꾸 들고 오시는데, 저는 그러면 한번 영리를 허용하는 나라 지구상의 순수, 자본주의 국가, 미국의 예를 들어보겠습니다.
# [3011.77–3020.50] (spk=3) 그러면 거기서 행하해주고 있는 의료의 수준이 결코 우리보다 의료, 의료윤리 수준이 낮거나 그러지 않습니다.
# [3020.90–3031.20] (spk=3) 오히려 더 다른 사회적 감시 기능에 의해서 높으면 높을 수가 있지, 절대로 낮지 않고. 아까 교수님 말씀대로 공공의료마저도 죄송합니다.
# [3031.70–3038.09] (spk=3) 그렇게 하면서 나라에서는 공공의료를 잘 보호하고 있다. 바로 그게 우리가 나가야 될 길 아닙니까?
# [3038.09–3046.41] (spk=3) 지금 저는 개방을 하면은 우리의 서비스질이 올라가고 또 아까 치과 선생님, 저 이병두 이사장님께서 말씀하신 대로.
# [3046.84–3058.02] (spk=3) 만약에 그렇게 몰락할 염려가 있다면 소외된 계층에서 어떤 접근할 데가 없다면 그것이 바로 정부의 역할 아닙니까? 지금 우리가 국가에서 하지를 않기 때문에 그런 거지.
# [3058.67–3065.10] (spk=3) 저는 이 자리에서 좀 더 국가에서 보건 이쪽 정책 앱배 신경을 더 많이 써달라고 부탁을 드리고 싶습니다, 그래서.
# [3065.92–3066.80] (spk=0) 예, 말씀하시죠오 예.
# [3067.42–3076.84] (spk=2) 그 물론 다른 분야에서는 그렇지 않다고 저는 믿고 있고, 또 이제 한의사로서 한의계의 입장을 말씀을 드려본다면 현실적으로 일어나고 있는 이들입니다.
# [3077.42–3087.18] (spk=2) 한의학이 아직까지도 국민들한테 접근하기가 어려운 분야로 지금 남아있고 인식이 되고 있습니다마는 저희들이 상당히 가슴 아픈 현실이. 지금 한의과 대학이 전국에 십 일 개 대학이 있습니다.
# [3087.41–3094.95] (spk=2) 그데 이게 불행하기도 전부 사립학교입니다. 그래서 우리가 끊임없이 정부에다가 국립 국립대학을 요구를 하고 있습니다마는.
# [3095.30–3104.85] (spk=2) 사립대학의 지금까지의 어떤 한의학을 연구하고 발전하고 진료하는 형태를 봤을 때 저희들이 문제점으로 지적을 하는 겁니다. 이 재투자가 잘 안 됩니다.
# [3105.89–3109.88] (spk=2) 결국은 사립병원이라고 하는 사립학교의 부속병원이라고 하는 역할이.
# [3110.19–3121.55] (spk=2) 공익성보다는 아무래도 사립학교 재단을 위한 학교가 되고 병원이 되고 있다는 데 저희들은 상당히 가슴 아픈 현실을 겪고 있습니다. 그렇다면은 앞으로 이렇게 의료 영리법인화가 된다고 했을 때.
# [3121.70–3127.49] (spk=2) 이런 부작용도 우리가 충분히 감안을 하고 지금 말씀하신 대로 국가의 기능이 개입이 돼야 된다고 보는.
# [3127.49–3129.36] (spk=0) 것이죠. 네 예 예.
# [3130.00–3141.10] (spk=5) 저 우리나라 뭐 전체 연구비가 미국의 존사피스디의 연구비보다 작다고 그럽니다. 미국에 존수 아프실 대학이 뭡니까? 미국에서 제일 그 병원이 좋은 병원을 가지고 있죠.
# [3141.68–3150.80] (spk=5) 병원 사실 우리나라 의류 수준이 많이 떨어지는데, 그 이유가 이 이 의사들이 그 연구할 시간이 없고 연구비가 별로 없는 겁니다.
# [3151.00–3158.62] (spk=5) 연구비게 첨단나 뭐 그런 의학 같은 데서는 굉장히 연구비가 많이 들지 않겠어요. 그런 거 할라면은 돈이 있어야 되는 겁니다.
# [3158.62–3168.99] (spk=5) 그러면 그런 뭐 기자재도 그렇지만 그런 그런 거 할라면은 결국 영리 그런 영리 법인이 아니고는 그런 돈을 마련할 수가 없는 거죠. 정부가 그걸 주겠습니까? 정부가 할 일은 이제 이런 게 있습니다.
# [3168.99–3176.97] (spk=5) 첫째는 공공성 때문에. 그런데 첫째는 이제 가난한 사람, 이런 사람을 위해서 정부가 그 그런 사람한테 의료 서비스를 갖도록 해줘야 됩니다.
# [3176.99–3187.49] (spk=5) 어떤 방안이든 그 둘째는인제, 그 어 병이라는 게 그 그 사람을 낳지 않으면 그 병이 전혀 하지 않습니까? 이래서 공공성이 있는 겁니다. 그래서 그런 전염병을 정부가 예방하고 치료하는 문제 에.
# [3187.49–3194.16] (spk=5) 그리고 아까 일 차적으로 뭐 정부가 해야 된다고 그는데 일 차적인 것이 아니고, 그렇게 이제 최소한도의 그런 서비스는 그건 정부에서 해야 되고.
# [3194.53–3200.55] (spk=5) 그리고 또 또 하나 중요한 건 그런 그 전염병이라든가 이런 것들이 또 그런 그런 것들이 이제 공공성이 있기 때문에.
# [3200.95–3210.92] (spk=5) 병원이라든가 이, 특히 연구 연구하는 문제라든가 또 전염성 있는 문제를 치료하는 문제 이런 데서는 정부가 과감하게 그 지원을 해야 된다고 봅니다.
# [3210.92–3221.46] (spk=0) 정부의 역할을 말씀하셨으니까 지금 저희가 그 정부 관계자와 전화를 연결했습니다. 예, 아, 황교사님 죄송하고요. 하시고자 하셨던 질문의 내용을 뭐 잠시 여쭐 수 있겠습니까?
# [3221.46–3223.28] (spk=0) 뭐 답변은 그렇습니다만 어
# [3223.28–3233.93] (spk=6) 저기 실질적으로 이게 지금 의료시장 개방 문제가 지금 주로 그 표면적으로는 의사, 병원 어 또는 이 그 저. 환자의 그 수급을 어떻게 하느냐.
# [3233.93–3242.63] (spk=6) 또는 조절을 어떻게 하느냐는 문제지만은 이 문제와 관련돼 갖고 사실은 의료보험 문제가 지금 사실은 같이 정비돼야 되는 문제로 지금 파악이 되고 있습니다.
# [3243.10–3248.56] (spk=6) 그렇다고 했을 때 가령 우리와 의료제도가 다른 미국이라든가 이런 쪽하고 얘기를 하게 될 때.
# [3248.96–3260.31] (spk=6) 우리가 지금 아직은 의료보험이 공보험 체계로 되어 있고, 여러 가지로 좀 문제가 많고 그 재원도 지금 문제가 많은 상태에서 어, 보건복지부가 아마 잠시 동안 그 사 그 저기 뭡니까?
# [3260.31–3270.18] (spk=6) 민간보험 얘기를 할려고 하다가 들어갔는데 이번에. 다시 재정경제부가 민간보험 문제를 들고 나온 걸로 알고 있습니다. 소비자 입장에서 볼 때는 려 서비스 소비자 입장에서 볼 때.
# [3270.43–3278.26] (spk=6) 이것이 혹시 공보험 체계의 그 붕괴라든가, 아니면은 사보험을 통해 갖고 결국 보험 부담이 급속하게 상승하는 것이 아닌가.
# [3278.72–3287.94] (spk=6) 여기에 대해서 말하자면은 이와 같은 의료시장 개방과 결부돼 있는 여타 여러 가지 그 의료 부속 제도 정비가 이 보험제도를 중심으로 해서.
# [3287.94–3291.60] (spk=6) 얼마나 지금 치밀하게 진행되고 있는가, 이 부분에 대해서 좀 여쭤보고 싶었습니다.
# [3291.64–3303.65] (spk=0) 사실 참 이 더블유 티 유 의료시장 개방 문제가 가져올 그 파장은 뭐 상당히 크리라는 데에 대해서는 뭐 참 모두가 공감하는 사실이고요. 그래서 저희가 이런 자리를 마련한 것 아니겠습니까?
# [3304.13–3314.51] (spk=0) 아, 조금 좀 논의를 구체화시켜서요. 안 교수님 어떻습니까? 또 의료 시장 개방으로 인한 그 우려사항 가운데는 의료 인력이 어떤 해외 유출 부분도 있습니다.
# [3314.56–3328.45] (spk=0) 제 우수 인력은 나가고 어 좀 아주 하위 나라로부터 어 뭐랄까. 준비되지 않은 의료 인력이 들어와서 국민의 어떤 의료 서비스가 떨어질 수도 있을 것이다. 이제 이런 우려도 있거든요. 어떻습니까?
# [3329.47–3338.78] (spk=3) 그것은 현재 그 의료인의 이동이 비교적 자유로운 이유를 한번 보시면 좀 이해하실 겁니다. 이유는 면허를 공유합니다.
# [3339.27–3348.58] (spk=3) 그래서 이동은 자유스럽게 놔뒀어도 실제 우리가 우려하던 그런 일은 하나도 나타나지 않고 있습니다. 또 우리 인력이 여기 의사들이 밖으로 진출하고 싶다.
# [3348.58–3355.19] (spk=3) 그러면은 거주기전인 자유라든가 개인의 삶의 자유를 위해서 많은 사람들이 나가고 싶다면 또 도와줘야 되고.
# [3355.55–3366.18] (spk=3) 또 우리를 오겠다면 나갈 만큼 또 들어올 수도 있는 거고, 그렇게 자꾸 교류하면서 발전하는 거 아닙니까? 저는 그것이 생각만큼 그렇게 우려할 만한 건 절대 아니라고 봅니다.
# [3366.79–3369.38] (spk=0) 한의사 입장에서 조금 생각이 다르실 것도 같은데요.
# [3369.61–3382.00] (spk=2) 저희들은 이제 미국 시장이라든지 선진국 시장에 한의사들이 제출 진출할려고 했을 때 사실은 각국이 자유스럽게 놔두는 것 같지만은 사실 보이지 않는 장벽들을 엄청나게 지금 해두고 있거든요.
# [3382.24–3389.77] (spk=2) 실제로 영국 같은 데 가서 개업을 할려면은 들어갈 수는 있습니다만. 한의원 할 어떤 그 건물을 계약할 때 삼십 년 계약을 요구를 합니다.
# [3390.25–3398.61] (spk=2) 사실은 어떤 보이지 않는 장벽이고, 또 각국의 어떤 언어를 제 자유롭게 구사할 수 있느냐 하는 능력을 본다라든지. 또 선진국이 상당히 개방적인 것 같지만요.
# [3398.96–3408.68] (spk=2) 캐나다 같은 경우는 제가 알기로 치과 의사들이 어떤 지역에 개업을 할려면은 정확하게 어떤 지역 내에 치과 개원의 숫자가 고정이 돼 있습니다. 티오제라 그러죠?
# [3408.79–3414.23] (spk=2) 그래서 어떤 사람이 이전을 하거나 비었을 때 한 사람이 들어갈 수 있도록 상당히 개업 자체를 규제하고 있습니다.
# [3414.23–3424.09] (spk=2) 실질적으로 또 미국 같은 경우에는 한의사 제도가 없지만 이제 친구사 제도를 이용해서 한의사들이 진출할려고 했을 때 가서 우리가 시험을 보고는 와서. 자격은 취득을 하지만.
# [3424.30–3432.45] (spk=2) 실제로 어떤 이민의 이민의 어떤 제안이라든지 취업 비자의 어떤 발급 거부라든지 이런 식으로 실제로 어떤 진출할 수 있는 길회을 많이 막아놓고. 있다고 하는 것이.
# [3432.45–3438.06] (spk=0) 문제가 되겠고, 판의사 입장에서 치과의사까지 다 시장을 조사하신 것 같은데요. 저 이 박사님 예.
# [3438.36–3442.47] (spk=4) 저 그 안 교수님한테 하나 그 여쭤볼 말씀인데.
# [3443.26–3443.61] (spk=2) 어
# [3444.27–3460.68] (spk=4) 제가 느낌상에는 타협회는 우리 의료시장 개방이 됐을 때 우리가 어 외부 인력이 우리한테 들어오는 것보다는 내국에 있는 의료 인력이 밖으로 나가는 거에 더 관심이 아마 있 있으시다 하는 제가 그런 느낌을 받거든요.
# [3460.93–3475.78] (spk=4) 근데 예, 맞습니까? 그러면 혹시 외부에 뭐 이런 말씀을 드려서 좋을지 모르지만 저희보다 좀 질이 낮은 그런 의료 인력이 들어오는 거에 대해서도 아마 검증을 좀 하셨을 텐데 예, 그에 대해서.
# [3476.15–3484.19] (spk=3) 얼마든지 그 막을 수 있습니다. 우리가 현재 그 면허취득이 생각보다 아주 단순하고 쉽게 돼 있기 때문에.
# [3484.64–3495.73] (spk=3) 사실 그런 부분이 좀 취약한데 앞으로 고거는 면허 부분을 좀 고단계화 선진국에서 요구하는 수준으로 올려놓으면 그렇게 쉽게 침투할 수 없습니다.
# [3496.24–3501.51] (spk=3) 우리도 보이지 않는 장벽, 즉 면허를 고도화시키면서 뭘 같이 해볼 수 있냐면.
# [3501.83–3511.06] (spk=3) 우리가 아직까지 하지 못했던 의료인력이라든가 이런 분들에 대한 품질 관리가 가능해지고, 또 그런 거는 다 제도가 선진화돼야 되는데.
# [3511.16–3522.51] (spk=3) 대개 다른 나라들은 입법민간단체에서 이걸 맡아가지고 하고 있습니다. 전문화된 단체가 따로 있어서, 또 수혜자 원칙에 의해서 의사와 사회가 공동으로 참여해서 다른 인력도 마찬가지입니다.
# [3522.51–3530.91] (spk=3) 사회의 공동참여로서 우리 스스로 전문인으로서의 품위도 지키고, 질도 유지하고, 면허도 아주 고도로 만들어 놔서.
# [3531.47–3537.11] (spk=3) 그렇게 그 장벽이 보이지 않는 장벽이 바로 그건데 우리도 인제, 그걸 곧 시도해야 됩니다. 그래서 제가.
# [3537.18–3550.02] (spk=4) 그것 때문에 인제 여쭤봤었는데요. 어, 아직까지는 그런 제도가 아직 우리나라에 그렇게 정비가 돼 있지는 않은 것 같습니다. 어떤 면허를 갖다가 어 검증할 수 있는 그런 방법도 없고요.
# [3550.09–3563.96] (spk=4) 기관도 없구요. 네, 그러다 보니까 저희 같은 경우는 어 구십 구 년도까지 필리핀에서 어 뭐 전부 다 불법은 아닙니다만. 필리핀에서 유입되어 온 치과의사가 이천 삼백 명 가량이 됩니다.
# [3564.04–3574.85] (spk=4) 그 현재는 그중에 오백 명 정도가 지금 활동을 하고 있고요. 물론 오백 명이 다 불법은 아닙니다. 그리고 아직까지도 매해 사백 명씩 계속 응시를 하고 있습니다.
# [3575.16–3587.58] (spk=4) 그러면 저희가 치과대학이 열 한 개인데요. 매년 사백 명씩 응시한다는 거는 어 열 한 개 치과대학 외에 우리나라의 치과대학을 갖다가 한 여섯 개 정도 더 가지고 있는 숫자나 마찬가지입니다.
# [3587.61–3594.30] (spk=4) 맞습니다. 예, 그리고 이 그 필리핀이나 이런 동남아에서 들어오는 인력이 어 자꾸 재수생이 쌓입니다.
# [3595.07–3602.45] (spk=4) 뭐 다른 가실 데가 없어서 그런지 재수생이 지금 자꾸 양산이 돼서 일부는 또 볼리비아로 넘어가서 거기서 이렇게 하고.
# [3602.45–3611.22] (spk=4) 그러기 때문에 이게 언젠가는 더블유 티 오 체제가 다 되면은 다 아마 어 언어 문제나 이런 것 때문에 전부 한국으로 들어올 텐데요.
# [3611.45–3621.35] (spk=4) 그럼 그때 전까지는 그런 어 좀 가릴 수 있는 법적 제도나 어떤 기관이나 이런 거가 절대적으로 필요하다고 생각하는데 아직은 그게 안 돼 있거든요.
# [3621.41–3631.81] (spk=3) 외국 같은 경우는 치과의사님들이 모여가지고 치과 의사들끼리 정부에 요구를 해서 정부에서는 법적인 근거만 마련해 주면 그 전문단체에서 그것을 설정해서 하고 있습니다.
# [3631.81–3639.17] (spk=3) 그때그때 탄력적으로. 근데 우리나라는 지금 면허제도가 복지부에서 나오기 때문에 상당히 국가기관에서 관리한다는 게 힘듭니다.
# [3639.77–3648.41] (spk=0) 네, 아, 지금 시각 아홉 시 십 이 분이고요. 시간이 얼마 남지 않았기 때문에 에 마무리 말씀을 한마디씩 간단하게 드리도록 하겠습니다. 먼저 홍 교수님께 부탁드릴까요? 예.
# [3648.46–3657.90] (spk=6) 그 저기 지금 방금 그 시청자께서 그 정형외과 의사 선생님께서 말씀하셨지만요. 더블유 티 오. 이 문제는 좋고 나쁘고 문제는 아니라고 생각을 합니다.
# [3658.21–3668.01] (spk=6) 어차피 지금 열린 사회에서 어, 그리고 그 어 그 세계화된 사회에서 우리가 살고 있기 때문에 그 부분에 대해서 인제 적절하게 대응을 하는 것이 문제가 되는데.
# [3668.30–3681.46] (spk=6) 이럴 기회에 그동안에 우리 사회에서 의료에 얽혔던 적폐를 어, 그 나름대로 어 그 그 좀 해소할 수 있는 기회로 삼았으면 좋겠다. 첫째는 의료의 공공성을 확실히 하게 하자.
# [3681.56–3692.12] (spk=6) 기본적으로 둘째, 그러면서 결국은 어 의료 시스템 짜는 문제하고 기술 개발에 좀 더 화끈하게 보장을 하고, 그리고 마지막으로는 어. 제가 볼 때 의료 주체성이라고 할까요?
# [3692.25–3698.70] (spk=6) 한의학 같은 것을 갖다가 외국에서 의술로 인정받을 수 있는 이런 어떤 학문적 정비 작업도 해야 된다고 저는 생각을 합니다.
# [3698.77–3700.00] (spk=0) 예 고맙습니다 왕 교수님.
# [3700.68–3709.65] (spk=5) 네, 저는 이제 그 정부에 대해서 좀 걱정하는 게 지금 저 칠리 와 우리나라 그 그 에프 티 에이 자유무역제도 그것이 지금 그걸 못하고 있어요.
# [3709.76–3721.56] (spk=5) 이것들 서비스 개방 하나인데, 서비스는 일반 전체의 개방인데. 왜 그러냐면 포도와 사과 재배하는 사람들이 반대하기 때문에 그걸 수입이 많아지니까 반역 때문에 못하고 있단 말이죠.
# [3721.92–3728.68] (spk=5) 그래서 이거와 마찬가지로 우리도 이제 너무 정부가 이해관계자들 다 의견을 다 듣고 그 뭐 만장 일출로 할라면 불가능합니다.
# [3728.68–3736.36] (spk=5) 그 다 듣되 그 어 선진국 사례를 들어서 예, 힘차게 해나가야 된다, 선진화를 해야 된다.
# [3736.84–3738.42] (spk=0) 겁니다 고맙습니다, 최 박사님.
# [3739.20–3749.85] (spk=2) 네, 뭐 저희 한의계에서는 어 더블유, 티 오 체제하에 대비를 하기 위해서 한의학의 어떤 공공의료 분야에 있어서 보험 급여를 확대를 한다라든지.
# [3750.19–3760.36] (spk=2) 또 산재보험이나 자동차 보험에 한방 분야를 참여시킨다라든지 국공립 한방병원을 확대해 준다라는데 하는 문제가 있고요. 그다음에 자체적으로는 이제 그 어.
# [3760.36–3766.64] (spk=2) 물론 법을 통해서 독립한의약법이라든지 한약관리법이라든지 한약 관련법을 빨리 정비를 해야 된다고 생각을 하고 있고요.
# [3767.03–3776.86] (spk=2) 그다음에각 국국의 어떤 전통의학 국가간 중국이나 한국이나 월남, 몽고 같은 나라들과 떤 네트워크을 형성해서 공동으로 대응할 수 있는 방법을 마련한다라든지.
# [3777.27–3786.21] (spk=2) 이 대학의 어떤 시설 기준을 확보해 가지고 어. 교육 단계에서부터 어떤 경쟁력을 강화를 한다라든지, 또 이 시간을 통해서 제 국민 여러분들께 당부드리고 싶은.
# [3786.21–3789.58] (spk=2) 것은 지금 저희 협회에 속속 보고되고 있는 사례들이 많이 있습니다.
# [3789.92–3798.30] (spk=2) 중국에서 중의 중이사 자격을 따왔다 해서 아주 고가의 의료비를 지금 받아서 국민들이 피해를 받고 있는 이런 사례가에서 보듯이.
# [3798.46–3803.89] (spk=2) 국민들이 의료 소비를 좀 더 현명하게 선택할 수 있는 이런 지혜로운 생활도 필요하다고.
# [3803.90–3805.28] (spk=0) 생각합니다 고맙습니다, 박사님.
# [3806.59–3815.44] (spk=1) 이십 일 세기에 가장 성장할 수 있는 부문으로, 세계적 경영학자는 의료 분야하고 교육 분야 레저 분야를 지적했습니다.
# [3816.10–3829.34] (spk=1) 근데 실제 우리나라는 이 교육 분야와 의료 분야가 가장 취약해지고 있습니다. 이 경쟁력을 강화시키려면 먼저 국가적인 시스템이 글로벌 스탠다드에 맞게 접근하는 거고.
# [3829.84–3838.25] (spk=1) 그 기간이 삼 년 남아 있는데, 그 삼 년 동안에 국제적인 룰에 맞도록 국가가 좀 많이 힘써주셨으면.
# [3838.30–3848.66] (spk=1) 예, 저희는 무슨 돈을 보조해 달라는 거든지 이런 게 아니라 실제적으로 이런 시스템의 구축이 국민건강에 좋을 거라고 생각합니다. 이 박사님 예.
# [3849.48–3854.46] (spk=4) 정부는 우리 국민들에 대해서 분명히 보건의료의 책임을 가지고 있는 주체입니다.
# [3854.82–3863.69] (spk=4) 그래서 요번 더블유 티 오 진행 과정에서 혹시라도 그 국민들을 위한 보건 의료에 아 좀 어떤 피해가 안 갔으면 하는 바람이 있고요.
# [3864.13–3875.57] (spk=4) 또 어 정부의 어떤 정책을 제안함에 있어서 의료계나 우리 어 국민들의 모든 의견이 합치되게 좀 결정을 해 주시라 하는 부탁의 말씀을 드리겠습니다.
# [3875.57–3878.24] (spk=0) 예, 고맙습니다. 그리고 끝으로 안 교수님께 부탁드리겠습니다.
# [3878.41–3886.84] (spk=3) 예, 전 뭐 간단히 말씀드리겠습니다. 어 더블유 티 오 를 두려워하지 말고. 그것이 대세라면 위기로 생각지 말고.
# [3886.84–3895.16] (spk=3) 오히려 우리가 어떤 기회를 생각하고 적극적으로 임하고, 그 전제는 우리 모두 국민을 위해서 일하겠다, 그렇게 말씀드리겠습니다. 네.
# [3895.16–3902.65] (spk=0) 고맙습니다. 토요일 밤 늦은 시각임에도 불구하고 이렇게 자리해 주신 토론자 여러분들과 시청자 여러분께 진심으로 감사의 말씀을 드립니다.
# [3905.31–3911.62] (spk=0) 더블유 티 오 전문직 서비스. 시장개방 협상 분야는 크게 변호사와 의료서비스로 요약할 수 있습니다.
# [3912.27–3921.15] (spk=0) 그런데 법률 서비스의 경우 법무부는 변호사 협회와 이미 오래전부터 작업반을 구성해서 대응택을 철저하게 준비해 온 것으로 알고 있습니다.
# [3922.07–3930.04] (spk=0) 의료서비스 개방협상이 본격화되고 있는 지금 묻겠습니다. 보건복지부는 관련 협회와 어떤 관계에 서 있습니까?
# [3930.89–3938.07] (spk=0) 국민의 건강과 생명을 아전인수격으로 해석해서 서로 혹시라도 대립관계에 서 있지는 않습니까?
# [3938.87–3950.15] (spk=0) 의약분업을 통해서 엄청난 혼란을 겪어야 했던 국민으로서는 심히 걱정하지 않을 수 없는 부분입니다. 의료시장 개방 문제를 짚어본 난상토론. 오늘은 여기서 접겠습니다. 안녕히 계십시오.
# Full text:
#  국내 의료계가 또다시 슬렁이고 있습니다. 더블유 티 오 를 중심으로 한 커센 개방의 파고가 그동안 공공제로 분류되어 왔던 의료계에도 숨가쁘게 밀려오고 있기 때문인데요. 국민의 생명과 직접 연계된 이 문제. 정부는 물론 당사자인 의료계도 너무 안이하게 대처하고 있는 게 아닌가 하는 비판이 일고 있습니다. 그래서 오늘 난상 토론에서는 의료서비스의 기본을 다시 한번 고민해 보고 개방협상에 임하는 우리의 대응방안을 심도 있게 고찰해 보도록 하겠습니다. 난상토론 잠시 후에 뵙겠습니다. 먼저 이렇게 자리해 주신 토론자 여러분들께 감사를 드리면서 어 치과의사협회와 한의사협회에서는 협회 내부의 입장이 정리된 관계로 오늘 토론회 이렇게 참석을 해 주셨습니다만 아. 또 그 이외에 국내 의료서비스 분야에는 대안의사협회라든가 대한병원협회, 그리고 대한 간호사협회 등 관련 협회들이 많지 않습니까? 아, 오늘 이 자리에 저희가 출연 요청을 드렸지만, 협회 측 사정상 아, 이 자리에 나오지 못하셨습니다. 이 점 양해의 말씀을 구합니다. 예, 뭐. 앞서 모두에서 보셨던 것처럼 그 의료시장 개방 협상이 본격화되고 있습니다. 아, 이번 협상을 이 자리에 오신 토론자분들께서는 어떻게 보고 계신지? 노 박사님께서는 아무래도 그 병원 경영자 입장에서 말이죠. 이번에 진행되고 있는 그 더블유 티 오 의료시장 개방협상을 어떻게 보고 계시는지요? 에 개방 협상이 만약에 개방 쪽으로 결론이 난다고 할 것 같으면 아마 가장 큰 영향을 받는 게 병원 분야인 것 같습니다. 병원은 그 병원 운영 자체뿐만 아니라 그 속에 구성원들이 의사 간호사, 그리고 또 병원 행정서비스. 그 외에 또 전산망이라든지 이런 여러 가지들이 다 동시에 개방되는 그런 우려가 있기 때문에. 그거에 의해서 아마 병원계에 승자와 패자가 갈라지는 그러한 굉장한 위험성도 내포하고 있다고 생각해서 예의 주시하고 있는. 상태입니다. 예, 천 박사님 뭐 한의사 분들도 어 더블유 티 오 시장 개방에 관한 어떤 입장이랄까요, 이것이 참 남다를 것 같은데요. 어떻게 이 협상을 준비하고 계신지요? 예, 뭐. 저희들은 구십 년대 초부터 한의학의 세계화를 주창을 하고, 세계 각국의 한의학을 보급하기 위해서 상당히 노력을 해 왔습니다만. 막상 이제 시장 개방이라고 하는 문제가 현실적으로 닥치니까. 회원들의 여론은 지금 두 가지로 나옵니다. 젊은 층을 중심으로 적극적으로 해외시장을 개발해야 된다는 입장과 또는 저 보수적인 입장에서 국민 건강의 어떤 그런 수준을 유지하기 위해서. 어떤 그 개발? 도상국에서 우리나라로 유입되는 인력에 대해서는 상당한 경계를 가지고 어 주의를 기울여야 된다는 두 가지 입장이 나오고 있습니다. 더군다나 이제 한의학이라고 하는 이제 분야가 우리나라에는 한의사 제도가 있지만, 선진제국에는 한의사라고 하는 제도 자체가 없기 때문에. 어떤 그 한의사라고 하는 제도. 분류 코드 자체를 유엔에서 좀 만들어줘서. 한의사들의 친구사가 아닌 또 다른 유사. 의료업자가 아닌 의료인으로서 각국의 진출할 수 있는 어떤 이런? 이제 국제 협상을 통해서 지위를 보장받아야 되겠다는 입장도 있고, 또 이제 한의학은 좀 특수적으로 국내적인 기반이 상당히 취약합니다. 관련 법규가 여러 가지로 미배한 점이 많기 때문에. 이번 더블유 티 오. 어떤 협상을 통해서 국내 법령을 좀 정비해서 한의학이 새롭게 도약할 수 있는 기회로 마련하자는 지금 준비를 열심히 하고 있습니다. 네, 안 교수님, 교수님께서는 대학교 교수이기도 하시지만, 동시에 성형외과 전문의이신 걸로 알고 있습니다. 그렇습니다. 아, 의사의 입장에서 어, 또 병원 경영자와는 좀 다른 뭐랄까 입장이랄까, 의견을 갖고 계실 것도 같은데. 더블유 티 오 개방 협상을 의사 입장에서는 어떻게 보고 계시는지요? 우선 제 사견으로는 지난 한 세기 동안, 아니 한 세대 동안 삼십 년 동안 우리나라 발전의 근간은 결국은 교역이 아니었지느냐. 우리가 그것을 근간으로 해서 이때까지 발달했고. 또 의학을 보더라도 우리나라 의학의 수준이 올라간 것은 어떤 형태든 간에 교류를 통해서 여기까지 올라온 것입니다. 그래서 결국은 더블유 티 오 가 이제 전 세계에서 피할 수 없는 대세이고, 또 그것을 원치 않는다 하더라도. 와이 투 케이처럼 가장 최악의 상황을 미리 대비해야 되기 때문에 저는 개방을 전제로 두고 거기에 대비해야 된다고 생각이 됩니다. 예, 이 박사님 예, 어 치과 의사도 어 참 뭐랄까 준비가 참 필요한 부분이 아닐 수 없을 것 같고요. 또 그 거센 개방의 파도에 맞서서 국내적으로, 또 국제적으로 여러 가지 그 상황을 예의 주시하고 계신 걸로 알고 있는데. 치과회사 협회는 이 더블유 티 오 개방에 관하여서 어떻게 준비를 하고 있고, 또 어떤 입장이신지가 궁금합니다. 어 치과 의료라는 것은 좀 어 타과에 비해서 약간 그 의료의 차이점이 있습니다. 그 어 환자와 대면에서 직접 모든 시간을 의사가 시술하고 환자 모든 시간을 같이 하는 아 좀. 의류의 특수성이 있는 분야가 치과 분야입니다. 아, 그래서 아마 어, 이 토론회를 보시는 분들 중에서 치과를 많이 그 당기셨던 분들은 어 아마 기대반 또 어 기후반. 이런 아마 시청자분들도 아마 그런 기분을 가지고 계실 텐데, 저희 치과의사들도 마찬가지입니다. 지금 아직까지는 혼란스럽고요. 어 또 어 서비스 분야가 그 성격이 짙은 분야이기 때문에 저희 치과의사들도 상당히 혼란스럽지만 지금 우려가 깊어지는 그런 분위기인 것 같습니다. 그래서 어 일단은 어 치과 특수 분야에 있어서 어 몇 가지 좀 가로막고 있는 그 장애물들이 있습니다. 그런 거가 좀 치워지지 않는 한은 개방에 좀 회의적이지 않은가. 예, 그런 분위기인 것 같습니다. 예. 그래서 지금까지 네 분 토론자께서는 아무래도 그 병원 경영자라든가 또는 이제 의사 한의사, 치과의사 입장에서 말씀해 주셨는데. 사실 그런 어떤 그 의료 담당자의 어떤 입장도 중요하지만, 아, 국민의 입장에서 생각하는 부분도 상당히 중요하지 않을 수 없고요. 그런 측면에서 오늘 토론은 여기부터 시작해보면 어떨까 싶습니다. 아, 과연 이 의료서비스라고 하는 것이 공공제로서의 어떤 성격을 계속해서 강조해야 할 것인지, 아니면 이 분야에 관하여서 소위. 그 시장경제 원리를 도입을 해서 어떤 서비스의 질적 개선을 좀 도모해야 할 것인지 제 이 부분에 관한 논의로 시작을 했으면 좋겠는데. 왕 교수님, 교수님께서는 아무래도 경제학자이시고 따라서. 의료서비스의 어떤 그 질적 개선을 위하여서 어떤 시장경제 원리의 도입에 찬성하시는 입장이신 걸로 알고 있는데 어떻습니까? 인제 그 의료서비스 분야가 공공재로서의 성격을 계속해서 유지해야 할 걸로 보십니까? 어떻습니까? 에 공공제라는 것실. 은행도 공공업인데 공공적인 성격이 큰데 은행은 다 열해야 된다고 나 지금 다 그렇게 합의를 보았습니다. 이거 이것도 마찬가지입니다. 우리가 적은 비용으로 보다 질 좋은 서비스를 어떻게 하면 제공하느냐 이거든요. 그런데 우리나라 지금 의료서비스는 완전히 사회주의적인 에 제도 의료제도입니다. 그러니까 수가도 병원 수가도 정해놓아가지고, 병원 대학 큰 병원들이 이익을 남기지 못하고 의사 의사 중요한 뭐 저 심장의과라든가 중요한 그 뇌라든가 이런 데는 지금 삼 디 업종으로 돼 가지고 의사들이 가질 않고 이게 저기 가격 체계가 맞지 않아서 그래요. 인센티브 유인 유인과 경쟁 체제가 안 되어 있다는 이겁니다. 그래서 그 시장경제로 해야 되고, 특히 또 소비자들은 또 이 다양한 것을 선택할 수 있고, 또 어 또 이 딴 것은 이제 이제 포기하더라도, 또 돈은 많이 들더라도 보다 질이 높은 서비스를 원하는 사람들이 많습니다. 그래서 그런 걸 제공하는 것이 이 자본주의과고, 그리고 경쟁과 유인이 없으면은 인센티브 제도가차 없으면은 이 사회가 잘 발전을 하지 않습니다. 의료제도 마찬가지라고 봅니다. 인센티브 제도를 강조하셨는데요. 홍 교수님, 홍 교수님께서도 그와 같은 입장에 찬성하시는지요? 어, 지금 그 어, 여기 그 어, 그 이 그 의료시장 개방이라고 하는 데 대해서 어 국가가 참으로 인제 그 의사 선생님들이라든가 병원분이라든가 어. 굉장히 걱정을 많이 하시는데. 불행하게도 철학 ...
#
# Transcription saved to /content/drive/MyDrive/output/sample.txt

# %%
# ============================
# 5. 감정(SER) 분석: HuBERT 기반
# ============================
# RTZR에서 사용한 정제 오디오(audio_for_asr)를 그대로 사용
y_ser, sr_ser = librosa.load(audio_for_asr, sr=16000, mono=True)
duration_ser = len(y_ser) / 16000.0
print(f"Loaded for SER: {audio_for_asr}, sr=16000, duration={duration_ser:.2f}s")

model_id = "superb/hubert-large-superb-er"
config_ser = AutoConfig.from_pretrained(model_id)
print("SER labels:", config_ser.id2label)

ser = pipeline(task="audio-classification", model=model_id, top_k=None)

def slice_audio(y, sr, start_s, end_s):
    i0 = int(max(0, start_s) * sr)
    i1 = int(min(len(y) / sr, end_s) * sr)
    return y[i0:i1]

def predict_emotion(wave_1d, sr=16000):
    if len(wave_1d) < int(sr * 0.3):  # 0.3초 미만은 스킵
        return {"label": "unknown", "score": 0.0, "probs": {}}
    out = ser({"array": wave_1d, "sampling_rate": sr})
    top = max(out, key=lambda d: d["score"])
    probs = {d["label"]: float(d["score"]) for d in out}
    return {"label": top["label"], "score": float(top["score"]), "probs": probs}

segment_emotions = []
for seg in segments_to_use:
    start, end, text = seg["start"], seg["end"], seg["text"]
    w = slice_audio(y_ser, 16000, start, end)
    pred = predict_emotion(w, 16000)
    segment_emotions.append({
        "start": start,
        "end": end,
        "text": text,
        "speaker": seg.get("speaker", None),
        "emotion": pred["label"],
        "confidence": pred["score"],
        "probs": pred["probs"],
    })

print("\n[DEBUG] SER 예시 5개:")
for s in segment_emotions[:5]:
    print(f"[{s['start']:.2f}-{s['end']:.2f}] spk={s['speaker']} "
          f"{s['emotion']} ({s['confidence']:.2f}) :: {s['text']}")
print(f"... 총 {len(segment_emotions)}개 세그먼트")
# Out:
# Loaded for SER: /content/drive/MyDrive/data_MP3/cleaned_sample.wav, sr=16000, duration=3951.06s
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# SER labels: {0: 'neu', 1: 'hap', 2: 'ang', 3: 'sad'}
# pytorch_model.bin:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/212 [00:00<?, ?B/s]
# Device set to use cuda:0
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# [DEBUG] SER 예시 5개:
# [0.53-11.29] spk=0 hap (0.74) :: 국내 의료계가 또다시 슬렁이고 있습니다. 더블유 티 오 를 중심으로 한 커센 개방의 파고가 그동안 공공제로 분류되어 왔던 의료계에도 숨가쁘게 밀려오고 있기 때문인데요.
# [12.83-21.44] spk=0 hap (0.48) :: 국민의 생명과 직접 연계된 이 문제. 정부는 물론 당사자인 의료계도 너무 안이하게 대처하고 있는 게 아닌가 하는 비판이 일고 있습니다.
# [22.21-32.85] spk=0 hap (0.56) :: 그래서 오늘 난상 토론에서는 의료서비스의 기본을 다시 한번 고민해 보고 개방협상에 임하는 우리의 대응방안을 심도 있게 고찰해 보도록 하겠습니다. 난상토론 잠시 후에 뵙겠습니다.
# [33.43-44.49] spk=0 neu (0.67) :: 먼저 이렇게 자리해 주신 토론자 여러분들께 감사를 드리면서 어 치과의사협회와 한의사협회에서는 협회 내부의 입장이 정리된 관계로 오늘 토론회 이렇게 참석을 해 주셨습니다만 아.
# [44.49-52.11] spk=0 hap (0.65) :: 또 그 이외에 국내 의료서비스 분야에는 대안의사협회라든가 대한병원협회, 그리고 대한 간호사협회 등 관련 협회들이 많지 않습니까?
# ... 총 441개 세그먼트

# %%
# ============================
# 6. 텍스트 감성 분석 (XLM-R sentiment)
# ============================
txt_model_id = "cardiffnlp/twitter-xlm-roberta-base-sentiment"
tok = AutoTokenizer.from_pretrained(txt_model_id)
txt_model = AutoModelForSequenceClassification.from_pretrained(txt_model_id)
txt_model.eval()

id2label_txt = {0: "negative", 1: "neutral", 2: "positive"}

def text_sentiment(s):
    if not s.strip():
        return {"label": "neutral", "score": 0.0}
    inputs = tok(s, return_tensors="pt", truncation=True, max_length=256)
    if torch.cuda.is_available():
        txt_model.to("cuda")
        inputs = {k: v.to("cuda") for k, v in inputs.items()}
    with torch.no_grad():
        logits = txt_model(**inputs).logits
    probs = torch.softmax(logits, dim=-1).squeeze().tolist()
    idx = int(np.argmax(probs))
    return {"label": id2label_txt[idx], "score": float(probs[idx])}

for it in segment_emotions:
    ts = text_sentiment(it["text"])
    it["text_sentiment"] = ts["label"]
    it["text_sentiment_conf"] = ts["score"]
# Out:
# config.json:   0%|          | 0.00/841 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]

# %%
# ============================
# 7. 감정 라벨 리매핑 (통일 태그)
# ============================
label_map = {
    "happiness": "happy",
    "sadness": "sad",
    "anger": "angry",
    "disgust": "disgust",
    "fear": "fear",
    "surprise": "surprise",
    "neutral": "neutral",
    # 필요시 추가
}

def remap(label):
    if label is None:
        return "unknown"
    l = label.lower()
    return label_map.get(l, l)

for it in segment_emotions:
    it["emotion"] = remap(it["emotion"])

# %%
# ============================
# 8. 전체 요약 + CSV 저장
# ============================
def summarize(items, key="emotion"):
    seq = [it[key] for it in items if it.get(key) and it[key] != "unknown"]
    if not seq:
        return "No clear emotion detected."
    counts = Counter(seq)
    top, cnt = counts.most_common(1)[0]
    preview = " → ".join(seq[:5] + (["..."] if len(seq) > 5 else []))
    return f"Dominant({key}): {top} (count={cnt}). Early trend: {preview}"

print("\n", summarize(segment_emotions, key="emotion"))
print(summarize(segment_emotions, key="text_sentiment"))

csv_path = "/content/drive/MyDrive/output/ser_segments.csv"
Path(csv_path).parent.mkdir(parents=True, exist_ok=True)
with open(csv_path, "w", newline="", encoding="utf-8") as f:
    w = csv.writer(f)
    w.writerow(["start","end","speaker","emotion","confidence",
                "text_sentiment","text_sent_conf","text"])
    for it in segment_emotions:
        w.writerow([
            f"{it['start']:.2f}",
            f"{it['end']:.2f}",
            it.get("speaker", ""),
            it["emotion"],
            f"{it['confidence']:.4f}",
            it.get("text_sentiment",""),
            f"{it.get('text_sentiment_conf',0.0):.4f}",
            it["text"]
        ])
print("Saved:", csv_path)
# Out:
#  Dominant(emotion): neu (count=343). Early trend: hap → hap → hap → neu → hap → ...
# Dominant(text_sentiment): neutral (count=251). Early trend: negative → negative → neutral → positive → neutral → ...
# Saved: /content/drive/MyDrive/output/ser_segments.csv
